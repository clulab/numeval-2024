# %%
import pandas as pd
import tensorflow as tf
from transformers import AutoTokenizer
import re
from transformers import AdamWeightDecay
from datasets import Dataset
import math
import numpy as np
from transformers import DataCollatorForSeq2Seq
from transformers import TFAutoModelForSeq2SeqLM
import torch
import matplotlib.pyplot as plt
import evaluate
from transformers import T5Tokenizer, T5Config, T5ForConditionalGeneration
import torch
# Out:
# 2023-11-20 16:33:41.241647: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-20 16:33:41.241670: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-20 16:33:41.241697: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-20 16:33:41.247582: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-20 16:33:41.785634: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
tf.config.experimental.list_physical_devices(device_type='GPU')
# Out:
# 2023-11-20 16:33:43.776648: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-20 16:33:43.780481: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-20 16:33:43.780630: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
def json_to_dataframe(filename):
    f = open(filename)
    df = pd.read_json(f)
    print(df.iloc[0])
    f.close()
    df["headline"]= df.apply(lambda x: x['masked headline'].replace('____', str(x['ans'])), axis=1)
    df['news'] = df['news'].apply(lambda x: re.sub(r'\([^)]*\)', '', x))
    df['masked headline'] = df['masked headline'].str.replace('____', '<extra_id_0> ') + ' </s>'
    df['text'] = df[['news', 'masked headline']].apply(" ".join, axis=1)
    df = df.astype(str)
    return df

# %%
train_data = json_to_dataframe('Train_Numerical_Reasoning.json')
# Out:
# news               (Oct 7, 2014  12:40 PM CDT) As of Jan. 1, Walm...
# masked headline    ____K Walmart Part-Timers to Lose Health Insur...
# calculation                                     Paraphrase(30,000,K)
# ans                                                               30
# Name: 0, dtype: object

# %%
train_data.head()
# Out:
#                                                 news  \
# 0   As of Jan. 1, Walmart will no longer offer 30...
# 1   Dax Shepard and Kristen Bell got married at t...
# 2   Nancy Reagan, the helpmate, backstage adviser...
# 3   American Airlines faces FAA fines of more tha...
# 4   Ingrid Lyne, the Seattle mom allegedly murder...
#
#                                      masked headline            calculation  \
# 0  <extra_id_0> K Walmart Part-Timers to Lose Hea...   Paraphrase(30,000,K)
# 1  Dax Shepard: Wedding to Kristen Bell Cost $<ex...              Copy(142)
# 2            Nancy Reagan Dead at <extra_id_0>  </s>               Copy(94)
# 3  American Airlines Faces $<extra_id_0> M Fine f...                Copy(7)
# 4  $<extra_id_0> K Raised for Kids of Mom Dismemb...  Paraphrase(222,000,K)
#
#    ans                                           headline  \
# 0   30   30K Walmart Part-Timers to Lose Health Insurance
# 1  142     Dax Shepard: Wedding to Kristen Bell Cost $142
# 2   94                            Nancy Reagan Dead at 94
# 3    7  American Airlines Faces $7M Fine for Safety Vi...
# 4  222   $222K Raised for Kids of Mom Dismembered on Date
#
#                                                 text
# 0   As of Jan. 1, Walmart will no longer offer 30...
# 1   Dax Shepard and Kristen Bell got married at t...
# 2   Nancy Reagan, the helpmate, backstage adviser...
# 3   American Airlines faces FAA fines of more tha...
# 4   Ingrid Lyne, the Seattle mom allegedly murder...

# %%
dataset = Dataset.from_pandas(train_data)
dataset = dataset.train_test_split(test_size=0.2)

# %%
model_name = "Michau/t5-base-en-generate-headline"

# %%
def preprocess_function(examples):   
    #inputs = [prefix + doc for doc in examples["news"]]
    inputs = tokenizer(examples['text'],max_length=3066,  truncation=True)
    labels = tokenizer(text_target=examples["headline"], max_length=256, truncation=True)
    inputs["labels"] = labels["input_ids"]
    return inputs

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name)

# %%
tokenized = dataset.map(preprocess_function, batched=True, #num_proc=4,
                        remove_columns=dataset['train'].column_names)
# Out:
# Map:   0%|          | 0/16925 [00:00<?, ? examples/s]
# Map:   0%|          | 0/4232 [00:00<?, ? examples/s]

# %%
data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer,
                                           model=model_name,
                                           return_tensors="tf")
#optimizer = AdamWeightDecay(learning_rate=1e-4, weight_decay_rate=0.01)
optimizer = AdamWeightDecay(learning_rate=5e-5, weight_decay_rate=0.01)
#optimizer = AdamWeightDecay(learning_rate=8e-5, weight_decay_rate=0.01)

# %%
model = TFAutoModelForSeq2SeqLM.from_pretrained(model_name)
# Out:
# All model checkpoint layers were used when initializing TFT5ForConditionalGeneration.
#
# All the layers of TFT5ForConditionalGeneration were initialized from the model checkpoint at Michau/t5-base-en-generate-headline.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFT5ForConditionalGeneration for predictions without further training.

# %%
tf_train_set = model.prepare_tf_dataset(
    tokenized["train"],
    shuffle=True,
    batch_size=3,
    collate_fn=data_collator,
)

tf_test_set = model.prepare_tf_dataset(
    tokenized["test"],
    shuffle=False,
    batch_size=3,
    collate_fn=data_collator,
)
# Out:
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.

# %%
model.compile(optimizer=optimizer)

# %%
eval_loss = model.evaluate(tf_test_set)
print(f"Pretrained LM Perplexity: {math.exp(eval_loss):.2f}")
# Out:
# 265/265 [==============================] - 61s 199ms/step - loss: 0.9788
# Pretrained LM Perplexity: 2.66

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=1)
history = model.fit(x=tf_train_set, validation_data=tf_test_set, callbacks=[callback],epochs=10)
#model.fit(x=tf_train_set, validation_data=tf_test_set, batch_size=6, epochs=1)
#eval_loss = model.evaluate(tf_test_set)
#print(f"Finetuned Perplexity: {math.exp(eval_loss):.2f}")
# Out:
# Epoch 1/10
# 5641/5641 [==============================] - 1365s 239ms/step - loss: 0.0774 - val_loss: 0.0456
# Epoch 2/10
# 5641/5641 [==============================] - 1358s 241ms/step - loss: 0.0415 - val_loss: 0.0460

# %%
eval_loss = model.evaluate(tf_test_set)
print(f"Finetuned Perplexity: {math.exp(eval_loss):.2f}")
# Out:
# 265/265 [==============================] - 53s 201ms/step - loss: 0.0442
# Finetuned Perplexity: 1.05

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
f = open('Dev_Numerical_Reasoning.json')
df = pd.read_json(f)
df['news'] = df['news'].apply(lambda x: re.sub(r'\([^)]*\)', '', x))
df['masked headline'] = df['masked headline'].str.replace('____', '<extra_id_0> ') + ' </s>'
df['text'] = df[['news', 'masked headline']].apply(" ".join, axis=1)
df = df.astype(str)
#df = df.iloc[:200]
#df = df.iloc[100:500]
f.close()
test_data = Dataset.from_pandas(df)

# %%
def t5_predictions(data, tokenizer, model):
    text = data['text']
    headline = data['masked headline']
    print(headline)
    inputs = tokenizer.encode_plus(text, add_special_tokens=True,
                                   return_tensors="pt").input_ids
    # input_ids = inputs['input_ids'].to(device)
    # attention_masks = inputs['attention_mask']

    outputs = model.generate(inputs,
                             max_length=128, num_beams=5, early_stopping=True)

    _0_index = headline.index('<extra_id_0> ')
    print(_0_index)

    res = ''
    results = tokenizer.decode(outputs[0][1:], skip_special_tokens=False,
                               clean_up_tokenization_spaces=False)
    print("Pred: ", results)
    #res = re.findall(r"([\d:,./]+)", results)
    res = re.findall(r"(\d+[./]?\d*)", results[_0_index:_0_index+50])
    if len(res) < 1:
        res = re.findall(r"(\d+[./]?\d*)", results)
    try:
        return res[0]
    except:
        return None

# %%
tru = 0
for i in test_data:
    prediction1 = t5_predictions(i, tokenizer, model)
    answer = i['ans']
    print("Answer: ", answer)
    print("Prediction1: ", prediction1)
    print("Calc: ", i['calculation'])
    if answer == prediction1:
        tru += 1
    print("")
# Out:
# <extra_id_0> rd Victim Dead in Quarry Shooting; Manhunt Still On </s>
# 2023-11-20 17:25:22.666219: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fa6dc057450 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-11-20 17:25:22.666237: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3060, Compute Capability 8.6
# 2023-11-20 17:25:22.673833: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-11-20 17:25:22.888348: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8700
# 2023-11-20 17:25:22.926782: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 0
# Pred:  3rd Victim Dead in Quarry Shooting; Manhunt Still On</s>
# Answer:  3
# Prediction1:  3
# Calc:  Trans(three)
#
# NYT Corrects 1853 Piece After <extra_id_0>  Years Win </s>
# 30
# Pred:  NYT Corrects 1853 Piece After 12 Years Win</s><pad>
# Answer:  12
# Prediction1:  12
# Calc:  Copy(12)
#
# Stocks Up <extra_id_0>  in Election Rally </s>
# 10
# Pred:  Stocks Up 305 in Election Rally</s>
# Answer:  305
# Prediction1:  305
# Calc:  Round(305.45,0)
#
# You Can Watch The Interview at <extra_id_0> pm </s>
# 31
# Pred:  You Can Watch The Interview at 1pm</s><pad>
# Answer:  1
# Prediction1:  1
# Calc:  Copy(1)
#
# Murder Suspect, <extra_id_0> , Will Stay in Adult Jail </s>
# 16
# Pred:  Murder Suspect, 10, Will Stay in Adult Jail</s><pad>
# Answer:  10
# Prediction1:  10
# Calc:  Copy(10)
#
# Tobacco Firms Knew of Radiation in Cigs—in <extra_id_0>  </s>
# 43
# Pred:  Tobacco Firms Knew of Radiation in Cigs—in 1959</s>
# Answer:  1959
# Prediction1:  1959
# Calc:  Copy(1959)
#
# AIG Bonuses Higher Than Thought: $<extra_id_0> M </s>
# 34
# Pred:  AIG Bonuses Higher Than Thought: $218M</s>
# Answer:  218
# Prediction1:  218
# Calc:  Copy(218)
#
# <extra_id_0>  Months May Not Be 'Normal' Pregnancy, After All </s>
# 0
# Pred:  3 Months May Not Be 'Normal' Pregnancy, After All</s>
# Answer:  9
# Prediction1:  3
# Calc:  Round(Divide(268,30),0)
#
# Yahoo Lays Off <extra_id_0> K Workers </s>
# 15
# Pred:  Yahoo Lays Off 2K Workers</s><pad>
# Answer:  2
# Prediction1:  2
# Calc:  Paraphrase(2,000,K)
#
# BP: <extra_id_0> %-70% Chance 'Top Kill' Will Work </s>
# 4
# Pred:  BP: 60%-70% Chance 'Top Kill' Will Work</s><pad>
# Answer:  60
# Prediction1:  60
# Calc:  Copy(60)
#
# Auto Bosses to Press Pelosi for Another $<extra_id_0> B </s>
# 41
# Pred:  Auto Bosses to Press Pelosi for Another $25B</s>
# Answer:  25
# Prediction1:  25
# Calc:  Copy(25)
#
# From Britain With Love: MI<extra_id_0>  Seeks Minorities </s>
# 26
# Pred:  From Britain With Love: MI6 Seeks Minorities</s>
# Answer:  6
# Prediction1:  6
# Calc:  Copy(6)
#
# Deficit Breaks $<extra_id_0> T Again </s>
# 16
# Pred:  Deficit Breaks $1T Again</s><pad>
# Answer:  1
# Prediction1:  1
# Calc:  Round(1.29,0)
#
# Louis CK Makes $200K in <extra_id_0>  Days on Web Video </s>
# 24
# Pred:  Louis CK Makes $200K in 4 Days on Web Video</s><pad>
# Answer:  4
# Prediction1:  4
# Calc:  Copy(4)
#
# <extra_id_0> rd American With Ebola Lands in US </s>
# 0
# Pred:  3rd American With Ebola Lands in US</s>
# Answer:  3
# Prediction1:  3
# Calc:  Trans(third)
#
# Economy May Tank Palin's $<extra_id_0> B Pipeline </s>
# 26
# Pred:  Economy May Tank Palin's $30B Pipeline</s>
# Answer:  30
# Prediction1:  30
# Calc:  Copy(30)
#
# G<extra_id_0>  Cops Caught on Tape Shoving Protester Who Died </s>
# 1
# Pred:  G20 Cops Caught on Tape Shoving Protester Who Died</s>
# Answer:  20
# Prediction1:  20
# Calc:  Copy(20)
#
# US Soldier Held After Killing <extra_id_0>  at Baghdad Base </s>
# 30
# Pred:  US Soldier Held After Killing 5 at Baghdad Base</s>
# Answer:  5
# Prediction1:  5
# Calc:  Trans(five)
#
# Nintendo Chief Dies at <extra_id_0>  </s>
# 23
# Pred:  Nintendo Chief Dies at 55</s>
# Answer:  55
# Prediction1:  55
# Calc:  Copy(55)
#
# USS Pueblo Crew Awarded $<extra_id_0> M </s>
# 25
# Pred:  USS Pueblo Crew Awarded $65M</s>
# Answer:  65
# Prediction1:  65
# Calc:  Copy(65)
#
# Seattle Slaps <extra_id_0> ¢ Fee on All Grocery Bags </s>
# 14
# Pred:  Seattle Slaps 20<unk> Fee on All Grocery Bags</s><pad>
# Answer:  20
# Prediction1:  20
# Calc:  Copy(20)
#
# Dow Edges Up <extra_id_0>  Points </s>
# 13
# Pred:  Dow Edges Up 3 Points</s><pad>
# Answer:  2
# Prediction1:  3
# Calc:  Copy(2)
#
# Secession Gets Green Light in <extra_id_0>  Colorado Counties </s>
# 30
# Pred:  Secession Gets Green Light in 6 Colorado Counties</s>
# Answer:  6
# Prediction1:  6
# Calc:  Copy(6)
#
# Bankrupt <extra_id_0>  Cent Now Suing His Ex-Lawyers </s>
# 9
# Pred:  Bankrupt 50 Cent Now Suing His Ex-Lawyers</s>
# Answer:  50
# Prediction1:  50
# Calc:  Copy(50)
#
# When It Comes to Tech Bubbles, 2011 Is Not <extra_id_0>  </s>
# 43
# Pred:  When It Comes to Tech Bubbles, 2011 Is Not 2010</s>
# Answer:  2000
# Prediction1:  2010
# Calc:  Subtract(2011,11)
#
# Slim Gain Is Dow's <extra_id_0> rd in Row </s>
# 19
# Pred:  Slim Gain Is Dow's 3rd in Row</s>
# Answer:  3
# Prediction1:  3
# Calc:  Copy(3)
#
# After <extra_id_0>  People Overdose, Chicago Cops Arrest 2 </s>
# 6
# Pred:  After 74 People Overdose, Chicago Cops Arrest 2</s>
# Answer:  74
# Prediction1:  74
# Calc:  Copy(74)
#
# Coke Back in Burma After <extra_id_0>  Years </s>
# 25
# Pred:  Coke Back in Burma After 60 Years</s><pad>
# Answer:  60
# Prediction1:  60
# Calc:  Copy(60)
#
# Boys Had Good Intentions, Ruin <extra_id_0> K-Year-Old Rock Art </s>
# 31
# Pred:  Boys Had Good Intentions, Ruin 5K-Year-Old Rock Art</s><pad>
# Answer:  5
# Prediction1:  5
# Calc:  Paraphrase(5,000,K)
#
# Woman Sells First Spot in iPad <extra_id_0>  Line for $900 </s>
# 31
# Pred:  Woman Sells First Spot in iPad 2 Line for $900</s>
# Answer:  2
# Prediction1:  2
# Calc:  Copy(2)
#
# Heartland Tornadoes Kill <extra_id_0>  in Arkansas </s>
# 25
# Pred:  Heartland Tornadoes Kill 7 in Arkansas</s>
# Answer:  7
# Prediction1:  7
# Calc:  Trans(seven)
#
# At <extra_id_0> , Seeger Still Tuned to Social Activism </s>
# 3
# Pred:  At 90, Seeger Still Tuned to Social Activism</s><pad>
# Answer:  90
# Prediction1:  90
# Calc:  Copy(90)
#
# After <extra_id_0>  Years, GM Cedes Sales Crown to Toyota </s>
# 6
# Pred:  After 77 Years, GM Cedes Sales Crown to Toyota</s>
# Answer:  77
# Prediction1:  77
# Calc:  Copy(77)
#
# After Potomac Primary, March <extra_id_0>  Looms Large </s>
# 29
# Pred:  After Potomac Primary, March 4 Looms Large</s>
# Answer:  4
# Prediction1:  4
# Calc:  Copy(4)
#
# Man Told $<extra_id_0> K Lottery Win Was a Misprint </s>
# 10
# Pred:  Man Told $500K Lottery Win Was a Misprint</s><pad>
# Answer:  500
# Prediction1:  500
# Calc:  Paraphrase(500,000,K)
#
# Obama Expects to Rake in $<extra_id_0> M This Month </s>
# 26
# Pred:  Obama Expects to Rake in $30M This Month</s><pad>
# Answer:  30
# Prediction1:  30
# Calc:  Copy(30)
#
# <extra_id_0>  Planes Barely Miss Each Other Over New York </s>
# 0
# Pred:  2 Planes Barely Miss Each Other Over New York</s>
# Answer:  2
# Prediction1:  2
# Calc:  Trans(two)
#
# Election <extra_id_0> : Mitt Romney Beats President Barack Obama in New Hampshire Poll </s>
# 9
# Pred:  Election 2012: Mitt Romney Beats President Barack Obama in New Hampshire Poll</s>
# Answer:  2012
# Prediction1:  2012
# Calc:  Copy(2012)
#
# Bankers to Reap $<extra_id_0> B Despite Crash </s>
# 17
# Pred:  Bankers to Reap $70B Despite Crash</s>
# Answer:  70
# Prediction1:  70
# Calc:  Copy(70)
#
# Unborn Twin Surgically Removed From <extra_id_0> -Year-Old </s>
# 36
# Pred:  Unborn Twin Surgically Removed From 15-Year-Old</s>
# Answer:  15
# Prediction1:  15
# Calc:  Copy(15)
#
# Sex in the City: <extra_id_0> % of New Yorkers Have Herpes </s>
# 17
# Pred:  Sex in the City: 26% of New Yorkers Have Herpes</s>
# Answer:  26
# Prediction1:  26
# Calc:  Copy(26)
#
# How Obama Crossed Paths With a Radical '<extra_id_0> s Bomber </s>
# 40
# Pred:  How Obama Crossed Paths With a Radical '60s Bomber</s>
# Answer:  60
# Prediction1:  60
# Calc:  Copy(60)
#
# <extra_id_0>  Dead as Worker Storms Conn. Beer Distributor </s>
# 0
# Pred:  9 Dead as Worker Storms Conn. Beer Distributor</s>
# Answer:  9
# Prediction1:  9
# Calc:  Trans(nine)
#
# AirAsia Jet Missing With <extra_id_0>  Aboard </s>
# 25
# Pred:  AirAsia Jet Missing With 162 Aboard</s>
# Answer:  162
# Prediction1:  162
# Calc:  Copy(162)
#
# Palin Grabbed $<extra_id_0> K in Gifts </s>
# 15
# Pred:  Palin Grabbed $25K in Gifts</s><pad>
# Answer:  25
# Prediction1:  25
# Calc:  Paraphrase(25,000,K)
#
# Florida Fugitive Caught After <extra_id_0>  Years in Mexico </s>
# 30
# Pred:  Florida Fugitive Caught After 37 Years in Mexico</s>
# Answer:  37
# Prediction1:  37
# Calc:  Copy(37)
#
# Eight Is Enough  Dad Dead at <extra_id_0>  </s>
# 29
# Pred:  Eight Is Enough Dad Dead at 86</s>
# Answer:  86
# Prediction1:  6
# Calc:  Copy(86)
#
# Starbucks Tests New Size: <extra_id_0> -Ounce 'Trenta' </s>
# 26
# Pred:  Starbucks Tests New Size: 31-Ounce 'Trenta'</s>
# Answer:  31
# Prediction1:  31
# Calc:  Copy(31)
#
# Texas Millionaire Hit With <extra_id_0>  Counts of Child Molestation </s>
# 27
# Pred:  Texas Millionaire Hit With 11 Counts of Child Molestation</s>
# Answer:  11
# Prediction1:  11
# Calc:  Copy(11)
#
# House Speaker John Boehner Rejects President Obama's Request to Address Joint Session of Congress on Sept. <extra_id_0>  </s>
# 107
# Pred:  House Speaker John Boehner Rejects President Obama's Request to Address Joint Session of Congress on Sept. 7</s>
# Answer:  7
# Prediction1:  7
# Calc:  Copy(7)
#
# Ford Surprises With $<extra_id_0> M Q1 Profit </s>
# 21
# Pred:  Ford Surprises With $100M Q1 Profit</s>
# Answer:  100
# Prediction1:  100
# Calc:  Copy(100)
#
# <extra_id_0>  Students Arrested After Chemical 'Device' Goes Off </s>
# 0
# Pred:  2 Students Arrested After Chemical 'Device' Goes Off</s>
# Answer:  2
# Prediction1:  2
# Calc:  Trans(Two)
#
# <extra_id_0>  Winning Powerball Tickets Sold </s>
# 0
# Pred:  2 Winning Powerball Tickets Sold</s>
# Answer:  2
# Prediction1:  2
# Calc:  Add(Span(Arizona),Span(Missouri))
#
# Humans Push Earth Past <extra_id_0>  of 9 Danger Zones </s>
# 23
# Pred:  Humans Push Earth Past 4 of 9 Danger Zones</s><pad>
# Answer:  4
# Prediction1:  4
# Calc:  Trans(four)
#
# Floridian Is Now <extra_id_0> rd to Die of Seawater Bacteria </s>
# 17
# Pred:  Floridian Is Now 3rd to Die of Seawater Bacteria</s>
# Answer:  3
# Prediction1:  3
# Calc:  Trans(three)
#
# Clintons Near Deal on $<extra_id_0> M Country Mansion </s>
# 23
# Pred:  Clintons Near Deal on $11M Country Mansion</s>
# Answer:  11
# Prediction1:  11
# Calc:  Copy(11)
#
# Periodic Table Gets <extra_id_0>  New Elements </s>
# 20
# Pred:  Periodic Table Gets 2 New Elements</s><pad>
# Answer:  2
# Prediction1:  2
# Calc:  Trans(Two)
#
# Sallie Mae Drops $<extra_id_0> M Lawsuit </s>
# 18
# Pred:  Sallie Mae Drops $900M Lawsuit</s>
# Answer:  900
# Prediction1:  900
# Calc:  Copy(900)
#
# Tale of Convicts' Famed <extra_id_0>  Escape Revealed </s>
# 24
# Pred:  Tale of Convicts' Famed 1791 Escape Revealed</s>
# Answer:  1791
# Prediction1:  1791
# Calc:  Copy(1791)
#
# <extra_id_0>  Girls Charged in Shooting Death of Big Brother, 16 </s>
# 0
# Pred:  2 Girls Charged in Shooting Death of Big Brother, 16</s>
# Answer:  2
# Prediction1:  2
# Calc:  Trans(two)
#
# Levi Aron Gets <extra_id_0>  Years for Murder of Brooklyn Boy, 8 </s>
# 15
# Pred:  Levi Aron Gets 40 Years for Murder of Brooklyn Boy, 8</s>
# Answer:  40
# Prediction1:  40
# Calc:  Copy(40)
#
# <extra_id_0>  Girls Dead After Bus Goes Off Freeway </s>
# 0
# Pred:  2 Girls Dead After Bus Goes Off Freeway</s>
# Answer:  2
# Prediction1:  2
# Calc:  Trans(two)
#
# YouTube Turns <extra_id_0> ; Watch Its First Video </s>
# 14
# Pred:  YouTube Turns 5; Watch Its First Video</s><pad>
# Answer:  5
# Prediction1:  5
# Calc:  Copy(5)
#
# US Economy Shrank <extra_id_0> %— Worst Since '09 </s>
# 18
# Pred:  US Economy Shrank 2.9%— Worst Since '09</s>
# Answer:  2.9
# Prediction1:  2.9
# Calc:  Copy(2.9)
#
# MH<extra_id_0>  Decision Could Leave Mystery Unsolved </s>
# 2
# Pred:  3 Decision Could Leave Mystery Unsolved</s><pad>
# Answer:  370
# Prediction1:  3
# Calc:  Copy(370)
#
# Motorcycle Racer Dies After Hitting <extra_id_0> mph </s>
# 36
# Pred:  Motorcycle Racer Dies After Hitting 300mph</s><pad>
# Answer:  285
# Prediction1:  300
# Calc:  Copy(285)
#
# <extra_id_0>  Teeth Removed From Boy's Head </s>
# 0
# Pred:  232 Teeth Removed From Boy's Head</s>
# Answer:  232
# Prediction1:  232
# Calc:  Copy(232)
#
# Giants Take Lead With <extra_id_0> -0 Shutout </s>
# 22
# Pred:  Giants Take Lead With 3-2 Shutout</s><pad>
# Answer:  5
# Prediction1:  3
# Calc:  Copy(5)
#
# Pols: No Stimulus By Jan. <extra_id_0>  </s>
# 26
# Pred:  Pols: No Stimulus By Jan. 19</s>
# Answer:  19
# Prediction1:  19
# Calc:  Copy(19)
#
# <extra_id_0> M New Citizens Break Century Record </s>
# 0
# Pred:  1M New Citizens Break Century Record</s><pad>
# Answer:  1
# Prediction1:  1
# Calc:  Span( a million)
#
# Lehman CEO Sells Mansion to Wife—for $<extra_id_0>  </s>
# 38
# Pred:  Lehman CEO Sells Mansion to Wife—for $100</s>
# Answer:  100
# Prediction1:  100
# Calc:  Copy(100)
#
# <extra_id_0>  Common Surgeries May Make Women More Fertile </s>
# 0
# Pred:  2 Common Surgeries May Make Women More Fertile</s>
# Answer:  2
# Prediction1:  2
# Calc:  Add(having their tonsils),Span(appendix removed))
#
# Save the Trauma Excuses: You Failed on <extra_id_0>  </s>
# 39
# Pred:  Save the Trauma Excuses: You Failed on 9/11</s><pad>
# Answer:  9/11
# Prediction1:  9/11
# Calc:  Copy(9/11)
#
# UK Forking Over $<extra_id_0> M to Bail Out Charities </s>
# 17
# Pred:  UK Forking Over $60M to Bail Out Charities</s><pad>
# Answer:  60
# Prediction1:  60
# Calc:  Copy(60)
#
# <extra_id_0>  Years Later, Pac-Man's Influence Endures </s>
# 0
# Pred:  30 Years Later, Pac-Man's Influence Endures</s>
# Answer:  30
# Prediction1:  30
# Calc:  Copy(30)
#
# <extra_id_0>  Days Later, California Prisoners End Hunger Strike </s>
# 0
# Pred:  2 Days Later, California Prisoners End Hunger Strike</s>
# Answer:  59
# Prediction1:  2
# Calc:  Subtract(Sep 5,July 8)
#
# Boy, 11, Charged in Fatal Shooting of Brother, <extra_id_0>  </s>
# 47
# Pred:  Boy, 11, Charged in Fatal Shooting of Brother, 3</s>
# Answer:  3
# Prediction1:  3
# Calc:  Copy(3)
#
# Obama Opens 10-Point Lead in Ohio, <extra_id_0>  in Florida </s>
# 35
# Pred:  Obama Opens 10-Point Lead in Ohio, 9 in Florida</s>
# Answer:  9
# Prediction1:  9
# Calc:  Copy(9)
#
# Wal-Mart Family Donates $<extra_id_0> M to Art Museum </s>
# 25
# Pred:  Wal-Mart Family Donates $800M to Art Museum</s>
# Answer:  800
# Prediction1:  800
# Calc:  Copy(800)
#
# Q3 GDP Growth More Like <extra_id_0> % Than 3.5% </s>
# 24
# Pred:  Q3 GDP Growth More Like 2.8% Than 3.5%</s>
# Answer:  2.8
# Prediction1:  2.8
# Calc:  Copy(2.8)
#
# World on Brink of <extra_id_0> th Great Extinction </s>
# 18
# Pred:  World on Brink of 6th Great Extinction</s>
# Answer:  6
# Prediction1:  6
# Calc:  Trans(six)
#
# <extra_id_0>  Aussies Killed in Afghan Insider Attack </s>
# 0
# Pred:  3 Aussies Killed in Afghan Insider Attack</s>
# Answer:  3
# Prediction1:  3
# Calc:  Copy(3)
#
# Lions to Make Stafford No. <extra_id_0>  Draft Pick </s>
# 27
# Pred:  Lions to Make Stafford No. 1 Draft Pick</s>
# Answer:  1
# Prediction1:  1
# Calc:  Span(top draft pick)
#
# <extra_id_0> K Flags Cover Veterans' Cemetery That Barred Them </s>
# 0
# Pred:  50K Flags Cover Veterans' Cemetery That Barred Them</s>
# Answer:  50
# Prediction1:  50
# Calc:  Paraphrase(50,000,K)
#
# Ex-Congressman Caught With $<extra_id_0> K in Freezer Is Guilty </s>
# 28
# Pred:  Ex-Congressman Caught With $90K in Freezer Is Guilty</s>
# Answer:  90
# Prediction1:  90
# Calc:  Paraphrase(90,000,K)
#
# LiLo Off Formal Probation for First Time in <extra_id_0>  Years </s>
# 44
# Pred:  LiLo Off Formal Probation for First Time in 4 Years</s><pad>
# Answer:  4.5
# Prediction1:  4
# Calc:  Trans(four and a half)
#
# Eartha Kitt Dead at <extra_id_0>  </s>
# 20
# Pred:  Eartha Kitt Dead at 81</s>
# Answer:  81
# Prediction1:  81
# Calc:  Copy(81)
#
# Chrome Surges to No. <extra_id_0>  </s>
# 21
# Pred:  Chrome Surges to No. 2</s><pad>
# Answer:  2
# Prediction1:  2
# Calc:  Copy(2)
#
# Arctic Hasn't Been This Warm in <extra_id_0> K Years </s>
# 32
# Pred:  Arctic Hasn't Been This Warm in 44K Years</s><pad>
# Answer:  44
# Prediction1:  44
# Calc:  Paraphrase(44,000,K)
#
# Paulson Wants Next $<extra_id_0> B, But Bush May Not Ask for It </s>
# 20
# Pred:  Paulson Wants Next $700B, But Bush May Not Ask for It</s>
# Answer:  350
# Prediction1:  700
# Calc:  Divide(700,2)
#
# Florida's Challenge: $<extra_id_0> K to Killer of Longest Python </s>
# 22
# Pred:  Florida's Challenge: $1K to Killer of Longest Python</s><pad>
# Answer:  1
# Prediction1:  1
# Calc:  Paraphrase(1,000,K)
#
# Man Loses <extra_id_0>  Years of Work When Google Deletes His Blog </s>
# 10
# Pred:  Man Loses 14 Years of Work When Google Deletes His Blog</s>
# Answer:  14
# Prediction1:  14
# Calc:  Copy(14)
#
# India Blames Pakistan in Killing of <extra_id_0>  Soldiers </s>
# 36
# Pred:  India Blames Pakistan in Killing of 5 Soldiers</s>
# Answer:  5
# Prediction1:  5
# Calc:  Trans(five)
#
# 'Web <extra_id_0> ' is English's Millionth Word </s>
# 5
# Pred:  'Web 2.0' is English's Millionth Word</s><pad>
# Answer:  2.0
# Prediction1:  2.0
# Calc:  Copy(2.0)
#
# Merkel Heads for <extra_id_0> nd Term, With Messy Coalition </s>
# 17
# Pred:  Merkel Heads for 2nd Term, With Messy Coalition</s><pad>
# Answer:  2
# Prediction1:  2
# Calc:  Trans(second)
#
# Rare Bug Kills SF Disease Researcher, <extra_id_0>  </s>
# 38
# Pred:  Rare Bug Kills SF Disease Researcher, 25</s>
# Answer:  25
# Prediction1:  25
# Calc:  Copy(25)
#
# Dow Ends Day Up <extra_id_0>  </s>
# 16
# Pred:  Dow Ends Day Up 74</s>
# Answer:  74
# Prediction1:  74
# Calc:  Copy(74)
#
# Sonar Vehicle Seeking MH<extra_id_0>  Crashes Into Volcano </s>
# 24
# Pred:  Sonar Vehicle Seeking MH370 Crashes Into Volcano</s><pad>
# Answer:  370
# Prediction1:  370
# Calc:  Copy(370)
#
# <extra_id_0>  Years Later, Wyoming Fugitive Caught in Alaska </s>
# 0
# Pred:  33 Years Later, Wyoming Fugitive Caught in Alaska</s>
# Answer:  31
# Prediction1:  33
# Calc:  Subtract(2012-1981)
#
# Bruni to G<extra_id_0> : Don't Let Recession Kill AIDS Funding </s>
# 10
# Pred:  Bruni to G8: Don't Let Recession Kill AIDS Funding</s>
# Answer:  8
# Prediction1:  8
# Calc:  Copy(8)
#
# Shakespeare Gets a <extra_id_0> -Year-Old Drug Test </s>
# 19
# Pred:  Shakespeare Gets an 400-Year-Old Drug Test</s>
# Answer:  400
# Prediction1:  400
# Calc:  Copy(400)
#
# Elizabeth Edwards Dead at <extra_id_0>  </s>
# 26
# Pred:  Elizabeth Edwards Dead at 61</s>
# Answer:  61
# Prediction1:  61
# Calc:  Copy(61)
#
# New EU Sanctions Hit Maker of AK-<extra_id_0>  </s>
# 33
# Pred:  New EU Sanctions Hit Maker of AK-47</s>
# Answer:  47
# Prediction1:  47
# Calc:  Copy(47)
#
# Zimmerman Sues NBC Over <extra_id_0>  Tape Edits </s>
# 24
# Pred:  Zimmerman Sues NBC Over 911 Tape Edits</s><pad>
# Answer:  911
# Prediction1:  911
# Calc:  Copy(911)
#
# Big <extra_id_0>  Execs Finish With Senate </s>
# 4
# Pred:  Big 3 Execs Finish With Senate</s>
# Answer:  3
# Prediction1:  3
# Calc:  Trans(Three)
#
# Texas Performs <extra_id_0> th Execution </s>
# 15
# Pred:  Texas Performs 500th Execution</s>
# Answer:  500
# Prediction1:  500
# Calc:  Copy(500)
#
# Some of the New $<extra_id_0>  Bills Will Be Worth $1K—or More </s>
# 17
# Pred:  Some of the New $100 Bills Will Be Worth $1K—or More</s>
# Answer:  100
# Prediction1:  100
# Calc:  Copy(100)
#
# <extra_id_0> -Year-Old Oudin Upsets Sharapova </s>
# 0
# Pred:  17-Year-Old Oudin Upsets Sharapova</s>
# Answer:  17
# Prediction1:  17
# Calc:  Copy(17)
#
# Harry Potter Bewitches Box Office for $<extra_id_0> M </s>
# 39
# Pred:  Harry Potter Bewitches Box Office for $79.5M</s>
# Answer:  160
# Prediction1:  79.5
# Calc:  Round(159.7,0)
#
# Parents Busted Trying to Sell Baby for $<extra_id_0>  </s>
# 40
# Pred:  Parents Busted Trying to Sell Baby for $25</s><pad>
# Answer:  25
# Prediction1:  25
# Calc:  Copy(25)
#
# <extra_id_0> -Story Skyscraper Forgets Elevator </s>
# 0
# Pred:  47-Story Skyscraper Forgets Elevator</s>
# Answer:  47
# Prediction1:  47
# Calc:  Trans(two)
#
# WWII Airman Who Crashed in '<extra_id_0>  Finally Going Home </s>
# 28
# Pred:  WWII Airman Who Crashed in '44 Finally Going Home</s>
# Answer:  44
# Prediction1:  44
# Calc:  Trans(two)
#
# Car Bomb Lesson Ends Badly, Kills <extra_id_0>  'Students' </s>
# 34
# Pred:  Car Bomb Lesson Ends Badly, Kills 21 'Students'</s>
# Answer:  21
# Prediction1:  21
# Calc:  Trans(two)
#
# <extra_id_0> -Year-Old Hacks Vine With Rickroll </s>
# 0
# Pred:  16-Year-Old Hacks Vine With Rickroll</s>
# Answer:  16
# Prediction1:  16
# Calc:  Trans(two)
#
# Mom Meets Daughter She Was Told Died <extra_id_0>  Years Ago </s>
# 37
# Pred:  Mom Meets Daughter She Was Told Died 50 Years Ago</s>
# Answer:  50
# Prediction1:  50
# Calc:  Trans(two)
#
# Death Toll Surges to <extra_id_0>  in Syria Crackdown </s>
# 21
# Pred:  Death Toll Surges to 100 in Syria Crackdown</s>
# Answer:  100
# Prediction1:  100
# Calc:  Trans(two)
#
# <extra_id_0>  Arrested for Allegedly Helping Denmark Shooter </s>
# 0
# Pred:  2 Arrested for Allegedly Helping Denmark Shooter</s>
# Answer:  2
# Prediction1:  2
# Calc:  Trans(two)
#
# No. <extra_id_0>  on Maxim's Hot 100: Manti Te'o's Fake Girlfriend </s>
# 4
# Pred:  No. 1 on Maxim's Hot 100: Manti Te'o's Fake Girlfriend</s><pad>
# Answer:  69
# Prediction1:  1
# Calc:  Trans(two)
#
# Here's the Mix Tape Kurt Cobain Made at <extra_id_0>  </s>
# 40
# Pred:  Here's the Mix Tape Kurt Cobain Made at 21</s>
# Answer:  21
# Prediction1:  21
# Calc:  Trans(two)
#
# Canada Pledges $<extra_id_0> B Aid for Automakers </s>
# 16
# Pred:  Canada Pledges $3.3B Aid for Automakers</s>
# Answer:  3.3
# Prediction1:  3.3
# Calc:  Trans(two)
#
# How We 'Know' the World Will End on May <extra_id_0>  </s>
# 40
# Pred:  How We 'Know' the World Will End on May 21</s><pad>
# Answer:  21
# Prediction1:  21
# Calc:  Trans(two)
#
# <extra_id_0>  Dead in Mall Shooting </s>
# 0
# Pred:  3 Dead in Mall Shooting</s>
# Answer:  3
# Prediction1:  3
# Calc:  Trans(two)
#
# <extra_id_0> K Homes in Danger as Calif. Wildfires Spread </s>
# 0
# Pred:  2K Homes in Danger as Calif. Wildfires Spread</s><pad>
# Answer:  2
# Prediction1:  2
# Calc:  Trans(two)
#
# Troop Crams 118 Years of Shakespeare Into <extra_id_0>  Months </s>
# 42
# Pred:  Troop Crams 118 Years of Shakespeare Into 2 Months</s>
# Answer:  2
# Prediction1:  2
# Calc:  Trans(two)
#
# Suspected Nazi Who Fled US Dead at <extra_id_0>  </s>
# 35
# Pred:  Suspected Nazi Who Fled US Dead at 92</s>
# Answer:  92
# Prediction1:  92
# Calc:  Trans(two)
#
# Led Zeppelin Drops <extra_id_0>  Unheard Tracks </s>
# 19
# Pred:  Led Zeppelin Drops 2 Unheard Tracks</s>
# Answer:  2
# Prediction1:  2
# Calc:  Trans(two)
#
# <extra_id_0>  Arrested in Seattle Protests </s>
# 0
# Pred:  18 Arrested in Seattle Protests</s>
# Answer:  18
# Prediction1:  18
# Calc:  Trans(two)
#
# Son, <extra_id_0> , Made Bad Mistake in Shooting: Dad </s>
# 5
# Pred:  Son, 9, Made Bad Mistake in Shooting: Dad</s><pad>
# Answer:  9
# Prediction1:  9
# Calc:  Trans(two)
#
# Mine That Bird Pulls Off 50-<extra_id_0>  Derby Shocker </s>
# 28
# Pred:  Mine That Bird Pulls Off 50-1 Derby Shocker</s><pad>
# Answer:  1
# Prediction1:  1
# Calc:  Trans(two)
#
# <extra_id_0> % of Young Americans Are Some Degree of Bisexual </s>
# 0
# Pred:  33% of Young Americans Are Some Degree of Bisexual</s>
# Answer:  29
# Prediction1:  33
# Calc:  Copy(29)
#
# <extra_id_0>  Charged With Stealing From Firefighters Battling Calif. Blaze </s>
# 0
# Pred:  2 Charged With Stealing From Firefighters Battling Calif. Blaze</s>
# Answer:  2
# Prediction1:  2
# Calc:  Trans(two)
#
# <extra_id_0>  Shot, 1 Killed at NYC Rap Concert </s>
# 0
# Pred:  3 Shot, 1 Killed at NYC Rap Concert</s>
# Answer:  4
# Prediction1:  3
# Calc:  Add(Trans(one),Trans(three))
#
# Feds Catching <extra_id_0> % More Health Care Fraudsters </s>
# 14
# Pred:  Feds Catching 24% More Health Care Fraudsters</s>
# Answer:  85
# Prediction1:  24
# Calc:  Copy(85)
#
# $100 Bill Goes <extra_id_0> D </s>
# 15
# Pred:  $100 Bill Goes 3D</s>
# Answer:  3
# Prediction1:  3
# Calc:  Copy(3)
#
# Tennessee Declares End to <extra_id_0>  Coal Creek War </s>
# 26
# Pred:  Tennessee Declares End to 121 Coal Creek War</s>
# Answer:  1892
# Prediction1:  121
# Calc:  Subtract(2013,121)
#
# 'Virtual Mars' Crew Locked in 'Spaceship' for <extra_id_0>  Months </s>
# 46
# Pred:  'Virtual Mars' Crew Locked in 'Spaceship' for 3 Months</s>
# Answer:  17
# Prediction1:  3
# Calc:  Round(Divide(520,30),0)
#
# Court: Man in Solitary Since 1972 Can Be Tried <extra_id_0> rd Time </s>
# 47
# Pred:  Court: Man in Solitary Since 1972 Can Be Tried 3rd Time</s>
# Answer:  3
# Prediction1:  3
# Calc:  Trans(third)
#
# Franken, Coleman Fight Over $<extra_id_0> K in Legal Fees </s>
# 29
# Pred:  Franken, Coleman Fight Over $94K in Legal Fees</s>
# Answer:  94
# Prediction1:  94
# Calc:  Paraphrase(94,000,K)
#
# <extra_id_0>  Burned in Fiery Dessert Disaster </s>
# 0
# Pred:  4 Burned in Fiery Dessert Disaster</s>
# Answer:  4
# Prediction1:  4
# Calc:  Add(2,2)
#
# Dow Ends Big Week Up <extra_id_0>  </s>
# 21
# Pred:  Dow Ends Big Week Up 12</s><pad>
# Answer:  13
# Prediction1:  12
# Calc:  Copy(13)
#
# Aggressive Obama Edges <extra_id_0> nd Debate </s>
# 23
# Pred:  Aggressive Obama Edges 2nd Debate</s>
# Answer:  2
# Prediction1:  2
# Calc:  Copy(2)
#
# Hidden Camera Captures Abuse of Calves at E<extra_id_0>  Cattle Company in Hart, Texas </s>
# 43
# Pred:  Hidden Camera Captures Abuse of Calves at E6 Cattle Company in Hart, Texas</s>
# Answer:  6
# Prediction1:  6
# Calc:  Copy(6)
#
# Ex-Cop's Fundraiser for Freddie Gray <extra_id_0> : Blackface </s>
# 37
# Pred:  Ex-Cop's Fundraiser for Freddie Gray 6: Blackface</s><pad>
# Answer:  6
# Prediction1:  6
# Calc:  Trans(six)
#
# Boy-Band Brain Gets <extra_id_0>  Years for Fraud </s>
# 20
# Pred:  Boy-Band Brain Gets 25 Years for Fraud</s>
# Answer:  25
# Prediction1:  25
# Calc:  Copy(25)
#
# Cartel Henchman Gets <extra_id_0>  Years for Drug-Smuggling Scheme </s>
# 21
# Pred:  Cartel Henchman Gets 22 Years for Drug-Smuggling Scheme</s>
# Answer:  22
# Prediction1:  22
# Calc:  Copy(22)
#
# <extra_id_0>  Injured in Denver Plane Accident Out of Hospital </s>
# 0
# Pred:  38 Injured in Denver Plane Accident Out of Hospital</s><pad>
# Answer:  2
# Prediction1:  38
# Calc:  Trans(Two)
#
# So How Far Could bin Laden Have Gotten on <extra_id_0>  Euros? </s>
# 42
# Pred:  So How Far Could bin Laden Have Gotten on 500 Euros?</s>
# Answer:  500
# Prediction1:  500
# Calc:  Copy(500)
#
# More Than <extra_id_0>  Men Sought in Gang Rape of Teen Girl </s>
# 10
# Pred:  More Than 30 Men Sought in Gang Rape of Teen Girl</s>
# Answer:  30
# Prediction1:  30
# Calc:  Copy(30)
#
# '<extra_id_0>  Days of Christmas' Gifts Will Cost You $97K </s>
# 1
# Pred:  '10 Days of Christmas' Gifts Will Cost You $97K</s>
# Answer:  12
# Prediction1:  10
# Calc:  Copy(12)
#
# <extra_id_0>  Injured by Turbulence on Flight From Rio </s>
# 0
# Pred:  4 Injured by Turbulence on Flight From Rio</s>
# Answer:  26
# Prediction1:  4
# Calc:  Add(22,Trans(four))
#
# Aussie Aerial Shoot Could Cull <extra_id_0> M Camels </s>
# 31
# Pred:  Aussie Aerial Shoot Could Cull 1M Camels</s><pad>
# Answer:  1
# Prediction1:  1
# Calc:  Copy(1)
#
# Romney's Cash Edge: $<extra_id_0> M </s>
# 21
# Pred:  Romney's Cash Edge: $91M</s>
# Answer:  62
# Prediction1:  91
# Calc:  Subtract(186,124)
#
# Coke Bids $<extra_id_0> B for Chinese Juice Company </s>
# 11
# Pred:  Coke Bids $2.4B for Chinese Juice Company</s>
# Answer:  2.4
# Prediction1:  2.4
# Calc:  Copy(2.4)
#
# Stimulus Gave $<extra_id_0> M to Faith-Based Groups </s>
# 15
# Pred:  Stimulus Gave $140M to Faith-Based Groups</s>
# Answer:  140
# Prediction1:  140
# Calc:  Copy(140)
#
# Google Maps Reunites Boy With Family, <extra_id_0>  Years Later </s>
# 38
# Pred:  Google Maps Reunites Boy With Family, 23 Years Later</s>
# Answer:  23
# Prediction1:  23
# Calc:  Copy(23)
#
# <extra_id_0> K Feared Dead in Turkey Quake </s>
# 0
# Pred:  1K Feared Dead in Turkey Quake</s><pad>
# Answer:  1
# Prediction1:  1
# Calc:  Paraphrase(1,000,K)
#
# <extra_id_0> K-Year-Old Bone Spills Beans on Human-Neanderthal Sex </s>
# 0
# Pred:  45K-Year-Old Bone Spills Beans on Human-Neanderthal Sex</s>
# Answer:  45
# Prediction1:  45
# Calc:  Paraphrase(45,000,K)
#
# US Missionary Kidnapped in Nigeria; $<extra_id_0> K Demanded </s>
# 37
# Pred:  US Missionary Kidnapped in Nigeria; $300K Demanded</s><pad>
# Answer:  300
# Prediction1:  300
# Calc:  Paraphrase(300,000,K)
#
# Only One of <extra_id_0>  9/11 Search Dogs Is Left </s>
# 12
# Pred:  Only One of 100 9/11 Search Dogs Is Left</s>
# Answer:  100
# Prediction1:  100
# Calc:  Copy(100)
#
# After 74 People Overdose, Chicago Cops Arrest <extra_id_0>  </s>
# 46
# Pred:  After 74 People Overdose, Chicago Cops Arrest 2</s>
# Answer:  2
# Prediction1:  2
# Calc:  Trans(two)
#
# Calif. Boy, <extra_id_0> , Tackles Everest </s>
# 12
# Pred:  Calif. Boy, 13, Tackles Everest</s><pad>
# Answer:  13
# Prediction1:  13
# Calc:  Copy(13)
#
# Economy Grew at <extra_id_0> % Rate in Q4 </s>
# 16
# Pred:  Economy Grew at 3.2% Rate in Q4</s>
# Answer:  3.2
# Prediction1:  3.2
# Calc:  Copy(3.2)
#
# 'Affluenza' Mom Off Hook for $<extra_id_0> K Extradition Tab </s>
# 30
# Pred:  'Affluenza' Mom Off Hook for $3K Extradition Tab</s><pad>
# Answer:  3
# Prediction1:  3
# Calc:  Round(Paraphrase(3,175,K),0)
#
# Father of Cryonics Robert Ettinger Dead at <extra_id_0>  </s>
# 43
# Pred:  Father of Cryonics Robert Ettinger Dead at 92</s>
# Answer:  92
# Prediction1:  92
# Calc:  Copy(92)
#
# Fort Hood Rampage Lasted <extra_id_0>  Minutes </s>
# 25
# Pred:  Fort Hood Rampage Lasted 8 Minutes</s>
# Answer:  8
# Prediction1:  8
# Calc:  Copy(8)
#
# Merrill to Slash Bonuses <extra_id_0> % </s>
# 25
# Pred:  Merrill to Slash Bonuses 50%</s><pad>
# Answer:  50
# Prediction1:  50
# Calc:  Copy(50)
#
# Air Jordan Turns <extra_id_0>  </s>
# 17
# Pred:  Air Jordan Turns 23</s>
# Answer:  23
# Prediction1:  23
# Calc:  Copy(23)
#
# Iran Blockade Could Send Oil Up <extra_id_0> % </s>
# 32
# Pred:  Iran Blockade Could Send Oil Up 50%</s><pad>
# Answer:  50
# Prediction1:  50
# Calc:  Copy(50)
#
# Insider Shooting Kills <extra_id_0>  US Troops </s>
# 23
# Pred:  Insider Shooting Kills 2 US Troops</s>
# Answer:  2
# Prediction1:  2
# Calc:  Trans(two)
#
# One in <extra_id_0>  US Kids Is Homeless </s>
# 7
# Pred:  One in 30 US Kids Is Homeless</s>
# Answer:  30
# Prediction1:  30
# Calc:  Copy(30)
#
# 2 Candidates, <extra_id_0>  Americas: Old Values vs. New </s>
# 14
# Pred:  2 Candidates, 2 Americas: Old Values vs. New</s>
# Answer:  2
# Prediction1:  2
# Calc:  Add(Span(Old America),Span(New America))
#
# <extra_id_0> -Year-Old Hit With $6.3M Bill for Sparking Forest Fire </s>
# 0
# Pred:  77-Year-Old Hit With $6.3M Bill for Sparking Forest Fire</s>
# Answer:  77
# Prediction1:  77
# Calc:  Copy(77)
#
# Google, Facebook Eye Twitter, Price Tag: $<extra_id_0> B </s>
# 42
# Pred:  Google, Facebook Eye Twitter, Price Tag: $8B</s>
# Answer:  10
# Prediction1:  8
# Calc:  Copy(10)
#
# Madoff's Wife Withdrew $<extra_id_0> M Days Before Arrest </s>
# 24
# Pred:  Madoff's Wife Withdrew $10M Days Before Arrest</s>
# Answer:  15.5
# Prediction1:  10
# Calc:  Add(10,5.5)
#
# <extra_id_0>  Busted in Libya Attack, 3rd Victim Named </s>
# 0
# Pred:  4 Busted in Libya Attack, 3rd Victim Named</s>
# Answer:  4
# Prediction1:  4
# Calc:  Trans(four)
#
# Romney Still Worth $<extra_id_0> M </s>
# 20
# Pred:  Romney Still Worth $250M</s><pad>
# Answer:  250
# Prediction1:  250
# Calc:  Copy(250)
#
# Maya Angelou Dead at <extra_id_0>  </s>
# 21
# Pred:  Maya Angelou Dead at 86</s>
# Answer:  86
# Prediction1:  86
# Calc:  Copy(86)
#
# How to Live to <extra_id_0> : Learn to Bounce Back </s>
# 15
# Pred:  How to Live to 109: Learn to Bounce Back</s>
# Answer:  100
# Prediction1:  109
# Calc:  Subtract(109,9)
#
# World's No. <extra_id_0>  Crack Market: Brazil </s>
# 12
# Pred:  World's No. 1 Crack Market: Brazil</s>
# Answer:  1
# Prediction1:  1
# Calc:  Copy(1)
#
# <extra_id_0>  Celebrity Friend 'Breakups' </s>
# 0
# Pred:  11 Celebrity Friend 'Breakups'</s>
# Answer:  11
# Prediction1:  11
# Calc:  Copy(11)
#
# Crystal Unleashes  Harry Met Sally <extra_id_0>  </s>
# 35
# Pred:  Crystal Unleashes Harry Met Sally 2</s><pad>
# Answer:  2
# Prediction1:  2
# Calc:  Trans(two)
#
# Iraq Cancels $<extra_id_0> B Arms Deal With Russia </s>
# 14
# Pred:  Iraq Cancels $4.2B Arms Deal With Russia</s>
# Answer:  4.2
# Prediction1:  4.2
# Calc:  Copy(4.2)
#
# Sister Wives Hubby 'Marries' Wife No. <extra_id_0>  </s>
# 38
# Pred:  Sister Wives Hubby 'Marries' Wife No. 4</s>
# Answer:  4
# Prediction1:  4
# Calc:  Trans(fourth)
#
# Bob Geldof to <extra_id_0>  Syrian Families: Come Stay in My Homes </s>
# 14
# Pred:  Bob Geldof to 4 Syrian Families: Come Stay in My Homes</s>
# Answer:  4
# Prediction1:  4
# Calc:  Copy(4)
#
# <extra_id_0> nd Test Finds Faster-Than-Light Particles </s>
# 0
# Pred:  2nd Test Finds Faster-Than-Light Particles</s><pad>
# Answer:  2
# Prediction1:  2
# Calc:  Trans(second)
#
# Ford: We'll Add <extra_id_0> K Jobs Over 3 Years </s>
# 16
# Pred:  Ford: We'll Add 12K Jobs Over 3 Years</s>
# Answer:  12
# Prediction1:  12
# Calc:  Paraphrase(12,000,K)
#
# Whole Foods Hawks $<extra_id_0>  'Asparagus Water,' Quickly Backs Off </s>
# 19
# Pred:  Whole Foods Hawks $5 'Asparagus Water,' Quickly Backs Off</s><pad>
# Answer:  6
# Prediction1:  5
# Calc:  Copy(6)
#
# Labradoodle Falls From <extra_id_0> -Foot Cliff, Lives </s>
# 23
# Pred:  Labradoodle Falls From 200-Foot Cliff, Lives</s>
# Answer:  200
# Prediction1:  200
# Calc:  Copy(200)
#
# South Africa Prez Marries <extra_id_0> rd Wife Today </s>
# 26
# Pred:  South Africa Prez Marries 3rd Wife Today</s>
# Answer:  3
# Prediction1:  3
# Calc:  Trans(third)
#
# Larry King Moderating <extra_id_0> rd-Party Debate </s>
# 22
# Pred:  Larry King Moderating 3rd-Party Debate</s>
# Answer:  3
# Prediction1:  3
# Calc:  Trans(third)
#
# In <extra_id_0> st, Majority of Americans Say Keep Abortion Legal </s>
# 3
# Pred:  In 1st, Majority of Americans Say Keep Abortion Legal</s><pad>
# Answer:  1
# Prediction1:  1
# Calc:  Trans(first)
#
# Doctors Separate Twins in <extra_id_0> -Hour Surgery </s>
# 26
# Pred:  Doctors Separate Twins in 18-Hour Surgery</s>
# Answer:  18
# Prediction1:  18
# Calc:  Copy(18)
#
# <extra_id_0> % Say America Is Broken </s>
# 0
# Pred:  86% Say America Is Broken</s>
# Answer:  86
# Prediction1:  86
# Calc:  Copy(86)
#
# Crack Team of Scientists' Goal: 'Make <extra_id_0>  the New 60' </s>
# 38
# Pred:  Crack Team of Scientists' Goal: 'Make 100 the New 60'</s><pad>
# Answer:  100
# Prediction1:  100
# Calc:  Copy(100)
#
# New No. <extra_id_0>  US Chain: Starbucks </s>
# 8
# Pred:  New No. 3 US Chain: Starbucks</s>
# Answer:  3
# Prediction1:  3
# Calc:  Copy(3)
#
# Hingis Nets <extra_id_0> -Year Ban for Coke </s>
# 12
# Pred:  Hingis Nets 2-Year Ban for Coke</s><pad>
# Answer:  2
# Prediction1:  2
# Calc:  Copy(2)
#
# End Malaria Deaths by <extra_id_0> : UN </s>
# 22
# Pred:  End Malaria Deaths by 2010: UN</s>
# Answer:  2010
# Prediction1:  2010
# Calc:  Copy(2010)
#
# Renegade US Group Wanted to Help Gadhafi—for $<extra_id_0> M </s>
# 46
# Pred:  Renegade US Group Wanted to Help Gadhafi—for $10M</s>
# Answer:  10
# Prediction1:  10
# Calc:  Copy(10)
#
# <extra_id_0>  Farmworkers Beheaded in Guatemala </s>
# 0
# Pred:  200 Farmworkers Beheaded in Guatemala</s>
# Answer:  27
# Prediction1:  200
# Calc:  Add(25,Trans(two))
#
# Jon Stewart Adopts Pony Hit With <extra_id_0>  Paintballs </s>
# 33
# Pred:  Jon Stewart Adopts Pony Hit With 125 Paintballs</s>
# Answer:  125
# Prediction1:  125
# Calc:  Copy(125)
#
# Missing: <extra_id_0> -Year-Old; 20 Inches Long, Big Nose </s>
# 9
# Pred:  Missing: 5-Year-Old; 20 Inches Long, Big Nose</s><pad>
# Answer:  5
# Prediction1:  5
# Calc:  Copy(5)
#
# Facebook: Defining Religion in <extra_id_0>  Characters </s>
# 31
# Pred:  Facebook: Defining Religion in 100 Characters</s>
# Answer:  100
# Prediction1:  100
# Calc:  Copy(100)
#
# China Quarantines <extra_id_0>  Yanks </s>
# 18
# Pred:  China Quarantines 2 Yanks</s><pad>
# Answer:  2
# Prediction1:  2
# Calc:  Trans(Two)
#
# Dow Ends Day Up <extra_id_0>  </s>
# 16
# Pred:  Dow Ends Day Up 22</s>
# Answer:  22
# Prediction1:  22
# Calc:  Copy(22)
#
# Court: Man in Solitary Since <extra_id_0>  Can Be Tried 3rd Time </s>
# 29
# Pred:  Court: Man in Solitary Since 1972 Can Be Tried 3rd Time</s>
# Answer:  1972
# Prediction1:  1972
# Calc:  Copy(1972)
#
# Fed Launches $<extra_id_0> B Programs to Unlock Lending </s>
# 14
# Pred:  Fed Launches $200B Programs to Unlock Lending</s>
# Answer:  800
# Prediction1:  200
# Calc:  Add(200,600)
#
# 'Terrifying' Glass Slide Hangs <extra_id_0> K Feet Above LA </s>
# 31
# Pred:  'Terrifying' Glass Slide Hangs 1K Feet Above LA</s><pad>
# Answer:  1
# Prediction1:  1
# Calc:  Paraphrase(1,000,K)
#
# American Was Among <extra_id_0>  Climbers Slain By Taliban </s>
# 19
# Pred:  American Was Among 10 Climbers Slain By Taliban</s>
# Answer:  10
# Prediction1:  10
# Calc:  Copy(10)
#
# Boehner Forgives <extra_id_0>  GOP Defectors </s>
# 17
# Pred:  Boehner Forgives 12 GOP Defectors</s>
# Answer:  12
# Prediction1:  12
# Calc:  Copy(12)
#
# Couple Marry in <extra_id_0> -Year-Old Son's Hospital Room </s>
# 16
# Pred:  Couple Marry in 4-Year-Old Son's Hospital Room</s><pad>
# Answer:  4
# Prediction1:  4
# Calc:  Copy(4)
#
# Geithner Questioned Libor's Credibility in <extra_id_0>  </s>
# 43
# Pred:  Geithner Questioned Libor's Credibility in 2008</s>
# Answer:  2008
# Prediction1:  2008
# Calc:  Copy(2008)
#
# No. 69 on Maxim's Hot <extra_id_0> : Manti Te'o's Fake Girlfriend </s>
# 22
# Pred:  No. 69 on Maxim's Hot 100: Manti Te'o's Fake Girlfriend</s>
# Answer:  100
# Prediction1:  100
# Calc:  Copy(100)
#
# 2 Brothers Held in Fatal Shooting of <extra_id_0>  Miss. Cops </s>
# 37
# Pred:  2 Brothers Held in Fatal Shooting of 2 Miss. Cops</s>
# Answer:  2
# Prediction1:  2
# Calc:  Trans(Two)
#
# Japanese Man, <extra_id_0> , Survived Both A-Bombs </s>
# 14
# Pred:  Japanese Man, 93, Survived Both A-Bombs</s>
# Answer:  93
# Prediction1:  93
# Calc:  Copy(93)
#
# Woman's Kidney Infection Actually a <extra_id_0> -Pound Baby </s>
# 36
# Pred:  Woman's Kidney Infection Actually a 6-Pound Baby</s><pad>
# Answer:  6
# Prediction1:  6
# Calc:  Copy(6)
#
# Indonesia to <extra_id_0>  Foreigners: State Your Last Wish </s>
# 13
# Pred:  Indonesia to 9 Foreigners: State Your Last Wish</s>
# Answer:  9
# Prediction1:  9
# Calc:  Trans(nine)
#
# Jasper Johns' Flag Sells for $<extra_id_0> M </s>
# 30
# Pred:  Jasper Johns' Flag Sells for $28.6M</s>
# Answer:  28.6
# Prediction1:  28.6
# Calc:  Copy(28.6)
#
# Nyad, <extra_id_0> , Attempts Marathon Swim Again </s>
# 6
# Pred:  Nyad, 62, Attempts Marathon Swim Again</s>
# Answer:  62
# Prediction1:  62
# Calc:  Copy(62)
#
# Tobacco Giants Ordered to Cough Up $<extra_id_0> B </s>
# 36
# Pred:  Tobacco Giants Ordered to Cough Up $12B</s>
# Answer:  12
# Prediction1:  12
# Calc:  Copy(12)
#
# Firm Plans to Build World's Tallest Building ... in <extra_id_0>  Days </s>
# 52
# Pred:  Firm Plans to Build World's Tallest Building ... in 90 Days</s><pad>
# Answer:  90
# Prediction1:  90
# Calc:  Copy(90)
#
# Want to Ask Paul Ryan a Question? Please Pay $<extra_id_0>  </s>
# 46
# Pred:  Want to Ask Paul Ryan a Question? Please Pay $15</s><pad>
# Answer:  15
# Prediction1:  15
# Calc:  Copy(15)
#
# Gas Prices Plummet Below $<extra_id_0>  </s>
# 26
# Pred:  Gas Prices Plummet Below $50</s>
# Answer:  2
# Prediction1:  50
# Calc:  Copy(2)
#
# Paul Walker's Daughter Gets $<extra_id_0> M From Porsche Driver </s>
# 29
# Pred:  Paul Walker's Daughter Gets $10.1M From Porsche Driver</s>
# Answer:  10.1
# Prediction1:  10.1
# Calc:  Copy(10.1)
#
# WWE Star Chyna Dies at <extra_id_0>  </s>
# 23
# Pred:  WWE Star Chyna Dies at 45</s>
# Answer:  45
# Prediction1:  45
# Calc:  Copy(45)
#
# Manhunt for Fugitive Frein Cost $<extra_id_0> M </s>
# 33
# Pred:  Manhunt for Fugitive Frein Cost $11M</s>
# Answer:  11
# Prediction1:  11
# Calc:  Copy(11)
#
# More Than <extra_id_0>  Dozen Killed in Mexican Drug Violence </s>
# 10
# Pred:  More Than 2 Dozen Killed in Mexican Drug Violence</s><pad>
# Answer:  2
# Prediction1:  2
# Calc:  Copy(2)
#
# Applause as $<extra_id_0> M Bond Set for Cop Charged With Murder </s>
# 13
# Pred:  Applause as $1M Bond Set for Cop Charged With Murder</s><pad>
# Answer:  1
# Prediction1:  1
# Calc:  Copy(1)
#
# Woman Spends $<extra_id_0> K to Look Like Jessica Rabbit </s>
# 14
# Pred:  Woman Spends $16K to Look Like Jessica Rabbit</s>
# Answer:  16
# Prediction1:  16
# Calc:  Paraphrase(16,000,K)
#
# FEMA Dragging Heels on Recouping $<extra_id_0> M </s>
# 34
# Pred:  FEMA Dragging Heels on Recouping $643M</s>
# Answer:  643
# Prediction1:  643
# Calc:  Copy(643)
#
# Blackhawks Win Opener, 4-<extra_id_0> , in Triple Overtime </s>
# 25
# Pred:  Blackhawks Win Opener, 4-3, in Triple Overtime</s>
# Answer:  3
# Prediction1:  3
# Calc:  Copy(3)
#
# <extra_id_0>  Injured When Greyhound Bus Flips </s>
# 0
# Pred:  52 Injured When Greyhound Bus Flips</s>
# Answer:  34
# Prediction1:  52
# Calc:  Copy(34)
#
# <extra_id_0>  GOP Ideas for Health Care Reform </s>
# 0
# Pred:  10 GOP Ideas for Health Care Reform</s>
# Answer:  10
# Prediction1:  10
# Calc:  Copy(10)
#
# 'Intentional' Gas Leak Sickens <extra_id_0>  at FurFest </s>
# 31
# Pred:  'Intentional' Gas Leak Sickens 19 at FurFest</s>
# Answer:  19
# Prediction1:  19
# Calc:  Trans(Nineteen)
#
# <extra_id_0>  Teens Arrested for Raping Toddler in India's Capital </s>
# 0
# Pred:  2 Teens Arrested for Raping Toddler in India's Capital</s>
# Answer:  2
# Prediction1:  2
# Calc:  Copy(2)
#
# Gisele: Tom's Son Feels <extra_id_0> % Like My Own </s>
# 24
# Pred:  Gisele: Tom's Son Feels 100% Like My Own</s><pad>
# Answer:  100
# Prediction1:  100
# Calc:  Copy(100)
#
# Lehman to Lay Off Another <extra_id_0>  </s>
# 26
# Pred:  Lehman to Lay Off Another 1,500</s>
# Answer:  1,500
# Prediction1:  1
# Calc:  Copy(1,500)
#
# 2 Dead, <extra_id_0>  Hurt in Va. Tornado </s>
# 8
# Pred:  2 Dead, 20 Hurt in Va. Tornado</s>
# Answer:  20
# Prediction1:  20
# Calc:  Copy(20)
#
# Tunisian Police Kill <extra_id_0> , Injure 17 </s>
# 21
# Pred:  Tunisian Police Kill 2, Injure 17</s>
# Answer:  2
# Prediction1:  2
# Calc:  Trans(Two)
#
# Burglars Pocket-Dial <extra_id_0> , Get Busted </s>
# 21
# Pred:  Burglars Pocket-Dial 911, Get Busted</s><pad>
# Answer:  911
# Prediction1:  911
# Calc:  Copy(911)
#
# Long-Lost Army Buddies: Neighbors for <extra_id_0>  Years </s>
# 38
# Pred:  Long-Lost Army Buddies: Neighbors for 18 Years</s><pad>
# Answer:  18
# Prediction1:  18
# Calc:  Copy(18)
#
# Want to Try This <extra_id_0> -Year-Old Chef's Food? That'll Be $160 </s>
# 17
# Pred:  Want to Try This 16-Year-Old Chef's Food? That'll Be $160</s>
# Answer:  16
# Prediction1:  16
# Calc:  Copy(16)
#
# Peterson Offers $<extra_id_0> K Reward for Wife's Return </s>
# 17
# Pred:  Peterson Offers $25K Reward for Wife's Return</s><pad>
# Answer:  25
# Prediction1:  25
# Calc:  Paraphrase(25,000,K)
#
# B&N E-Reader Sports <extra_id_0>  Screens: E-Ink and LCD </s>
# 20
# Pred:  B&N E-Reader Sports 2 Screens: E-Ink and LCD</s>
# Answer:  2
# Prediction1:  2
# Calc:  Trans(two)
#
# Record <extra_id_0> % of Women Have a Gun in Home </s>
# 7
# Pred:  Record 43% of Women Have a Gun in Home</s>
# Answer:  43
# Prediction1:  43
# Calc:  Copy(43)
#
# Honda Recalls <extra_id_0> K Vehicles </s>
# 14
# Pred:  Honda Recalls 384K Vehicles</s>
# Answer:  384
# Prediction1:  384
# Calc:  Paraphrase(384,000,K)
#
# Spain Busts <extra_id_0>  Islamic Militants in Terror Plot </s>
# 12
# Pred:  Spain Busts 14 Islamic Militants in Terror Plot</s>
# Answer:  14
# Prediction1:  14
# Calc:  Copy(14)
#
# <extra_id_0>  Siblings Orphaned After Parents Die Days Apart </s>
# 0
# Pred:  4 Siblings Orphaned After Parents Die Days Apart</s>
# Answer:  4
# Prediction1:  4
# Calc:  Copy(4)
#
# Preacher's Spanking Book Linked to <extra_id_0>  Child Deaths </s>
# 35
# Pred:  Preacher's Spanking Book Linked to 3 Child Deaths</s>
# Answer:  3
# Prediction1:  3
# Calc:  Trans(three)
#
# Bush Unveils Record-Busting $<extra_id_0> T Budget </s>
# 29
# Pred:  Bush Unveils Record-Busting $3.1T Budget</s>
# Answer:  3
# Prediction1:  3.1
# Calc:  Copy(3)
#
# Woman Gets $<extra_id_0> K Over Endless Cable Robocalls </s>
# 12
# Pred:  Woman Gets $229K Over Endless Cable Robocalls</s>
# Answer:  230
# Prediction1:  229
# Calc:  Round(Paraphrase(229,500,k),0)
#
# Ford: We'll Add 12K Jobs Over <extra_id_0>  Years </s>
# 30
# Pred:  Ford: We'll Add 12K Jobs Over 3 Years</s>
# Answer:  3
# Prediction1:  3
# Calc:  Trans(three)
#
# Man May Have Paid $<extra_id_0> K to Kill Africa's Most Famous Lion </s>
# 19
# Pred:  Man May Have Paid $55K to Kill Africa's Most Famous Lion</s>
# Answer:  55
# Prediction1:  55
# Calc:  Paraphrase(55,000,K)
#
# Vet Stands on Bridge <extra_id_0>  Hours to Honor Victims in Tennessee </s>
# 21
# Pred:  Vet Stands on Bridge 4 Hours to Honor Victims in Tennessee</s><pad>
# Answer:  4
# Prediction1:  4
# Calc:  Trans(four)
#
# Man Willing to Lose Job Over <extra_id_0> -Minute Diversity Video </s>
# 29
# Pred:  Man Willing to Lose Job Over 17-Minute Diversity Video</s>
# Answer:  17
# Prediction1:  17
# Calc:  Copy(17)
#
# Romney to Say If He's Running at <extra_id_0> am </s>
# 33
# Pred:  Romney to Say If He's Running at 11am</s>
# Answer:  11
# Prediction1:  11
# Calc:  Copy(11)
#
# <extra_id_0> nd Known Photo of Emily Dickinson Surfaces </s>
# 0
# Pred:  2nd Known Photo of Emily Dickinson Surfaces</s><pad>
# Answer:  2
# Prediction1:  2
# Calc:  Trans(second)
#
# Berlusconi Sex Trial Adjourned After <extra_id_0>  Minutes </s>
# 37
# Pred:  Berlusconi Sex Trial Adjourned After 7 Minutes</s>
# Answer:  7
# Prediction1:  7
# Calc:  Trans(seven)
#
# Cops: Man Tried Exorcism on Girlfriend, <extra_id_0>  </s>
# 40
# Pred:  Cops: Man Tried Exorcism on Girlfriend, 80</s><pad>
# Answer:  80
# Prediction1:  80
# Calc:  Copy(80)
#
# Commercial Real Estate May Set Off <extra_id_0> nd Crisis </s>
# 35
# Pred:  Commercial Real Estate May Set Off 2nd Crisis</s><pad>
# Answer:  2
# Prediction1:  2
# Calc:  Trans(second)
#
# Adopted at <extra_id_0> , She Had Found Her Way Home </s>
# 11
# Pred:  Adopted at 17, She Had Found Her Way Home</s><pad>
# Answer:  17
# Prediction1:  17
# Calc:  Copy(17)
#
# Phillies Grab 3-<extra_id_0>  Lead on 9th-Inning Rally </s>
# 16
# Pred:  Phillies Grab 3-1 Lead on 9th-Inning Rally</s><pad>
# Answer:  1
# Prediction1:  1
# Calc:  Copy(1)
#
# Utah Truck Crash Frees <extra_id_0> M Bees </s>
# 23
# Pred:  Utah Truck Crash Frees 25M Bees</s>
# Answer:  25
# Prediction1:  25
# Calc:  Copy(25)
#
# Angels Win in <extra_id_0> , Trim Yankees' Lead </s>
# 14
# Pred:  Angels Win in 2, Trim Yankees' Lead</s>
# Answer:  11
# Prediction1:  2
# Calc:  Copy(11)
#
# Did Peeing Swimmers Kill <extra_id_0>  Fish? </s>
# 25
# Pred:  Did Peeing Swimmers Kill 500 Fish?</s>
# Answer:  500
# Prediction1:  500
# Calc:  Copy(500)
#
# UK Elects Youngest Lawmaker Since <extra_id_0>  </s>
# 34
# Pred:  UK Elects Youngest Lawmaker Since 1667</s>
# Answer:  1667
# Prediction1:  1667
# Calc:  Copy(1667)
#
# Dow Ends Day Up <extra_id_0>  </s>
# 16
# Pred:  Dow Ends Day Up 185</s>
# Answer:  185
# Prediction1:  185
# Calc:  Copy(185)
#
# Judge Slaps Teen With 1- to <extra_id_0> -Year Sentence </s>
# 28
# Pred:  Judge Slaps Teen With 1- to 15-Year Sentence</s><pad>
# Answer:  15
# Prediction1:  15
# Calc:  Copy(15)
#
# Economy Grows in Q<extra_id_0> , Signals End of Recession </s>
# 18
# Pred:  Economy Grows in Q3, Signals End of Recession</s>
# Answer:  3
# Prediction1:  3
# Calc:  Trans(third)
#
# Balloon Pilot in Deadly Crash Had <extra_id_0>  DWI Convictions </s>
# 34
# Pred:  Balloon Pilot in Deadly Crash Had 4 DWI Convictions</s>
# Answer:  4
# Prediction1:  4
# Calc:  Trans(four)
#
# Calif. Supreme Court Hears Prop <extra_id_0>  Arguments </s>
# 32
# Pred:  Calif. Supreme Court Hears Prop 8 Arguments</s>
# Answer:  8
# Prediction1:  8
# Calc:  Copy(8)
#
# Madoff Had $<extra_id_0> M in Checks for Friends, Relatives: Feds </s>
# 12
# Pred:  Madoff Had $173M in Checks for Friends, Relatives: Feds</s>
# Answer:  173
# Prediction1:  173
# Calc:  Copy(173)
#
# Evicted California <extra_id_0> -Year-Old Gets a New Home </s>
# 19
# Pred:  Evicted California 100-Year-Old Gets a New Home</s>
# Answer:  100
# Prediction1:  100
# Calc:  Copy(100)
#
# Poachers Use Cyanide to Kill <extra_id_0>  Elephants </s>
# 29
# Pred:  Poachers Use Cyanide to Kill 5 Elephants</s><pad>
# Answer:  5
# Prediction1:  5
# Calc:  Trans(five)
#
# ATF Lost $<extra_id_0> M in Cigs in Unapproved Stings </s>
# 10
# Pred:  ATF Lost $162M in Cigs in Unapproved Stings</s>
# Answer:  127
# Prediction1:  162
# Calc:  Copy(127)
#
# Navy: Java Sea Wreck Is Grave of <extra_id_0>  </s>
# 33
# Pred:  Navy: Java Sea Wreck Is Grave of 700</s>
# Answer:  700
# Prediction1:  700
# Calc:  Copy(700)
#
# Facebook Co-Founder Aims to Dump Trump With $<extra_id_0> M Donation </s>
# 45
# Pred:  Facebook Co-Founder Aims to Dump Trump With $1M Donation</s><pad>
# Answer:  20
# Prediction1:  1
# Calc:  Copy(20)
#
# 2 Officers Killed, <extra_id_0>  Wounded in Calif. Domestic Dispute </s>
# 19
# Pred:  2 Officers Killed, 1 Wounded in Calif. Domestic Dispute</s>
# Answer:  1
# Prediction1:  1
# Calc:  Span(wounding another in Palm Springs)
#
# Baby's Delivery First of Its Kind in US Since <extra_id_0>  </s>
# 46
# Pred:  Baby's Delivery First of Its Kind in US Since 1999</s>
# Answer:  1999
# Prediction1:  1999
# Calc:  Copy(1999)
#
# Paula Deen Making $<extra_id_0> M Comeback </s>
# 19
# Pred:  Paula Deen Making $75M Comeback</s><pad>
# Answer:  75
# Prediction1:  75
# Calc:  Copy(75)
#
# Dance Legend Pina Bausch Dead at <extra_id_0>  </s>
# 33
# Pred:  Dance Legend Pina Bausch Dead at 68</s>
# Answer:  68
# Prediction1:  68
# Calc:  Copy(68)
#
# <extra_id_0>  Flee Raging SoCal Wildfire </s>
# 0
# Pred:  1,000 Flee Raging SoCal Wildfire</s><pad>
# Answer:  1,000
# Prediction1:  1
# Calc:  Copy(1,000)
#
# Baffled Jury Acquits Guy for ‘Stealing’ <extra_id_0> -Cent Hot Dog </s>
# 40
# Pred:  Baffled Jury Acquits Guy for ‘Stealing’ 99-Cent Hot Dog</s>
# Answer:  99
# Prediction1:  99
# Calc:  Copy(99)
#
# Lunch With Buffett Sells for $<extra_id_0> M </s>
# 30
# Pred:  Lunch With Buffett Sells for $1.68M</s>
# Answer:  1.68
# Prediction1:  1.68
# Calc:  Copy(1.68)
#
# AK-<extra_id_0> s Flooding US Cities </s>
# 3
# Pred:  AK-47s Flooding US Cities</s><pad>
# Answer:  47
# Prediction1:  47
# Calc:  Copy(47)
#
# Search Chief Says MH<extra_id_0>  May Never Be Found </s>
# 20
# Pred:  Search Chief Says MH370 May Never Be Found</s>
# Answer:  370
# Prediction1:  370
# Calc:  Copy(370)
#
# ...
#
# 14 Photos From the Moment Trump Became No. <extra_id_0>  </s>
# 43
# Pred:  14 Photos From the Moment Trump Became No. 45</s>
# Answer:  45
# Prediction1:  45
# Calc:  Copy(45)
#
# Suspect Who Let Partner Drown Nabbed <extra_id_0>  Years Later: Cops </s>
# 37
# Pred:  Suspect Who Let Partner Drown Nabbed 5 Years Later: Cops</s><pad>
# Answer:  5
# Prediction1:  5
# Calc:  Trans(five)
#
# <extra_id_0>  Gang Members Arrested in Long Island Slayings </s>
# 0
# Pred:  35 Gang Members Arrested in Long Island Slayings</s>
# Answer:  35
# Prediction1:  35
# Calc:  Copy(35)
#
# Couple Together for <extra_id_0>  Decades Carry Out Suicide Pact: Cops </s>
# 20
# Pred:  Couple Together for 3 Decades Carry Out Suicide Pact: Cops</s>
# Answer:  6
# Prediction1:  3
# Calc:  Divide(60,10)
#
# Secret Gov't Airline Needs Someone to Fly to Area <extra_id_0>  </s>
# 50
# Pred:  Secret Gov't Airline Needs Someone to Fly to Area 51</s>
# Answer:  51
# Prediction1:  51
# Calc:  Copy(51)
#
# Woman 'Wins' $<extra_id_0> M on Slots; Casino Says Not So Fast </s>
# 14
# Pred:  Woman 'Wins' $42.9M on Slots; Casino Says Not So Fast</s>
# Answer:  43
# Prediction1:  42.9
# Calc:  Copy(43)
#
# <extra_id_0>  States That Need to Take a Chill Pill </s>
# 0
# Pred:  5 States That Need to Take a Chill Pill</s><pad>
# Answer:  5
# Prediction1:  5
# Calc:  Trans(five)
#
# <extra_id_0> -Year-Old Saves Family From Bear Attack </s>
# 0
# Pred:  11-Year-Old Saves Family From Bear Attack</s>
# Answer:  11
# Prediction1:  11
# Calc:  Copy(11)
#
# How <extra_id_0>  Business Card Holders Cost Judge His Job </s>
# 4
# Pred:  How 2 Business Card Holders Cost Judge His Job</s>
# Answer:  2
# Prediction1:  2
# Calc:  Trans(two)
#
# $<extra_id_0> K Reward Offered for Killer of Yellowstone White Wolf </s>
# 1
# Pred:  $10K Reward Offered for Killer of Yellowstone White Wolf</s>
# Answer:  10
# Prediction1:  10
# Calc:  Paraphrase(10,000,K)
#
# Family Hid in Jungle for <extra_id_0>  Days After Pirate Attack </s>
# 25
# Pred:  Family Hid in Jungle for 3 Days After Pirate Attack</s><pad>
# Answer:  3
# Prediction1:  3
# Calc:  Copy(3)
#
# <extra_id_0> th State Legalizes Assisted Suicide </s>
# 0
# Pred:  8th State Legalizes Assisted Suicide</s>
# Answer:  8
# Prediction1:  8
# Calc:  Trans(eighth)
#
# Bilked Out of $400K, Koch Bro Spends $<extra_id_0> M to Investigate </s>
# 38
# Pred:  Bilked Out of $400K, Koch Bro Spends $35M to Investigate</s><pad>
# Answer:  35
# Prediction1:  35
# Calc:  Copy(35)
#
# <extra_id_0> -Year-Old Boy Killed by Falling Flower Box </s>
# 0
# Pred:  8-Year-Old Boy Killed by Falling Flower Box</s>
# Answer:  8
# Prediction1:  8
# Calc:  Copy(8)
#
# Woman Sues for $<extra_id_0> M Over Hysterectomy, Mastectomy </s>
# 16
# Pred:  Woman Sues for $1.8M Over Hysterectomy, Mastectomy</s>
# Answer:  1.8
# Prediction1:  1.8
# Calc:  Copy(1.8)
#
# UN: Survivors Report 240 Dead in <extra_id_0>  Mediterranean Shipwrecks </s>
# 33
# Pred:  UN: Survivors Report 240 Dead in 2 Mediterranean Shipwrecks</s><pad>
# Answer:  2
# Prediction1:  2
# Calc:  Trans(two)
#
# 6 Kids Among <extra_id_0>  Killed in Devastating Chicago Fire </s>
# 13
# Pred:  6 Kids Among 8 Killed in Devastating Chicago Fire</s><pad>
# Answer:  8
# Prediction1:  8
# Calc:  Trans(Eight)
#
# <extra_id_0>  US Soldiers Killed in ISIS Fight </s>
# 0
# Pred:  2 US Soldiers Killed in ISIS Fight</s>
# Answer:  2
# Prediction1:  2
# Calc:  Trans(two)
#
# Father of Slain Soldier: Trump Didn't Send Promised $<extra_id_0> K </s>
# 53
# Pred:  Father of Slain Soldier: Trump Didn't Send Promised $25K</s><pad>
# Answer:  25
# Prediction1:  25
# Calc:  Paraphrase(25,000,k)
#
# <extra_id_0>  Native American Boys Exhumed With Greatest Care </s>
# 0
# Pred:  3 Native American Boys Exhumed With Greatest Care</s>
# Answer:  3
# Prediction1:  3
# Calc:  Trans(three)
#
# Coca-Cola Offering $<extra_id_0> M For New Sugar Substitute </s>
# 20
# Pred:  Coca-Cola Offering $1.1M For New Sugar Substitute</s>
# Answer:  1
# Prediction1:  1.1
# Calc:  Copy(1)
#
# Dow, S&P <extra_id_0>  Close at Record Highs </s>
# 9
# Pred:  Dow, S&P 500 Close at Record Highs</s><pad>
# Answer:  500
# Prediction1:  500
# Calc:  Copy(500)
#
# <extra_id_0> M Years Before Humans, Ants Were Farmers </s>
# 0
# Pred:  3M Years Before Humans, Ants Were Farmers</s>
# Answer:  3
# Prediction1:  3
# Calc:  Copy(3)
#
# <extra_id_0>  States With Most, Fewest Green Cards </s>
# 0
# Pred:  5 States With Most, Fewest Green Cards</s><pad>
# Answer:  5
# Prediction1:  5
# Calc:  Trans(five)
#
# Equifax's Latest Headache: a $<extra_id_0>  Fake Website </s>
# 30
# Pred:  Equifax's Latest Headache: a $10 Fake Website</s><pad>
# Answer:  10
# Prediction1:  10
# Calc:  Copy(10)
#
# Report: Mugabe Resigning After <extra_id_0>  Years in Power </s>
# 31
# Pred:  Report: Mugabe Resigning After 40 Years in Power</s>
# Answer:  37
# Prediction1:  40
# Calc:  Copy(37)
#
# Billionaire Samsung Heir Sentenced to <extra_id_0>  Years In Prison </s>
# 38
# Pred:  Billionaire Samsung Heir Sentenced to 5 Years In Prison</s><pad>
# Answer:  5
# Prediction1:  5
# Calc:  Trans(five)
#
# Dartmouth Ponies Up $<extra_id_0> M Over Lab Animal Dumping Ground </s>
# 21
# Pred:  Dartmouth Ponies Up $8M Over Lab Animal Dumping Ground</s><pad>
# Answer:  8.4
# Prediction1:  8
# Calc:  Copy(8.4)
#
# Burglars Nab $<extra_id_0> K in Jewelry From Kendall Jenner </s>
# 14
# Pred:  Burglars Nab $200K in Jewelry From Kendall Jenner</s><pad>
# Answer:  200
# Prediction1:  200
# Calc:  Paraphrase(200,000,K)
#
# Scientists Have Never Seen <extra_id_0>  Hurricanes Line Up Like This </s>
# 27
# Pred:  Scientists Have Never Seen 3 Hurricanes Line Up Like This</s>
# Answer:  3
# Prediction1:  3
# Calc:  Copy(3)
#
# Apple: <extra_id_0> % of Chargers Sold on Amazon May Be Counterfeit </s>
# 7
# Pred:  Apple: 90% of Chargers Sold on Amazon May Be Counterfeit</s><pad>
# Answer:  90
# Prediction1:  90
# Calc:  Copy(90)
#
# Malcolm Young of AC/DC Dead at <extra_id_0>  </s>
# 31
# Pred:  Malcolm Young of AC/DC Dead at 64</s><pad>
# Answer:  64
# Prediction1:  64
# Calc:  Copy(64)
#
# Dow Ends Day Down <extra_id_0>  </s>
# 18
# Pred:  Dow Ends Day Down 63</s>
# Answer:  63
# Prediction1:  63
# Calc:  Copy(63)
#
# Guess Who Landed $<extra_id_0> M Deal to Help IRS Verify Your Identity? </s>
# 18
# Pred:  Guess Who Landed $7M Deal to Help IRS Verify Your Identity?</s><pad>
# Answer:  7
# Prediction1:  7
# Calc:  Round(7.25,0)
#
# As Fire Raged, Calif. Couple Hid in Pool for <extra_id_0>  Hours </s>
# 45
# Pred:  As Fire Raged, Calif. Couple Hid in Pool for 6 Hours</s><pad>
# Answer:  6
# Prediction1:  6
# Calc:  Trans(six)
#
# Chronic Shoplifter Finally Jailed—Over $<extra_id_0>  Advil </s>
# 40
# Pred:  Chronic Shoplifter Finally Jailed—Over $4 Advil</s><pad>
# Answer:  4.49
# Prediction1:  4
# Calc:  Copy(4.49)
#
# 112 Trump Protesters Arrested. At Least <extra_id_0>  Didn't Vote at All </s>
# 40
# Pred:  112 Trump Protesters Arrested. At Least 39 Didn't Vote at All</s>
# Answer:  39
# Prediction1:  39
# Calc:  Copy(39)
#
# Pentagon Blew $<extra_id_0> M on Iffy Afghan Army Uniforms </s>
# 15
# Pred:  Pentagon Blew $28M on Iffy Afghan Army Uniforms</s>
# Answer:  28
# Prediction1:  28
# Calc:  Copy(28)
#
# Witness: Driver Was Texting Before Crash That Killed <extra_id_0>  </s>
# 53
# Pred:  Witness: Driver Was Texting Before Crash That Killed 13</s>
# Answer:  13
# Prediction1:  13
# Calc:  Copy(13)
#
# 'She Just Wanted Some Candy': Instead Girl, <extra_id_0> , Is Dead </s>
# 44
# Pred:  'She Just Wanted Some Candy': Instead Girl, 4, Is Dead</s><pad>
# Answer:  4
# Prediction1:  4
# Calc:  Copy(4)
#
# Report: Harvey Caused <extra_id_0> K Gallons of Fuel to Spill </s>
# 22
# Pred:  Report: Harvey Caused 145K Gallons of Fuel to Spill</s>
# Answer:  145
# Prediction1:  145
# Calc:  Paraphrase(145,000,K)
#
# S&P <extra_id_0> , Nasdaq Close at Record Highs </s>
# 4
# Pred:  S&P 500, Nasdaq Close at Record Highs</s><pad>
# Answer:  500
# Prediction1:  500
# Calc:  Copy(500)
#
# <extra_id_0>  Dead as City Bus, Tour Bus Collide in NYC </s>
# 0
# Pred:  3 Dead as City Bus, Tour Bus Collide in NYC</s>
# Answer:  3
# Prediction1:  3
# Calc:  Trans(three)
#
# Federal Debt Soars Past $<extra_id_0> T </s>
# 25
# Pred:  Federal Debt Soars Past $20T</s>
# Answer:  20
# Prediction1:  20
# Calc:  Copy(20)
#
# <extra_id_0> -Day March Against White Supremacy to Begin Monday </s>
# 0
# Pred:  10-Day March Against White Supremacy to Begin Monday</s><pad>
# Answer:  10
# Prediction1:  10
# Calc:  Copy(10)
#
# He Spent <extra_id_0>  Years on the Run. Then Police Received a Tip </s>
# 9
# Pred:  He Spent 3 Years on the Run. Then Police Received a Tip</s>
# Answer:  32
# Prediction1:  3
# Calc:  Subtract(2017,1985)
#
# NCIS: Los Angeles Star Miguel Ferrer Dead at <extra_id_0>  </s>
# 45
# Pred:  NCIS: Los Angeles Star Miguel Ferrer Dead at 61</s>
# Answer:  61
# Prediction1:  61
# Calc:  Copy(61)
#
# Cost of This Drug in 2013: $<extra_id_0> . Cost Now: $2,979 </s>
# 28
# Pred:  Cost of This Drug in 2013: $138. Cost Now: $2,979</s>
# Answer:  138
# Prediction1:  138.
# Calc:  Copy(138)
#
# Gunman Kills <extra_id_0> , Shuts Vegas Strip for Hours </s>
# 13
# Pred:  Gunman Kills 1, Shuts Vegas Strip for Hours</s>
# Answer:  1
# Prediction1:  1
# Calc:  Trans(one)
#
# Democratic Favorite for <extra_id_0> ? None of the Above </s>
# 24
# Pred:  Democratic Favorite for 2020? None of the Above</s>
# Answer:  2020
# Prediction1:  2020
# Calc:  Copy(2020)
#
# Dow Surges <extra_id_0>  </s>
# 11
# Pred:  Dow Surges 297</s>
# Answer:  297
# Prediction1:  297
# Calc:  Copy(297)
#
# <extra_id_0>  Trump Protesters Arrested. At Least 39 Didn't Vote at All </s>
# 0
# Pred:  112 Trump Protesters Arrested. At Least 39 Didn't Vote at All</s>
# Answer:  112
# Prediction1:  112
# Calc:  Copy(112)
#
# Witness Recants <extra_id_0>  Years After Teen Jailed for Murder </s>
# 16
# Pred:  Witness Recants 27 Years After Teen Jailed for Murder</s>
# Answer:  27
# Prediction1:  27
# Calc:  Copy(27)
#
# <extra_id_0> -Year-Old's Obituary Calls Out Bullying </s>
# 0
# Pred:  15-Year-Old's Obituary Calls Out Bullying</s>
# Answer:  15
# Prediction1:  15
# Calc:  Copy(15)
#
# <extra_id_0>  Years After Girl's Abduction, a Big Break </s>
# 0
# Pred:  47 Years After Girl's Abduction, a Big Break</s>
# Answer:  47
# Prediction1:  47
# Calc:  Copy(47)
#
# UN: Survivors Report <extra_id_0>  Dead in 2 Mediterranean Shipwrecks </s>
# 21
# Pred:  UN: Survivors Report 240 Dead in 2 Mediterranean Shipwrecks</s><pad>
# Answer:  240
# Prediction1:  240
# Calc:  Copy(240)
#
# NYPD Baffled by Case of Baby Thrown From Building in <extra_id_0>  </s>
# 53
# Pred:  NYPD Baffled by Case of Baby Thrown From Building in 1993</s>
# Answer:  1993
# Prediction1:  1993
# Calc:  Copy(1993)
#
# An Epic Voyage: 3 Years, <extra_id_0> K Miles in Canoe With No GPS </s>
# 25
# Pred:  An Epic Voyage: 3 Years, 40K Miles in Canoe With No GPS</s>
# Answer:  40
# Prediction1:  40
# Calc:  Paraphrase(40,000,K)
#
# Novelist's Plea in Court Ends <extra_id_0> -Year Murder Case </s>
# 30
# Pred:  Novelist's Plea in Court Ends 15-Year Murder Case</s>
# Answer:  15
# Prediction1:  15
# Calc:  Copy(15)
#
# Philando Castile's Girlfriend to Get $<extra_id_0> K </s>
# 38
# Pred:  Philando Castile's Girlfriend to Get $800K</s>
# Answer:  800
# Prediction1:  800
# Calc:  Paraphrase(800,000,k)
#
# Tiger Woods, Mickelson Will Play 1-on-1 for $<extra_id_0> M </s>
# 45
# Pred:  Tiger Woods, Mickelson Will Play 1-on-1 for $10M</s>
# Answer:  10
# Prediction1:  10
# Calc:  Copy(10)
#
# Richest <extra_id_0> % Now Control Record 50.1% of Global Wealth </s>
# 8
# Pred:  Richest 1% Now Control Record 50.1% of Global Wealth</s>
# Answer:  1
# Prediction1:  1
# Calc:  Copy(1)
#
# <extra_id_0>  Cops Injured in St. Louis Protests </s>
# 0
# Pred:  9 Cops Injured in St. Louis Protests</s>
# Answer:  10
# Prediction1:  9
# Calc:  Add(1,Trans(nine))
#
# Trump: I Told Pence to Leave Colts Game If <extra_id_0> ers Kneeled </s>
# 43
# Pred:  Trump: I Told Pence to Leave Colts Game If 20 49ers Kneeled</s>
# Answer:  49
# Prediction1:  20
# Calc:  Copy(49)
#
# Sources: AT&T Agrees to Buy Time Warner for $<extra_id_0> B </s>
# 45
# Pred:  Sources: AT&T Agrees to Buy Time Warner for $80B</s>
# Answer:  80
# Prediction1:  80
# Calc:  Copy(80)
#
# <extra_id_0>  Die in Volcano Rescue Helicopter Crash </s>
# 0
# Pred:  8 Die in Volcano Rescue Helicopter Crash</s>
# Answer:  8
# Prediction1:  8
# Calc:  Trans(eight)
#
# Doctors Find <extra_id_0>  Contact Lenses in Woman's Eye </s>
# 13
# Pred:  Doctors Find 27 Contact Lenses in Woman's Eye</s>
# Answer:  27
# Prediction1:  27
# Calc:  Copy(27)
#
# 'San Antonio 4' Declared Innocent of <extra_id_0>  Gang-Rape </s>
# 37
# Pred:  'San Antonio 4' Declared Innocent of 1997 Gang-Rape</s>
# Answer:  1994
# Prediction1:  1997
# Calc:  Copy(1994)
#
# He's an <extra_id_0> -Year-Old Mormon. He's Also a Supermodel </s>
# 8
# Pred:  He's an 18-Year-Old Mormon. He's Also a Supermodel</s><pad>
# Answer:  18
# Prediction1:  18
# Calc:  Copy(18)
#
# Military May Soon Hold Its 1st Execution in <extra_id_0>  Years </s>
# 44
# Pred:  Military May Soon Hold Its 1st Execution in 50 Years</s>
# Answer:  56
# Prediction1:  50
# Calc:  Subtract(2016,1961)
#
# <extra_id_0>  Killed in 30-Car Pileup on Icy Interstate </s>
# 0
# Pred:  2 Killed in 30-Car Pileup on Icy Interstate</s>
# Answer:  2
# Prediction1:  2
# Calc:  Trans(two)
#
# Charlottesville Victim Was <extra_id_0> -Year-Old Virginia Woman </s>
# 27
# Pred:  Charlottesville Victim Was 32-Year-Old Virginia Woman</s>
# Answer:  32
# Prediction1:  32
# Calc:  Copy(32)
#
# Bilked Out of $<extra_id_0> K, Koch Bro Spends $35M to Investigate </s>
# 15
# Pred:  Bilked Out of $400K, Koch Bro Spends $35M to Investigate</s><pad>
# Answer:  400
# Prediction1:  400
# Calc:  Paraphrase(400,000,K)
#
# Teen's Charity Effort Has Her in the Hole $<extra_id_0> K </s>
# 43
# Pred:  Teen's Charity Effort Has Her in the Hole $600K</s>
# Answer:  200
# Prediction1:  600
# Calc:  Paraphrase(200,000,k)
#
# School District to Pay $<extra_id_0> K Over 'Drunk Goggles' Injury </s>
# 24
# Pred:  School District to Pay $100K Over 'Drunk Goggles' Injury</s><pad>
# Answer:  100
# Prediction1:  100
# Calc:  Paraphrase(100,000,K)
#
# Thieves Steal $<extra_id_0> K Worth of Stuff From Venus Williams' Home </s>
# 15
# Pred:  Thieves Steal $400K Worth of Stuff From Venus Williams' Home</s><pad>
# Answer:  400
# Prediction1:  400
# Calc:  Paraphrase(400,000,K)
#
# Paris Thieves Nab $<extra_id_0> M in Highway Heist </s>
# 19
# Pred:  Paris Thieves Nab $5.6M in Highway Heist</s>
# Answer:  5.6
# Prediction1:  5.6
# Calc:  Copy(5.6)
#
# Sri Lanka Mudslides: <extra_id_0>  Dead, 102K Displaced </s>
# 21
# Pred:  Sri Lanka Mudslides: 151 Dead, 102K Displaced</s>
# Answer:  151
# Prediction1:  151
# Calc:  Copy(151)
#
# House GOP to Slash Corporate Tax Rate From 39% to <extra_id_0> % </s>
# 50
# Pred:  House GOP to Slash Corporate Tax Rate From 39% to 20%</s><pad>
# Answer:  20
# Prediction1:  20
# Calc:  Copy(20)
#
# Trump Welcomes <extra_id_0> K to White House Easter Egg Roll </s>
# 15
# Pred:  Trump Welcomes 139K to White House Easter Egg Roll</s>
# Answer:  21
# Prediction1:  139
# Calc:  Paraphrase(21,000,K)
#
# Inmates Escapes Maximum Security for <extra_id_0> nd Time </s>
# 37
# Pred:  Inmates Escapes Maximum Security for 2nd Time</s><pad>
# Answer:  2
# Prediction1:  2
# Calc:  Copy(2)
#
# Report: Williams Got <extra_id_0> % of Male Co-Star's Pay for Reshoot </s>
# 21
# Pred:  Report: Williams Got 0.07% of Male Co-Star's Pay for Reshoot</s>
# Answer:  0.07
# Prediction1:  0.07
# Calc:  Copy(0.07)
#
# Hollywood Has Worst Weekend in <extra_id_0>  Years </s>
# 31
# Pred:  Hollywood Has Worst Weekend in 16 Years</s>
# Answer:  16
# Prediction1:  16
# Calc:  Copy(16)
#
# Hubbub Over Hernandez's <extra_id_0> rd Suicide Note Rages On </s>
# 24
# Pred:  Hubbub Over Hernandez's 3rd Suicide Note Rages On</s>
# Answer:  3
# Prediction1:  3
# Calc:  Trans(third)
#
# Election <extra_id_0> 's Strange Bedfellows Birth 'Electionland' </s>
# 9
# Pred:  Election 2016's Strange Bedfellows Birth 'Electionland'</s>
# Answer:  2016
# Prediction1:  2016
# Calc:  Copy(2016)
#
# The Mountaineer We Never Knew Dies at <extra_id_0>  </s>
# 38
# Pred:  The Mountaineer We Never Knew Dies at 94</s>
# Answer:  94
# Prediction1:  94
# Calc:  Copy(94)
#
# Federer Ekes Out <extra_id_0> th Grand Slam </s>
# 17
# Pred:  Federer Ekes Out 18th Grand Slam</s>
# Answer:  18
# Prediction1:  18
# Calc:  Copy(18)
#
# Laurence Fishburne Files for Divorce After <extra_id_0> -Year Marriage </s>
# 43
# Pred:  Laurence Fishburne Files for Divorce After 15-Year Marriage</s>
# Answer:  15
# Prediction1:  15
# Calc:  Copy(15)
#
# <extra_id_0>  Months After Baby, Janet Jackson, Hubby Split </s>
# 0
# Pred:  3 Months After Baby, Janet Jackson, Hubby Split</s>
# Answer:  3
# Prediction1:  3
# Calc:  Trans(three)
#
# Jihadist Attack Kills <extra_id_0>  UN Peacekeepers </s>
# 22
# Pred:  Jihadist Attack Kills 3 UN Peacekeepers</s>
# Answer:  3
# Prediction1:  3
# Calc:  Trans(three)

# %%
print(tru/len(test_data))
# Out:
# 0.8771384136858476
