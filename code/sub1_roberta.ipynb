# %%
import pandas as pd
import tensorflow as tf
from transformers import AutoTokenizer
import re
from transformers import DataCollatorForLanguageModeling
from transformers import AdamWeightDecay
from transformers import TFAutoModelForMaskedLM
from datasets import Dataset
import math
import numpy as np
import matplotlib.pyplot as plt
import torch
# Out:
# 2023-11-24 09:08:51.882606: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-24 09:08:51.882629: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-24 09:08:51.882657: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-24 09:08:51.888047: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-24 09:08:52.398497: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
import tensorflow as tf
tf.config.experimental.list_physical_devices(device_type='GPU')
# Out:
# 2023-11-24 09:08:54.250898: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-24 09:08:54.254586: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-24 09:08:54.254753: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
def json_to_dataframe(filename):
    f = open(filename)
    df = pd.read_json(f)
    print(df.iloc[0])
    f.close()
    df['news'] = df['news'].apply(lambda x: re.sub(r'\([^)]*\)', '', x)) # Remove time stamps
    df['masked headline'] = df['masked headline'].str.replace('____', '<mask> ') # Replace ___ with <mask>
    df['text'] = df[['news', 'masked headline', 'calculation']].apply(" ".join, axis=1)
    #df['text'] = df[['news', 'masked headline']].apply(" ".join, axis=1)
    df = df.astype(str)
    return df

# %%
df = json_to_dataframe('Train_Numerical_Reasoning.json')
df.head()
# Out:
# news               (Oct 7, 2014  12:40 PM CDT) As of Jan. 1, Walm...
# masked headline    ____K Walmart Part-Timers to Lose Health Insur...
# calculation                                     Paraphrase(30,000,K)
# ans                                                               30
# Name: 0, dtype: object
#                                                 news  \
# 0   As of Jan. 1, Walmart will no longer offer 30...
# 1   Dax Shepard and Kristen Bell got married at t...
# 2   Nancy Reagan, the helpmate, backstage adviser...
# 3   American Airlines faces FAA fines of more tha...
# 4   Ingrid Lyne, the Seattle mom allegedly murder...
#
#                                      masked headline            calculation  \
# 0  <mask> K Walmart Part-Timers to Lose Health In...   Paraphrase(30,000,K)
# 1  Dax Shepard: Wedding to Kristen Bell Cost $<ma...              Copy(142)
# 2                       Nancy Reagan Dead at <mask>                Copy(94)
# 3  American Airlines Faces $<mask> M Fine for Saf...                Copy(7)
# 4  $<mask> K Raised for Kids of Mom Dismembered o...  Paraphrase(222,000,K)
#
#    ans                                               text
# 0   30   As of Jan. 1, Walmart will no longer offer 30...
# 1  142   Dax Shepard and Kristen Bell got married at t...
# 2   94   Nancy Reagan, the helpmate, backstage adviser...
# 3    7   American Airlines faces FAA fines of more tha...
# 4  222   Ingrid Lyne, the Seattle mom allegedly murder...

# %%
df.shape
# Out:
# (21157, 5)

# %%
dataset = Dataset.from_pandas(df)
dataset = dataset.train_test_split(test_size=0.2)

# %% [markdown]
# To load a DistilRoBERTa tokenizer to process the text for masked language modeling,

# %% [markdown]
# RoBERTa  (short for “Robustly Optimized BERT Approach”) is a variant of the BERT (Bidirectional Encoder Representations from Transformers) model. Like BERT, RoBERTa is a transformer-based language model that uses self-attention to process input sequences and generate contextualized representations of words in a sentence. But RoBERTa was trained on more than 10 times larger than the dataset used to train BERT (160GB of text). Also RoBERTa uses a dynamic masking technique during training that helps the model learn more robust and generalizable representations of words.

# %%
model_name = "distilroberta-base"

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name)

# %%
def preprocess_function(examples):
    inputs = tokenizer(examples['text'],truncation=True)
    inputs['labels'] = examples['ans']
    return inputs

# %% [markdown]
# To apply the preprocess function over the entire dataset

# %%
tokenized = dataset.map(preprocess_function, batched=True, num_proc=4,
                        remove_columns=dataset['train'].column_names)
# Out:
# Map (num_proc=4):   0%|          | 0/16925 [00:00<?, ? examples/s]
# Map (num_proc=4):   0%|          | 0/4232 [00:00<?, ? examples/s]

# %%
tokenized['train']
# Out:
# Dataset({
#     features: ['input_ids', 'attention_mask', 'labels'],
#     num_rows: 16925
# })

# %% [markdown]
# To create batches using DataCollatorForLanguageModeling, which dynamically pads the sentences to the longest length in a batch during collation. This is  more efficient than padding the whole dataset to the maximum length. To use the end-of-sequence token as the padding token and specify mlm_probability to randomly mask tokens each time iterated over the data.
# Also, to set up optimizer function

# %%
data_collator = DataCollatorForLanguageModeling(tokenizer=tokenizer,  mlm_probability=0.15,return_tensors="tf")
#optimizer = AdamWeightDecay(learning_rate=3e-5, weight_decay_rate=0.01)
optimizer = AdamWeightDecay(learning_rate=5e-5, weight_decay_rate=0.01)

# %% [markdown]
# To load DistilRoBERTa with AutoModelForMaskedLM

# %%
model = TFAutoModelForMaskedLM.from_pretrained(model_name)
# Out:
# 2023-11-24 09:09:59.382068: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-24 09:09:59.382247: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-24 09:09:59.382382: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-24 09:09:59.780920: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-24 09:09:59.781084: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-24 09:09:59.781225: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-24 09:09:59.781334: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9476 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:08:00.0, compute capability: 8.6
# All PyTorch model weights were used when initializing TFRobertaForMaskedLM.
#
# All the weights of TFRobertaForMaskedLM were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaForMaskedLM for predictions without further training.

# %% [markdown]
# To convert datasets to the tf.data.Dataset format

# %%
tf_train_set = model.prepare_tf_dataset(
    tokenized["train"],
    shuffle=True,
    batch_size=6,
    collate_fn=data_collator,
)

tf_test_set = model.prepare_tf_dataset(
    tokenized["test"],
    shuffle=False,
    batch_size=6,
    collate_fn=data_collator,
)
# Out:
# You're using a RobertaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.

# %%
model.compile(optimizer=optimizer)

# %% [markdown]
# Perplexity to evaluate the model - to calculate the probabilities it assigns to the next word in all the sentences of the test set (the exponential of the cross-entropy loss is computed)

# %%
eval_loss = model.evaluate(tf_test_set)
print(f"Pretrained LM Perplexity: {math.exp(eval_loss):.2f}")
# Out:
# 265/265 [==============================] - 39s 132ms/step - loss: 1.8290
# Pretrained LM Perplexity: 6.23

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=1)
history = model.fit(x=tf_train_set, validation_data=tf_test_set, callbacks=[callback],batch_size=3, epochs=15)
# Out:
# Epoch 1/15
# 2820/2820 [==============================] - 767s 270ms/step - loss: 1.5355 - val_loss: 1.3759
# Epoch 2/15
# 2820/2820 [==============================] - 757s 268ms/step - loss: 1.4786 - val_loss: 1.3476
# Epoch 3/15
# 2820/2820 [==============================] - 758s 269ms/step - loss: 1.4417 - val_loss: 1.3301
# Epoch 4/15
# 2820/2820 [==============================] - 756s 268ms/step - loss: 1.4108 - val_loss: 1.3388

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
eval_loss = model.evaluate(tf_test_set)
print(f"Finetuned Perplexity: {math.exp(eval_loss):.2f}")
# Out:
# 265/265 [==============================] - 35s 134ms/step - loss: 1.3041
# Finetuned Perplexity: 3.68

# %% [markdown]
# To use the model for dev dataset

# %%
f = open('Dev_Numerical_Reasoning.json')
df = pd.read_json(f)
df['news'] = df['news'].apply(lambda x: re.sub(r'\([^)]*\)', '', x))
df['masked headline'] = df['masked headline'].str.replace('____', '<mask> ')    
df['text'] = df[['news', 'masked headline']].apply(" ".join, axis=1)
df = df.astype(str)
#df = df.iloc[100:100]
f.close()
test_data = Dataset.from_pandas(df)

# %%
def predictions(data, tokenizer, model):
    inputs = tokenizer(data['text'], return_tensors="np")
    logits = model(**inputs).logits
    mask_token_index = np.argwhere(inputs["input_ids"] == tokenizer.mask_token_id)[0, 1]
    mask_token_logits = logits[0, mask_token_index, :]
    top_tokens = tf.math.top_k(mask_token_logits, 20).indices.numpy()
    result = ''

    for token in top_tokens:
        result = tokenizer.decode([token][0]).strip()
        if result.isnumeric():
            break
        else:
            continue

    return result

# %%
tr = 0
pre = []
for i in test_data:
    prediction = predictions(i, tokenizer, model)
    pre.append(prediction)
    ans = i['ans']
    print("Prediction: ", prediction)
    print("Answer:     ", i['ans'])
    print("Calc: ", i['calculation'])
    if prediction == ans:
        tr += 1
    print("")
# Out:
# Prediction:  3
# Answer:      3
# Calc:  Trans(three)
#
# Prediction:  161
# Answer:      12
# Calc:  Copy(12)
#
# Prediction:  305
# Answer:      305
# Calc:  Round(305.45,0)
#
# Prediction:  1
# Answer:      1
# Calc:  Copy(1)
#
# Prediction:  10
# Answer:      10
# Calc:  Copy(10)
#
# Prediction:  1959
# Answer:      1959
# Calc:  Copy(1959)
#
# Prediction:  218
# Answer:      218
# Calc:  Copy(218)
#
# Prediction:  5
# Answer:      9
# Calc:  Round(Divide(268,30),0)
#
# Prediction:  2
# Answer:      2
# Calc:  Paraphrase(2,000,K)
#
# Prediction:  60
# Answer:      60
# Calc:  Copy(60)
#
# Prediction:  25
# Answer:      25
# Calc:  Copy(25)
#
# Prediction:  6
# Answer:      6
# Calc:  Copy(6)
#
# Prediction:  1
# Answer:      1
# Calc:  Round(1.29,0)
#
# Prediction:  4
# Answer:      4
# Calc:  Copy(4)
#
# Prediction:  3
# Answer:      3
# Calc:  Trans(third)
#
# Prediction:  30
# Answer:      30
# Calc:  Copy(30)
#
# Prediction:  20
# Answer:      20
# Calc:  Copy(20)
#
# Prediction:  5
# Answer:      5
# Calc:  Trans(five)
#
# Prediction:  55
# Answer:      55
# Calc:  Copy(55)
#
# Prediction:  65
# Answer:      65
# Calc:  Copy(65)
#
# Prediction:  20
# Answer:      20
# Calc:  Copy(20)
#
# Prediction:  5
# Answer:      2
# Calc:  Copy(2)
#
# Prediction:  11
# Answer:      6
# Calc:  Copy(6)
#
# Prediction:  50
# Answer:      50
# Calc:  Copy(50)
#
# Prediction:  Good
# Answer:      2000
# Calc:  Subtract(2011,11)
#
# Prediction:  3
# Answer:      3
# Calc:  Copy(3)
#
# Prediction:  74
# Answer:      74
# Calc:  Copy(74)
#
# Prediction:  60
# Answer:      60
# Calc:  Copy(60)
#
# Prediction:  5
# Answer:      5
# Calc:  Paraphrase(5,000,K)
#
# Prediction:  2
# Answer:      2
# Calc:  Copy(2)
#
# Prediction:  7
# Answer:      7
# Calc:  Trans(seven)
#
# Prediction:  90
# Answer:      90
# Calc:  Copy(90)
#
# Prediction:  77
# Answer:      77
# Calc:  Copy(77)
#
# Prediction:  4
# Answer:      4
# Calc:  Copy(4)
#
# Prediction:  500
# Answer:      500
# Calc:  Paraphrase(500,000,K)
#
# Prediction:  30
# Answer:      30
# Calc:  Copy(30)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  2012
# Answer:      2012
# Calc:  Copy(2012)
#
# Prediction:  70
# Answer:      70
# Calc:  Copy(70)
#
# Prediction:  15
# Answer:      15
# Calc:  Copy(15)
#
# Prediction:  26
# Answer:      26
# Calc:  Copy(26)
#
# Prediction:  60
# Answer:      60
# Calc:  Copy(60)
#
# Prediction:  9
# Answer:      9
# Calc:  Trans(nine)
#
# Prediction:  162
# Answer:      162
# Calc:  Copy(162)
#
# Prediction:  25
# Answer:      25
# Calc:  Paraphrase(25,000,K)
#
# Prediction:  37
# Answer:      37
# Calc:  Copy(37)
#
# Prediction:  86
# Answer:      86
# Calc:  Copy(86)
#
# Prediction:  31
# Answer:      31
# Calc:  Copy(31)
#
# Prediction:  11
# Answer:      11
# Calc:  Copy(11)
#
# Prediction:  7
# Answer:      7
# Calc:  Copy(7)
#
# Prediction:  100
# Answer:      100
# Calc:  Copy(100)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(Two)
#
# Prediction:  5
# Answer:      2
# Calc:  Add(Span(Arizona),Span(Missouri))
#
# Prediction:  4
# Answer:      4
# Calc:  Trans(four)
#
# Prediction:  3
# Answer:      3
# Calc:  Trans(three)
#
# Prediction:  11
# Answer:      11
# Calc:  Copy(11)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(Two)
#
# Prediction:  900
# Answer:      900
# Calc:  Copy(900)
#
# Prediction:  Origin
# Answer:      1791
# Calc:  Copy(1791)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  40
# Answer:      40
# Calc:  Copy(40)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  90
# Answer:      5
# Calc:  Copy(5)
#
# Prediction:  2
# Answer:      2.9
# Calc:  Copy(2.9)
#
# Prediction:  370
# Answer:      370
# Calc:  Copy(370)
#
# Prediction:  300
# Answer:      285
# Calc:  Copy(285)
#
# Prediction:  232
# Answer:      232
# Calc:  Copy(232)
#
# Prediction:  5
# Answer:      5
# Calc:  Copy(5)
#
# Prediction:  19
# Answer:      19
# Calc:  Copy(19)
#
# Prediction:  1
# Answer:      1
# Calc:  Span( a million)
#
# Prediction:  100
# Answer:      100
# Calc:  Copy(100)
#
# Prediction:  3
# Answer:      2
# Calc:  Add(having their tonsils),Span(appendix removed))
#
# Prediction:  Tuesday
# Answer:      9/11
# Calc:  Copy(9/11)
#
# Prediction:  60
# Answer:      60
# Calc:  Copy(60)
#
# Prediction:  30
# Answer:      30
# Calc:  Copy(30)
#
# Prediction:  2
# Answer:      59
# Calc:  Subtract(Sep 5,July 8)
#
# Prediction:  3
# Answer:      3
# Calc:  Copy(3)
#
# Prediction:  1
# Answer:      9
# Calc:  Copy(9)
#
# Prediction:  800
# Answer:      800
# Calc:  Copy(800)
#
# Prediction:  2
# Answer:      2.8
# Calc:  Copy(2.8)
#
# Prediction:  6
# Answer:      6
# Calc:  Trans(six)
#
# Prediction:  3
# Answer:      3
# Calc:  Copy(3)
#
# Prediction:  1
# Answer:      1
# Calc:  Span(top draft pick)
#
# Prediction:  50
# Answer:      50
# Calc:  Paraphrase(50,000,K)
#
# Prediction:  90
# Answer:      90
# Calc:  Paraphrase(90,000,K)
#
# Prediction:  4
# Answer:      4.5
# Calc:  Trans(four and a half)
#
# Prediction:  81
# Answer:      81
# Calc:  Copy(81)
#
# Prediction:  1
# Answer:      2
# Calc:  Copy(2)
#
# Prediction:  44
# Answer:      44
# Calc:  Paraphrase(44,000,K)
#
# Prediction:  700
# Answer:      350
# Calc:  Divide(700,2)
#
# Prediction:  1
# Answer:      1
# Calc:  Paraphrase(1,000,K)
#
# Prediction:  14
# Answer:      14
# Calc:  Copy(14)
#
# Prediction:  5
# Answer:      5
# Calc:  Trans(five)
#
# Prediction:  2
# Answer:      2.0
# Calc:  Copy(2.0)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(second)
#
# Prediction:  25
# Answer:      25
# Calc:  Copy(25)
#
# Prediction:  74
# Answer:      74
# Calc:  Copy(74)
#
# Prediction:  370
# Answer:      370
# Calc:  Copy(370)
#
# Prediction:  3
# Answer:      31
# Calc:  Subtract(2012-1981)
#
# Prediction:  8
# Answer:      8
# Calc:  Copy(8)
#
# Prediction:  400
# Answer:      400
# Calc:  Copy(400)
#
# Prediction:  61
# Answer:      61
# Calc:  Copy(61)
#
# Prediction:  47
# Answer:      47
# Calc:  Copy(47)
#
# Prediction:  911
# Answer:      911
# Calc:  Copy(911)
#
# Prediction:  3
# Answer:      3
# Calc:  Trans(Three)
#
# Prediction:  500
# Answer:      500
# Calc:  Copy(500)
#
# Prediction:  100
# Answer:      100
# Calc:  Copy(100)
#
# Prediction:  17
# Answer:      17
# Calc:  Copy(17)
#
# Prediction:  79
# Answer:      160
# Calc:  Round(159.7,0)
#
# Prediction:  25
# Answer:      25
# Calc:  Copy(25)
#
# Prediction:  47
# Answer:      47
# Calc:  Trans(two)
#
# Prediction:  44
# Answer:      44
# Calc:  Trans(two)
#
# Prediction:  21
# Answer:      21
# Calc:  Trans(two)
#
# Prediction:  16
# Answer:      16
# Calc:  Trans(two)
#
# Prediction:  5
# Answer:      50
# Calc:  Trans(two)
#
# Prediction:  100
# Answer:      100
# Calc:  Trans(two)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  69
# Answer:      69
# Calc:  Trans(two)
#
# Prediction:  21
# Answer:      21
# Calc:  Trans(two)
#
# Prediction:  3
# Answer:      3.3
# Calc:  Trans(two)
#
# Prediction:  21
# Answer:      21
# Calc:  Trans(two)
#
# Prediction:  3
# Answer:      3
# Calc:  Trans(two)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  92
# Answer:      92
# Calc:  Trans(two)
#
# Prediction:  3
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  18
# Answer:      18
# Calc:  Trans(two)
#
# Prediction:  9
# Answer:      9
# Calc:  Trans(two)
#
# Prediction:  1
# Answer:      1
# Calc:  Trans(two)
#
# Prediction:  23
# Answer:      29
# Calc:  Copy(29)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  1
# Answer:      4
# Calc:  Add(Trans(one),Trans(three))
#
# Prediction:  24
# Answer:      85
# Calc:  Copy(85)
#
# Prediction:  3
# Answer:      3
# Calc:  Copy(3)
#
# Prediction:  121
# Answer:      1892
# Calc:  Subtract(2013,121)
#
# Prediction:  5
# Answer:      17
# Calc:  Round(Divide(520,30),0)
#
# Prediction:  3
# Answer:      3
# Calc:  Trans(third)
#
# Prediction:  94
# Answer:      94
# Calc:  Paraphrase(94,000,K)
#
# Prediction:  2
# Answer:      4
# Calc:  Add(2,2)
#
# Prediction:  12
# Answer:      13
# Calc:  Copy(13)
#
# Prediction:  2
# Answer:      2
# Calc:  Copy(2)
#
# Prediction:  6
# Answer:      6
# Calc:  Copy(6)
#
# Prediction:  Case
# Answer:      6
# Calc:  Trans(six)
#
# Prediction:  25
# Answer:      25
# Calc:  Copy(25)
#
# Prediction:  22
# Answer:      22
# Calc:  Copy(22)
#
# Prediction:  3
# Answer:      2
# Calc:  Trans(Two)
#
# Prediction:  500
# Answer:      500
# Calc:  Copy(500)
#
# Prediction:  30
# Answer:      30
# Calc:  Copy(30)
#
# Prediction:  364
# Answer:      12
# Calc:  Copy(12)
#
# Prediction:  4
# Answer:      26
# Calc:  Add(22,Trans(four))
#
# Prediction:  1
# Answer:      1
# Calc:  Copy(1)
#
# Prediction:  91
# Answer:      62
# Calc:  Subtract(186,124)
#
# Prediction:  2
# Answer:      2.4
# Calc:  Copy(2.4)
#
# Prediction:  140
# Answer:      140
# Calc:  Copy(140)
#
# Prediction:  23
# Answer:      23
# Calc:  Copy(23)
#
# Prediction:  1
# Answer:      1
# Calc:  Paraphrase(1,000,K)
#
# Prediction:  45
# Answer:      45
# Calc:  Paraphrase(45,000,K)
#
# Prediction:  300
# Answer:      300
# Calc:  Paraphrase(300,000,K)
#
# Prediction:  100
# Answer:      100
# Calc:  Copy(100)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(two)
# Prediction:  13
# Answer:      13
# Calc:  Copy(13)
#
# Prediction:  3
# Answer:      3.2
# Calc:  Copy(3.2)
#
# Prediction:  3
# Answer:      3
# Calc:  Round(Paraphrase(3,175,K),0)
#
# Prediction:  92
# Answer:      92
# Calc:  Copy(92)
#
# Prediction:  8
# Answer:      8
# Calc:  Copy(8)
#
# Prediction:  50
# Answer:      50
# Calc:  Copy(50)
#
# Prediction:  23
# Answer:      23
# Calc:  Copy(23)
#
# Prediction:  50
# Answer:      50
# Calc:  Copy(50)
#
# Prediction:  5
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  30
# Answer:      30
# Calc:  Copy(30)
#
# Prediction:  4
# Answer:      2
# Calc:  Add(Span(Old America),Span(New America))
#
# Prediction:  77
# Answer:      77
# Calc:  Copy(77)
#
# Prediction:  10
# Answer:      10
# Calc:  Copy(10)
#
# Prediction:  10
# Answer:      15.5
# Calc:  Add(10,5.5)
#
# Prediction:  4
# Answer:      4
# Calc:  Trans(four)
#
# Prediction:  250
# Answer:      250
# Calc:  Copy(250)
#
# Prediction:  86
# Answer:      86
# Calc:  Copy(86)
#
# Prediction:  100
# Answer:      100
# Calc:  Subtract(109,9)
#
# Prediction:  1
# Answer:      1
# Calc:  Copy(1)
#
# Prediction:  11
# Answer:      11
# Calc:  Copy(11)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  4
# Answer:      4.2
# Calc:  Copy(4.2)
#
# Prediction:  4
# Answer:      4
# Calc:  Trans(fourth)
#
# Prediction:  4
# Answer:      4
# Calc:  Copy(4)
#
# Prediction:  3
# Answer:      2
# Calc:  Trans(second)
#
# Prediction:  12
# Answer:      12
# Calc:  Paraphrase(12,000,K)
#
# Prediction:  6
# Answer:      6
# Calc:  Copy(6)
#
# Prediction:  200
# Answer:      200
# Calc:  Copy(200)
#
# Prediction:  3
# Answer:      3
# Calc:  Trans(third)
#
# Prediction:  3
# Answer:      3
# Calc:  Trans(third)
#
# Prediction:  1
# Answer:      1
# Calc:  Trans(first)
#
# Prediction:  18
# Answer:      18
# Calc:  Copy(18)
#
# Prediction:  86
# Answer:      86
# Calc:  Copy(86)
#
# Prediction:  60
# Answer:      100
# Calc:  Copy(100)
#
# Prediction:  3
# Answer:      3
# Calc:  Copy(3)
#
# Prediction:  2
# Answer:      2
# Calc:  Copy(2)
#
# Prediction:  2010
# Answer:      2010
# Calc:  Copy(2010)
#
# Prediction:  10
# Answer:      10
# Calc:  Copy(10)
#
# Prediction:  25
# Answer:      27
# Calc:  Add(25,Trans(two))
#
# Prediction:  125
# Answer:      125
# Calc:  Copy(125)
#
# Prediction:  5
# Answer:      5
# Calc:  Copy(5)
#
# Prediction:  100
# Answer:      100
# Calc:  Copy(100)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(Two)
#
# Prediction:  22
# Answer:      22
# Calc:  Copy(22)
#
# Prediction:  1972
# Answer:      1972
# Calc:  Copy(1972)
#
# Prediction:  200
# Answer:      800
# Calc:  Add(200,600)
#
# Prediction:  1
# Answer:      1
# Calc:  Paraphrase(1,000,K)
#
# Prediction:  10
# Answer:      10
# Calc:  Copy(10)
#
# Prediction:  12
# Answer:      12
# Calc:  Copy(12)
#
# Prediction:  4
# Answer:      4
# Calc:  Copy(4)
#
# Prediction:  2008
# Answer:      2008
# Calc:  Copy(2008)
#
# Prediction:  100
# Answer:      100
# Calc:  Copy(100)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(Two)
#
# Prediction:  93
# Answer:      93
# Calc:  Copy(93)
#
# Prediction:  6
# Answer:      6
# Calc:  Copy(6)
#
# Prediction:  9
# Answer:      9
# Calc:  Trans(nine)
#
# Prediction:  28
# Answer:      28.6
# Calc:  Copy(28.6)
#
# Prediction:  62
# Answer:      62
# Calc:  Copy(62)
#
# Prediction:  12
# Answer:      12
# Calc:  Copy(12)
#
# Prediction:  90
# Answer:      90
# Calc:  Copy(90)
#
# Prediction:  15
# Answer:      15
# Calc:  Copy(15)
#
# Prediction:  50
# Answer:      2
# Calc:  Copy(2)
#
# Prediction:  10
# Answer:      10.1
# Calc:  Copy(10.1)
#
# Prediction:  45
# Answer:      45
# Calc:  Copy(45)
#
# Prediction:  11
# Answer:      11
# Calc:  Copy(11)
#
# Prediction:  1
# Answer:      2
# Calc:  Copy(2)
#
# Prediction:  1
# Answer:      1
# Calc:  Copy(1)
#
# Prediction:  16
# Answer:      16
# Calc:  Paraphrase(16,000,K)
#
# Prediction:  643
# Answer:      643
# Calc:  Copy(643)
#
# Prediction:  3
# Answer:      3
# Calc:  Copy(3)
#
# Prediction:  52
# Answer:      34
# Calc:  Copy(34)
#
# Prediction:  10
# Answer:      10
# Calc:  Copy(10)
#
# Prediction:  19
# Answer:      19
# Calc:  Trans(Nineteen)
#
# Prediction:  2
# Answer:      2
# Calc:  Copy(2)
#
# Prediction:  100
# Answer:      100
# Calc:  Copy(100)
#
# Prediction:  500
# Answer:      1,500
# Calc:  Copy(1,500)
#
# Prediction:  20
# Answer:      20
# Calc:  Copy(20)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(Two)
#
# Prediction:  911
# Answer:      911
# Calc:  Copy(911)
#
# Prediction:  18
# Answer:      18
# Calc:  Copy(18)
#
# Prediction:  16
# Answer:      16
# Calc:  Copy(16)
#
# Prediction:  25
# Answer:      25
# Calc:  Paraphrase(25,000,K)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  43
# Answer:      43
# Calc:  Copy(43)
#
# Prediction:  384
# Answer:      384
# Calc:  Paraphrase(384,000,K)
#
# Prediction:  14
# Answer:      14
# Calc:  Copy(14)
#
# Prediction:  4
# Answer:      4
# Calc:  Copy(4)
#
# Prediction:  3
# Answer:      3
# Calc:  Trans(three)
#
# Prediction:  3
# Answer:      3
# Calc:  Copy(3)
#
# Prediction:  229
# Answer:      230
# Calc:  Round(Paraphrase(229,500,k),0)
#
# Prediction:  3
# Answer:      3
# Calc:  Trans(three)
#
# Prediction:  55
# Answer:      55
# Calc:  Paraphrase(55,000,K)
#
# Prediction:  4
# Answer:      4
# Calc:  Trans(four)
#
# Prediction:  17
# Answer:      17
# Calc:  Copy(17)
#
# Prediction:  11
# Answer:      11
# Calc:  Copy(11)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(second)
#
# Prediction:  7
# Answer:      7
# Calc:  Trans(seven)
#
# Prediction:  80
# Answer:      80
# Calc:  Copy(80)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(second)
#
# Prediction:  17
# Answer:      17
# Calc:  Copy(17)
#
# Prediction:  1
# Answer:      1
# Calc:  Copy(1)
#
# Prediction:  25
# Answer:      25
# Calc:  Copy(25)
#
# Prediction:  3
# Answer:      11
# Calc:  Copy(11)
#
# Prediction:  500
# Answer:      500
# Calc:  Copy(500)
#
# Prediction:  1918
# Answer:      1667
# Calc:  Copy(1667)
#
# Prediction:  185
# Answer:      185
# Calc:  Copy(185)
#
# Prediction:  15
# Answer:      15
# Calc:  Copy(15)
#
# Prediction:  3
# Answer:      3
# Calc:  Trans(third)
#
# Prediction:  4
# Answer:      4
# Calc:  Trans(four)
#
# Prediction:  8
# Answer:      8
# Calc:  Copy(8)
#
# Prediction:  173
# Answer:      173
# Calc:  Copy(173)
#
# Prediction:  100
# Answer:      100
# Calc:  Copy(100)
#
# Prediction:  5
# Answer:      5
# Calc:  Trans(five)
#
# Prediction:  127
# Answer:      127
# Calc:  Copy(127)
#
# Prediction:  700
# Answer:      700
# Calc:  Copy(700)
#
# Prediction:  10
# Answer:      20
# Calc:  Copy(20)
#
# Prediction:  1
# Answer:      1
# Calc:  Span(wounding another in Palm Springs)
#
# Prediction:  1982
# Answer:      1999
# Calc:  Copy(1999)
#
# Prediction:  75
# Answer:      75
# Calc:  Copy(75)
#
# Prediction:  68
# Answer:      68
# Calc:  Copy(68)
#
# Prediction:  400
# Answer:      1,000
# Calc:  Copy(1,000)
#
# Prediction:  99
# Answer:      99
# Calc:  Copy(99)
#
# Prediction:  1
# Answer:      1.68
# Calc:  Copy(1.68)
#
# Prediction:  47
# Answer:      47
# Calc:  Copy(47)
#
# Prediction:  370
# Answer:      370
# Calc:  Copy(370)
#
# Prediction:  4
# Answer:      14
# Calc:  Copy(14)
#
# Prediction:  4
# Answer:      4
# Calc:  Copy(4)
#
# Prediction:  2009
# Answer:      2009
# Calc:  Copy(2009)
#
# Prediction:  15
# Answer:      15
# Calc:  Copy(15)
#
# Prediction:  1
# Answer:      1
# Calc:  Copy(1)
#
# Prediction:  6
# Answer:      6
# Calc:  Trans(six)
#
# Prediction:  2
# Answer:      2
# Calc:  Copy(2)
#
# Prediction:  2
# Answer:      2
# Calc:  Paraphrase(2,000,K)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  1
# Answer:      1
# Calc:  Copy(1)
#
# Prediction:  69
# Answer:      69
# Calc:  Copy(69)
#
# Prediction:  5
# Answer:      5
# Calc:  Copy(5)
#
# Prediction:  7
# Answer:      12
# Calc:  Copy(12)
#
# Prediction:  100
# Answer:      100
# Calc:  Copy(100)
#
# Prediction:  20
# Answer:      20
# Calc:  Copy(20)
#
# Prediction:  16
# Answer:      16
# Calc:  Copy(16)
#
# Prediction:  17
# Answer:      17
# Calc:  Copy(17)
#
# Prediction:  100
# Answer:      100
# Calc:  Copy(100)
#
# Prediction:  15
# Answer:      15
# Calc:  Copy(15)
#
# Prediction:  5
# Answer:      500
# Calc:  Paraphrase(513,000,K)
#
# Prediction:  2017
# Answer:      2010
# Calc:  Copy(2010)
#
# Prediction:  6
# Answer:      51
# Calc:  Copy(51)
#
# Prediction:  2
# Answer:      3
# Calc:  Subtract(4,1)
#
# Prediction:  39
# Answer:      39
# Calc:  Copy(39)
#
# Prediction:  4
# Answer:      4.9
# Calc:  Copy(4.9)
#
# Prediction:  4
# Answer:      4.5
# Calc:  Copy(4.5)
#
# Prediction:  Fatal
# Answer:      1981
# Calc:  Subtract(2015,34)
#
# Prediction:  200
# Answer:      200
# Calc:  Paraphrase(200,000,K)
#
# Prediction:  1
# Answer:      1
# Calc:  Copy(1)
#
# Prediction:  99
# Answer:      99
# Calc:  Copy(99)
#
# Prediction:  8
# Answer:      8
# Calc:  Copy(8)
#
# Prediction:  90
# Answer:      90
# Calc:  Copy(90)
#
# Prediction:  5
# Answer:      5
# Calc:  Trans(five)
#
# Prediction:  905
# Answer:      900
# Calc:  Paraphrase(905,000,K)
#
# Prediction:  02
# Answer:      02
# Calc:  Subtract(2002,2000)
#
# Prediction:  10
# Answer:      10
# Calc:  Copy(10)
#
# Prediction:  75
# Answer:      75
# Calc:  Copy(75)
# Prediction:  40
# Answer:      9/11
# Calc:  Trans(Sept. 11)
#
# Prediction:  75
# Answer:      75
# Calc:  Copy(75)
#
# Prediction:  60
# Answer:      60
# Calc:  Paraphrase(60,000,K)
#
# Prediction:  2016
# Answer:      2016
# Calc:  Copy(2016)
#
# Prediction:  60
# Answer:      60
# Calc:  Copy(60)
#
# Prediction:  1
# Answer:      1
# Calc:  Copy(1)
#
# Prediction:  88
# Answer:      88
# Calc:  Copy(88)
#
# Prediction:  2
# Answer:      2
# Calc:  Copy(2)
#
# Prediction:  12
# Answer:      12
# Calc:  Trans(Twelve)
#
# Prediction:  7
# Answer:      7
# Calc:  Trans(seven)
#
# Prediction:  2012
# Answer:      2012
# Calc:  Copy(2012)
#
# Prediction:  200
# Answer:      20
# Calc:  Paraphrase(20,000,K)
#
# Prediction:  1
# Answer:      1.2
# Calc:  Copy(1.2)
#
# Prediction:  40
# Answer:      40
# Calc:  Copy(40)
#
# Prediction:  500
# Answer:      1,000
# Calc:  Copy(1,000)
#
# Prediction:  85
# Answer:      85
# Calc:  Copy(85)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  85
# Answer:      85
# Calc:  Copy(85)
#
# Prediction:  2010
# Answer:      2010
# Calc:  Copy(2010)
#
# Prediction:  3
# Answer:      3
# Calc:  Trans(third)
#
# Prediction:  70
# Answer:      70
# Calc:  Copy(70)
#
# Prediction:  10
# Answer:      6.4
# Calc:  Copy(6.4)
#
# Prediction:  7
# Answer:      7
# Calc:  Copy(7)
#
# Prediction:  80
# Answer:      80
# Calc:  Copy(80)
#
# Prediction:  911
# Answer:      911
# Calc:  Copy(911)
#
# Prediction:  169
# Answer:      19
# Calc:  Round(223.32,0)
#
# Prediction:  17
# Answer:      17
# Calc:  Copy(17)
#
# Prediction:  33
# Answer:      33
# Calc:  Copy(33)
#
# Prediction:  1940
# Answer:      1940
# Calc:  Copy(1940)
#
# Prediction:  9
# Answer:      9
# Calc:  Round(Paraphrase(9,350,K),0)
#
# Prediction:  73
# Answer:      40
# Calc:  Subtract(2014,1974)
#
# Prediction:  20
# Answer:      20
# Calc:  Paraphrase(20,000,K)
#
# Prediction:  3
# Answer:      3
# Calc:  Paraphrase(3,000,K)
#
# Prediction:  57
# Answer:      57
# Calc:  Copy(57)
#
# Prediction:  5
# Answer:      5
# Calc:  Copy(5)
#
# Prediction:  200
# Answer:      200
# Calc:  Copy(200)
#
# Prediction:  10
# Answer:      12
# Calc:  Copy(12)
#
# Prediction:  6
# Answer:      6
# Calc:  Trans(six)
#
# Prediction:  100
# Answer:      100
# Calc:  Copy(100)
#
# Prediction:  1960
# Answer:      1960
# Calc:  Copy(1960)
#
# Prediction:  12
# Answer:      10
# Calc:  Copy(10)
#
# Prediction:  400
# Answer:      400
# Calc:  Paraphrase(400,000,K)
#
# Prediction:  3
# Answer:      3
# Calc:  Trans(three)
#
# Prediction:  185
# Answer:      185
# Calc:  Copy(185)
#
# Prediction:  3
# Answer:      3
# Calc:  Copy(3)
#
# Prediction:  16
# Answer:      16
# Calc:  Copy(16)
#
# Prediction:  2012
# Answer:      2012
# Calc:  Copy(2012)
#
# Prediction:  27
# Answer:      27
# Calc:  Copy(27)
#
# Prediction:  120
# Answer:      120
# Calc:  Paraphrase(120,000,K)
#
# Prediction:  47
# Answer:      75
# Calc:  Multiply(Trans(Three-quarters))
#
# Prediction:  101
# Answer:      100
# Calc:  Copy(100)
#
# Prediction:  136
# Answer:      136
# Calc:  Copy(136)
#
# Prediction:  15
# Answer:      15
# Calc:  Copy(15)
#
# Prediction:  6
# Answer:      6
# Calc:  Trans(Six)
#
# Prediction:  50
# Answer:      50
# Calc:  Copy(50)
#
# Prediction:  17
# Answer:      17
# Calc:  Copy(17)
#
# Prediction:  9
# Answer:      9
# Calc:  Paraphrase(9,000,K)
#
# Prediction:  1
# Answer:      1.5
# Calc:  Copy(1.5)
#
# Prediction:  5
# Answer:      5
# Calc:  Paraphrase(5,000,K)
#
# Prediction:  2011
# Answer:      2011
# Calc:  Copy(2011)
#
# Prediction:  81
# Answer:      81
# Calc:  Copy(81)
#
# Prediction:  1
# Answer:      1
# Calc:  Trans(first)
#
# Prediction:  1957
# Answer:      1957
# Calc:  Copy(1957)
#
# Prediction:  2005
# Answer:      2005
# Calc:  Copy(2005)
#
# Prediction:  36
# Answer:      36
# Calc:  Copy(36)
#
# Prediction:  10
# Answer:      12
# Calc:  Divide(24,2)
#
# Prediction:  750
# Answer:      750
# Calc:  Copy(750)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  15
# Answer:      15
# Calc:  Copy(15)
#
# Prediction:  5
# Answer:      5
# Calc:  Trans(Five)
#
# Prediction:  105
# Answer:      105
# Calc:  Copy(105)
#
# Prediction:  1
# Answer:      1
# Calc:  Trans(first)
#
# Prediction:  3
# Answer:      3
# Calc:  Copy(3)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(second)
#
# Prediction:  2010
# Answer:      2010
# Calc:  Copy(2010)
#
# Prediction:  83
# Answer:      83
# Calc:  Copy(83)
#
# Prediction:  2
# Answer:      2
# Calc:  Copy(2)
#
# Prediction:  7
# Answer:      7
# Calc:  Copy(7)
#
# Prediction:  2014
# Answer:      2014
# Calc:  Copy(2014)
#
# Prediction:  3
# Answer:      1
# Calc:  Trans(One)
#
# Prediction:  24
# Answer:      24
# Calc:  Copy(24)
#
# Prediction:  3
# Answer:      3
# Calc:  Copy(3)
#
# Prediction:  11
# Answer:      11
# Calc:  Copy(11)
#
# Prediction:  6
# Answer:      25
# Calc:  Add(Trans(six),Add(19,Span(the driver suffered a broken nose)))
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  Near
# Answer:      1984
# Calc:  Copy(1984)
#
# Prediction:  0
# Answer:      0
# Calc:  Copy(0)
#
# Prediction:  4
# Answer:      4
# Calc:  Copy(4)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  12
# Answer:      12
# Calc:  Trans(a dozen)
#
# Prediction:  3
# Answer:      3
# Calc:  Trans(three)
#
# Prediction:  3
# Answer:      3
# Calc:  Trans(third)
#
# Prediction:  2
# Answer:      1
# Calc:  Copy(1)
#
# Prediction:  13
# Answer:      13
# Calc:  Copy(13)
#
# Prediction:  40
# Answer:      40
# Calc:  Paraphrase(40,000,K)
#
# Prediction:  40
# Answer:      40
# Calc:  Copy(40)
#
# Prediction:  7
# Answer:      7
# Calc:  Copy(7)
#
# Prediction:  12
# Answer:      12
# Calc:  Trans(dozen)
#
# Prediction:  8
# Answer:      8
# Calc:  Copy(8)
#
# Prediction:  40
# Answer:      40
# Calc:  Copy(40)
#
# Prediction:  500
# Answer:      12
# Calc:  Round(Paraphrase(11,867,K),0)
#
# Prediction:  20
# Answer:      20
# Calc:  Copy(20)
#
# Prediction:  29
# Answer:      29
# Calc:  Copy(29)
#
# Prediction:  1
# Answer:      1.2
# Calc:  Copy(1.2)
#
# Prediction:  1908
# Answer:      1845
# Calc:  Copy(1845)
#
# Prediction:  1
# Answer:      1
# Calc:  Copy(1)
#
# Prediction:  80
# Answer:      80
# Calc:  Copy(80)
#
# Prediction:  168
# Answer:      168
# Calc:  Copy(168)
#
# Prediction:  Threat
# Answer:      9/11
# Calc:  Copy(9/11)
#
# Prediction:  40
# Answer:      30
# Calc:  Copy(30)
#
# Prediction:  4
# Answer:      4.2
# Calc:  Copy(4.2)
#
# Prediction:  7
# Answer:      7
# Calc:  Copy(7)
#
# Prediction:  32
# Answer:      32
# Calc:  Copy(32)
#
# Prediction:  6
# Answer:      2
# Calc:  Copy(2)
#
# Prediction:  5
# Answer:      7
# Calc:  Trans(seventh)
#
# Prediction:  2
# Answer:      2
# Calc:  Copy(2)
#
# Prediction:  31
# Answer:      31
# Calc:  Copy(31)
#
# Prediction:  33
# Answer:      30
# Calc:  Copy(30)
#
# Prediction:  13
# Answer:      13
# Calc:  Paraphrase(13,000,k)
#
# Prediction:  6
# Answer:      136
# Calc:  Copy(136)
#
# Prediction:  130
# Answer:      130
# Calc:  Paraphrase(130,000,K)
#
# Prediction:  9
# Answer:      9
# Calc:  Trans(Nine)
#
# Prediction:  13
# Answer:      13
# Calc:  Copy(13)
#
# Prediction:  31
# Answer:      31
# Calc:  Copy(31)
#
# Prediction:  90
# Answer:      90
# Calc:  Copy(90)
#
# Prediction:  97
# Answer:      97
# Calc:  Copy(97)
#
# Prediction:  13
# Answer:      13
# Calc:  Copy(13)
#
# Prediction:  2
# Answer:      2
# Calc:  Copy(2)
#
# Prediction:  96
# Answer:      96
# Calc:  Copy(96)
#
# Prediction:  2
# Answer:      2
# Calc:  Copy(2)
#
# Prediction:  38
# Answer:      38
# Calc:  Copy(38)
#
# Prediction:  18
# Answer:      21
# Calc:  Copy(21)
#
# Prediction:  58
# Answer:      58
# Calc:  Copy(58)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  1
# Answer:      1.1
# Calc:  Copy(1.1)
#
# Prediction:  70
# Answer:      72
# Calc:  Trans(Seventy-two)
#
# Prediction:  45
# Answer:      45
# Calc:  Paraphrase(45,000,K)
#
# Prediction:  2
# Answer:      2
# Calc:  Copy(2)
#
# Prediction:  80
# Answer:      80
# Calc:  Copy(80)
#
# Prediction:  1
# Answer:      1
# Calc:  Paraphrase(1,000,K)
#
# Prediction:  15
# Answer:      15
# Calc:  Copy(15)
#
# Prediction:  4
# Answer:      4.4
# Calc:  Copy(4.4)
#
# Prediction:  1
# Answer:      1.2
# Calc:  Copy(1.2)
#
# Prediction:  2012
# Answer:      2012
# Calc:  Copy(2012)
#
# Prediction:  520
# Answer:      500
# Calc:  Paraphrase(500,000,K)
#
# Prediction:  100
# Answer:      100
# Calc:  Copy(100)
#
# Prediction:  1
# Answer:      1
# Calc:  Copy(1)
#
# Prediction:  3
# Answer:      2
# Calc:  Trans(second)
#
# Prediction:  2
# Answer:      2
# Calc:  Copy(2)
#
# Prediction:  1
# Answer:      1
# Calc:  Trans(first)
#
# Prediction:  700
# Answer:      700
# Calc:  Copy(700)
#
# Prediction:  5
# Answer:      3.6
# Calc:  Copy(3.6)
#
# Prediction:  99
# Answer:      31
# Calc:  Round(Multiply(Divide(Subtract(42,29),42),100),0)
#
# Prediction:  3
# Answer:      12
# Calc:  Subtract(2011,1999)
#
# Prediction:  10
# Answer:      10
# Calc:  Copy(10)
#
# Prediction:  1
# Answer:      1
# Calc:  Copy(1)
#
# Prediction:  99
# Answer:      35
# Calc:  Copy(35)
#
# Prediction:  6
# Answer:      6
# Calc:  Trans(six)
#
# Prediction:  4
# Answer:      456
# Calc:  Copy(456)
# Prediction:  1
# Answer:      1
# Calc:  Copy(1)
#
# Prediction:  2015
# Answer:      2015
# Calc:  Copy(2015)
#
# Prediction:  9
# Answer:      9.8
# Calc:  Paraphrase(9,800,K)
#
# Prediction:  6
# Answer:      6
# Calc:  Trans(six)
#
# Prediction:  41
# Answer:      1
# Calc:  Trans(first)
#
# Prediction:  5
# Answer:      5
# Calc:  Trans(five)
#
# Prediction:  200
# Answer:      1,200
# Calc:  Copy(1,200)
#
# Prediction:  15
# Answer:      15
# Calc:  Copy(15)
#
# Prediction:  66
# Answer:      66
# Calc:  Copy(66)
#
# Prediction:  2
# Answer:      2
# Calc:  Copy(2)
#
# Prediction:  7
# Answer:      7
# Calc:  Copy(7)
#
# Prediction:  28
# Answer:      73
# Calc:  Add(28,45)
#
# Prediction:  10
# Answer:      10
# Calc:  Paraphrase(10,000,K)
#
# Prediction:  3
# Answer:      3
# Calc:  Trans(three)
#
# Prediction:  10
# Answer:      11
# Calc:  Copy(11)
#
# Prediction:  27
# Answer:      27.2
# Calc:  Round(Multiply(Divide(Subtract(5.26,3.83),5.26),100),1)
#
# Prediction:  100
# Answer:      100
# Calc:  Copy(100)
#
# Prediction:  10
# Answer:      10
# Calc:  Copy(10)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  2
# Answer:      2.4
# Calc:  Copy(2.4)
#
# Prediction:  400
# Answer:      400
# Calc:  Copy(400)
#
# Prediction:  35
# Answer:      45
# Calc:  Paraphrase(45,000,K)
#
# Prediction:  40
# Answer:      40
# Calc:  Copy(40)
#
# Prediction:  35
# Answer:      35
# Calc:  Copy(35)
#
# Prediction:  3
# Answer:      15
# Calc:  Copy(15)
#
# Prediction:  400
# Answer:      400
# Calc:  Copy(400)
#
# Prediction:  22
# Answer:      22
# Calc:  Copy(22)
#
# Prediction:  28
# Answer:      28
# Calc:  Paraphrase(28,000,K)
#
# Prediction:  57
# Answer:      23,344
# Calc:  Copy(23,344)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(Two)
#
# Prediction:  100
# Answer:      100
# Calc:  Copy(100)
#
# Prediction:  5
# Answer:      30
# Calc:  Copy(30)
#
# Prediction:  1
# Answer:      1
# Calc:  Copy(1)
#
# Prediction:  2
# Answer:      2.1
# Calc:  Copy(2.1)
#
# Prediction:  10
# Answer:      10
# Calc:  Paraphrase(10,000,k)
#
# Prediction:  50
# Answer:      50
# Calc:  Copy(50)
#
# Prediction:  4
# Answer:      4
# Calc:  Copy(4)
#
# Prediction:  150
# Answer:      150
# Calc:  Copy(150)
#
# Prediction:  33
# Answer:      33
# Calc:  Copy(33)
#
# Prediction:  38
# Answer:      38
# Calc:  Round(38.47,0)
#
# Prediction:  23
# Answer:      23
# Calc:  Round(23.3,0)
#
# Prediction:  90
# Answer:      25
# Calc:  Multiply(Trans(a quarter),100)
#
# Prediction:  2
# Answer:      2.77
# Calc:  Copy(2.77)
#
# Prediction:  200
# Answer:      200
# Calc:  Copy(200)
#
# Prediction:  215
# Answer:      215
# Calc:  Copy(215)
#
# Prediction:  1
# Answer:      1
# Calc:  Trans(first)
#
# Prediction:  100
# Answer:      100
# Calc:  Copy(100)
#
# Prediction:  5
# Answer:      5
# Calc:  Trans(five)
#
# Prediction:  911
# Answer:      9/11
# Calc:  Copy(9/11)
#
# Prediction:  38
# Answer:      38
# Calc:  Copy(38)
#
# Prediction:  2012
# Answer:      2012
# Calc:  Copy(2012)
#
# Prediction:  20
# Answer:      20
# Calc:  Copy(20)
#
# Prediction:  8
# Answer:      8
# Calc:  Trans(eight)
#
# Prediction:  21
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  1
# Answer:      1.2
# Calc:  Copy(1.2)
#
# Prediction:  6
# Answer:      6
# Calc:  Trans(Six)
#
# Prediction:  23
# Answer:      1958
# Calc:  Subtract(2008,50)
#
# Prediction:  5
# Answer:      5
# Calc:  Copy(5)
#
# Prediction:  05
# Answer:      05
# Calc:  Subtract(2005,2000)
#
# Prediction:  30
# Answer:      30
# Calc:  Copy(30)
#
# Prediction:  4
# Answer:      4.4
# Calc:  Paraphrase(4,400,K)
#
# Prediction:  12
# Answer:      12
# Calc:  Copy(12)
#
# Prediction:  1
# Answer:      1
# Calc:  Copy(1)
#
# Prediction:  3
# Answer:      3
# Calc:  Copy(3)
#
# Prediction:  10
# Answer:      10
# Calc:  Copy(10)
#
# Prediction:  25
# Answer:      260
# Calc:  Copy(260)
#
# Prediction:  18
# Answer:      18
# Calc:  Copy(18)
#
# Prediction:  105
# Answer:      105
# Calc:  Copy(105)
#
# Prediction:  60
# Answer:      560
# Calc:  Copy(560)
#
# Prediction:  1
# Answer:      2
# Calc:  Copy(2)
#
# Prediction:  10
# Answer:      10
# Calc:  Copy(10)
#
# Prediction:  2011
# Answer:      2011
# Calc:  Copy(2011)
#
# Prediction:  5
# Answer:      5
# Calc:  Copy(5)
#
# Prediction:  74
# Answer:      74
# Calc:  Copy(74)
#
# Prediction:  10
# Answer:      10
# Calc:  Paraphrase(10,000,K)
#
# Prediction:  1996
# Answer:      1996
# Calc:  Copy(1996)
#
# Prediction:  27
# Answer:      27
# Calc:  Copy(27)
#
# Prediction:  18
# Answer:      18
# Calc:  Copy(18)
#
# Prediction:  5
# Answer:      5
# Calc:  Trans(five)
#
# Prediction:  10
# Answer:      10
# Calc:  Copy(10)
#
# Prediction:  240
# Answer:      240
# Calc:  Copy(240)
#
# Prediction:  70
# Answer:      70
# Calc:  Copy(70)
#
# Prediction:  4
# Answer:      4
# Calc:  Copy(4)
#
# Prediction:  24
# Answer:      24
# Calc:  Copy(24)
#
# Prediction:  681
# Answer:      681
# Calc:  Copy(681)
#
# Prediction:  101
# Answer:      101
# Calc:  Copy(101)
#
# Prediction:  14
# Answer:      14
# Calc:  Copy(14)
#
# Prediction:  20
# Answer:      20
# Calc:  Copy(20)
#
# Prediction:  10
# Answer:      10
# Calc:  Copy(10)
#
# Prediction:  24
# Answer:      24
# Calc:  Paraphrase(24,000,K)
#
# Prediction:  6
# Answer:      5
# Calc:  Subtract(Trans(Six),Span(him))
#
# Prediction:  45
# Answer:      50
# Calc:  Paraphrase(50,000,K)
#
# Prediction:  5
# Answer:      5,000
# Calc:  Copy(5,000)
#
# Prediction:  8
# Answer:      8
# Calc:  Copy(8)
#
# Prediction:  68
# Answer:      68
# Calc:  Copy(68)
#
# Prediction:  85
# Answer:      85
# Calc:  Copy(85)
#
# Prediction:  8
# Answer:      8
# Calc:  Copy(8)
#
# Prediction:  1
# Answer:      2.9
# Calc:  Copy(2.9)
#
# Prediction:  1
# Answer:      1.7
# Calc:  Copy(1.7)
#
# Prediction:  22
# Answer:      22
# Calc:  Copy(22)
#
# Prediction:  8
# Answer:      8
# Calc:  Copy(8)
#
# Prediction:  70
# Answer:      70
# Calc:  Copy(70)
#
# Prediction:  35
# Answer:      35
# Calc:  Copy(35)
#
# Prediction:  22
# Answer:      22
# Calc:  Copy(22)
#
# Prediction:  5
# Answer:      5
# Calc:  Trans(five)
#
# Prediction:  5
# Answer:      5
# Calc:  Trans(five)
#
# Prediction:  17
# Answer:      17
# Calc:  Copy(17)
#
# Prediction:  60
# Answer:      60
# Calc:  Copy(60)
#
# Prediction:  1
# Answer:      1
# Calc:  Paraphrase(1,000,K)
#
# Prediction:  3
# Answer:      3
# Calc:  Trans(three)
#
# Prediction:  700
# Answer:      700
# Calc:  Paraphrase(700,000,K)
#
# Prediction:  1964
# Answer:      1964
# Calc:  Copy(1964)
#
# Prediction:  09
# Answer:      09
# Calc:  Subtract(2009,2000)
#
# Prediction:  30
# Answer:      30
# Calc:  Copy(30)
#
# Prediction:  5
# Answer:      5
# Calc:  Trans(five)
#
# Prediction:  1
# Answer:      1
# Calc:  Copy(1)
#
# Prediction:  30
# Answer:      30
# Calc:  Copy(30)
#
# Prediction:  4
# Answer:      4
# Calc:  Copy(4)
#
# Prediction:  11
# Answer:      11
# Calc:  Copy(11)
#
# Prediction:  6
# Answer:      6
# Calc:  Trans(six)
#
# Prediction:  20
# Answer:      20
# Calc:  Copy(20)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  71
# Answer:      71
# Calc:  Copy(71)
#
# Prediction:  41
# Answer:      41
# Calc:  Copy(41)
#
# Prediction:  3
# Answer:      5
# Calc:  Round(Subtract(8.5,3.8),0)
#
# Prediction:  2011
# Answer:      2011
# Calc:  Copy(2011)
#
# Prediction:  5
# Answer:      5
# Calc:  Copy(5)
#
# Prediction:  140
# Answer:      160
# Calc:  Paraphrase(160,000,K)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  60
# Answer:      60
# Calc:  Copy(60)
#
# Prediction:  8
# Answer:      8
# Calc:  Copy(8)
#
# Prediction:  40
# Answer:      40
# Calc:  Copy(40)
#
# Prediction:  20
# Answer:      20
# Calc:  Paraphrase(20,000,K)
#
# Prediction:  100
# Answer:      100
# Calc:  Copy(100)
#
# Prediction:  9
# Answer:      68
# Calc:  Copy(68)
#
# Prediction:  10
# Answer:      10
# Calc:  Paraphrase(10,000,K)
#
# Prediction:  3
# Answer:      3
# Calc:  Copy(3)
#
# Prediction:  21
# Answer:      21
# Calc:  Copy(21)
#
# Prediction:  3
# Answer:      2014
# Calc:  Add(2013,1)
#
# Prediction:  1966
# Answer:      1966
# Calc:  Copy(1966)
#
# Prediction:  12
# Answer:      12
# Calc:  Copy(12)
#
# Prediction:  150
# Answer:      150
# Calc:  Copy(150)
#
# Prediction:  10
# Answer:      10
# Calc:  Copy(10)
#
# Prediction:  3
# Answer:      3
# Calc:  Copy(3)
#
# Prediction:  248
# Answer:      248
# Calc:  Round(248.02,0)
#
# Prediction:  65
# Answer:      65
# Calc:  Copy(65)
#
# Prediction:  26
# Answer:      26
# Calc:  Copy(26)
#
# Prediction:  2
# Answer:      2
# Calc:  Copy(2)
#
# Prediction:  2
# Answer:      2
# Calc:  Copy(2)
#
# Prediction:  49
# Answer:      49
# Calc:  Copy(49)
#
# Prediction:  900
# Answer:      900
# Calc:  Paraphrase(900,000,K)
#
# Prediction:  3
# Answer:      3
# Calc:  Copy(3)
#
# Prediction:  24
# Answer:      24
# Calc:  Copy(24)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  40
# Answer:      40
# Calc:  Copy(40)
#
# Prediction:  22
# Answer:      22
# Calc:  Copy(22)
#
# Prediction:  21
# Answer:      21
# Calc:  Copy(21)
#
# Prediction:  3
# Answer:      3.5
# Calc:  Copy(3.5)
#
# Prediction:  88
# Answer:      89
# Calc:  Round(88.81,0)
#
# Prediction:  2016
# Answer:      2016
# Calc:  Copy(2016)
# Prediction:  1
# Answer:      1.2
# Calc:  Copy(1.2)
#
# Prediction:  250
# Answer:      250
# Calc:  Copy(250)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(second)
#
# Prediction:  25
# Answer:      25
# Calc:  Paraphrase(25,000,K)
#
# Prediction:  5
# Answer:      32
# Calc:  Trans(Thirty-two)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  9
# Answer:      9
# Calc:  Trans(nine)
#
# Prediction:  2
# Answer:      2
# Calc:  Paraphrase(2,000,K)
#
# Prediction:  3
# Answer:      3.4
# Calc:  Copy(3.4)
#
# Prediction:  New
# Answer:      1906
# Calc:  Copy(1906)
#
# Prediction:  3
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  8
# Answer:      8
# Calc:  Copy(8)
#
# Prediction:  3
# Answer:      1.3
# Calc:  Paraphrase(1,300,K)
#
# Prediction:  81
# Answer:      81
# Calc:  Copy(81)
#
# Prediction:  1
# Answer:      1
# Calc:  Trans(first)
#
# Prediction:  8
# Answer:      8
# Calc:  Copy(8)
#
# Prediction:  11
# Answer:      192
# Calc:  Copy(192)
#
# Prediction:  300
# Answer:      20
# Calc:  Copy(20)
#
# Prediction:  100
# Answer:      100
# Calc:  Copy(100)
#
# Prediction:  16
# Answer:      16
# Calc:  Copy(16)
#
# Prediction:  18
# Answer:      18
# Calc:  Copy(18)
#
# Prediction:  1
# Answer:      1
# Calc:  Copy(1)
#
# Prediction:  50
# Answer:      1
# Calc:  Copy(1)
#
# Prediction:  100
# Answer:      100
# Calc:  Copy(100)
#
# Prediction:  11
# Answer:      12
# Calc:  Copy(12)
#
# Prediction:  30
# Answer:      30
# Calc:  Copy(30)
#
# Prediction:  100
# Answer:      100
# Calc:  Copy(100)
#
# Prediction:  211
# Answer:      211
# Calc:  Copy(211)
#
# Prediction:  370
# Answer:      370
# Calc:  Copy(370)
#
# Prediction:  68
# Answer:      68
# Calc:  Copy(68)
#
# Prediction:  23
# Answer:      23
# Calc:  Copy(23)
#
# Prediction:  13
# Answer:      13.5
# Calc:  Copy(13.5)
#
# Prediction:  2004
# Answer:      9/11
# Calc:  Copy(9/11)
#
# Prediction:  88
# Answer:      88
# Calc:  Copy(88)
#
# Prediction:  1
# Answer:      1
# Calc:  Copy(1)
#
# Prediction:  08
# Answer:      08
# Calc:  Subtract(2008,2000)
#
# Prediction:  3
# Answer:      3
# Calc:  Trans(three)
#
# Prediction:  47
# Answer:      47
# Calc:  Copy(47)
#
# Prediction:  1
# Answer:      81
# Calc:  Round(Paraphrase(81,314,K),0)
#
# Prediction:  3
# Answer:      3
# Calc:  Copy(3)
#
# Prediction:  3
# Answer:      2
# Calc:  Trans(second)
#
# Prediction:  7
# Answer:      7
# Calc:  Copy(7)
#
# Prediction:  50
# Answer:      50
# Calc:  Copy(50)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  4
# Answer:      4
# Calc:  Copy(4)
#
# Prediction:  11
# Answer:      11
# Calc:  Copy(11)
#
# Prediction:  688
# Answer:      688
# Calc:  Copy(688)
#
# Prediction:  1
# Answer:      1
# Calc:  Paraphrase(1,000,K)
#
# Prediction:  80
# Answer:      80
# Calc:  Copy(80)
#
# Prediction:  38
# Answer:      50
# Calc:  Add(12,38)
#
# Prediction:  15
# Answer:      15
# Calc:  Copy(15)
#
# Prediction:  80
# Answer:      80
# Calc:  Copy(80)
#
# Prediction:  7
# Answer:      7.5
# Calc:  Paraphrase(7,500,K)
#
# Prediction:  3
# Answer:      3
# Calc:  Trans(three)
#
# Prediction:  13
# Answer:      13
# Calc:  Copy(13)
#
# Prediction:  14
# Answer:      14
# Calc:  Copy(14)
#
# Prediction:  2
# Answer:      2
# Calc:  Copy(2)
#
# Prediction:  10
# Answer:      10
# Calc:  Copy(10)
#
# Prediction:  2011
# Answer:      2011
# Calc:  Copy(2011)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(Two)
#
# Prediction:  8
# Answer:      11
# Calc:  Copy(11)
#
# Prediction:  2011
# Answer:      2011
# Calc:  Copy(2011)
#
# Prediction:  3
# Answer:      3
# Calc:  Copy(3)
#
# Prediction:  6
# Answer:      6
# Calc:  Trans(six)
#
# Prediction:  5
# Answer:      5
# Calc:  Trans(five)
#
# Prediction:  74
# Answer:      74
# Calc:  Copy(74)
#
# Prediction:  700
# Answer:      700
# Calc:  Copy(700)
#
# Prediction:  70
# Answer:      70
# Calc:  Round(70.3,0)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(second)
#
# Prediction:  206
# Answer:      205
# Calc:  Round(204.6,0)
#
# Prediction:  3
# Answer:      3
# Calc:  Copy(3)
#
# Prediction:  1
# Answer:      1
# Calc:  Copy(1)
#
# Prediction:  328
# Answer:      328
# Calc:  Paraphrase(328,000,K)
#
# Prediction:  168
# Answer:      168
# Calc:  Round(168.46,0)
#
# Prediction:  28
# Answer:      28
# Calc:  Copy(28)
#
# Prediction:  30
# Answer:      10
# Calc:  Copy(10)
#
# Prediction:  3
# Answer:      20
# Calc:  Copy(20)
#
# Prediction:  97
# Answer:      97
# Calc:  Copy(97)
#
# Prediction:  47
# Answer:      47
# Calc:  Copy(47)
#
# Prediction:  11
# Answer:      11
# Calc:  Copy(11)
#
# Prediction:  3
# Answer:      3
# Calc:  Trans(three)
#
# Prediction:  5
# Answer:      5
# Calc:  Copy(5)
#
# Prediction:  50
# Answer:      50
# Calc:  Copy(50)
#
# Prediction:  60
# Answer:      60
# Calc:  Copy(60)
#
# Prediction:  70
# Answer:      70
# Calc:  Copy(70)
#
# Prediction:  6
# Answer:      4
# Calc:  Trans(four)
#
# Prediction:  142
# Answer:      142
# Calc:  Copy(142)
#
# Prediction:  10
# Answer:      10
# Calc:  Copy(10)
#
# Prediction:  4
# Answer:      11
# Calc:  Copy(11)
#
# Prediction:  170
# Answer:      170
# Calc:  Copy(170)
#
# Prediction:  11
# Answer:      14
# Calc:  Copy(14)
#
# Prediction:  12
# Answer:      12
# Calc:  Copy(12)
#
# Prediction:  3
# Answer:      3
# Calc:  Trans(three)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  3
# Answer:      3
# Calc:  Copy(3)
#
# Prediction:  4
# Answer:      14
# Calc:  Trans(Fourteen)
#
# Prediction:  1
# Answer:      99
# Calc:  Subtract(100,1)
#
# Prediction:  95
# Answer:      95
# Calc:  Copy(95)
#
# Prediction:  51
# Answer:      24
# Calc:  Round(Paraphrase(24,298.93,K),0)
#
# Prediction:  252
# Answer:      1,018
# Calc:  Copy(1,018)
#
# Prediction:  90
# Answer:      90
# Calc:  Copy(90)
#
# Prediction:  1970
# Answer:      1970
# Calc:  Copy(1970)
#
# Prediction:  16
# Answer:      16
# Calc:  Copy(16)
#
# Prediction:  87
# Answer:      87
# Calc:  Copy(87)
#
# Prediction:  48
# Answer:      48
# Calc:  Copy(48)
#
# Prediction:  16
# Answer:      16
# Calc:  Copy(16)
#
# Prediction:  1988
# Answer:      1988
# Calc:  Copy(1988)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  15
# Answer:      15
# Calc:  Copy(15)
#
# Prediction:  100
# Answer:      100
# Calc:  Copy(100)
#
# Prediction:  2
# Answer:      2
# Calc:  Copy(2)
#
# Prediction:  1982
# Answer:      1982
# Calc:  Copy(1982)
#
# Prediction:  5
# Answer:      5
# Calc:  Copy(5)
#
# Prediction:  20
# Answer:      20
# Calc:  Copy(20)
#
# Prediction:  Affect
# Answer:      800
# Calc:  Copy(800)
#
# Prediction:  45
# Answer:      45
# Calc:  Copy(45)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  3
# Answer:      3
# Calc:  Trans(three)
#
# Prediction:  15
# Answer:      15
# Calc:  Copy(15)
#
# Prediction:  20
# Answer:      20
# Calc:  Copy(20)
#
# Prediction:  65
# Answer:      65
# Calc:  Copy(65)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(second)
#
# Prediction:  17
# Answer:      17
# Calc:  Copy(17)
#
# Prediction:  2
# Answer:      2
# Calc:  Copy(2)
#
# Prediction:  1997
# Answer:      1997
# Calc:  Copy(1997)
#
# Prediction:  25
# Answer:      25
# Calc:  Round(25.5,1)
#
# Prediction:  13
# Answer:      13
# Calc:  Copy(13)
#
# Prediction:  100
# Answer:      100
# Calc:  Copy(100)
#
# Prediction:  8
# Answer:      8
# Calc:  Trans(eight)
#
# Prediction:  25
# Answer:      25
# Calc:  Copy(25)
#
# Prediction:  83
# Answer:      83
# Calc:  Copy(83)
#
# Prediction:  10
# Answer:      10
# Calc:  Copy(10)
#
# Prediction:  3
# Answer:      1.3
# Calc:  Copy(1.3)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  67
# Answer:      67
# Calc:  Copy(67)
#
# Prediction:  8
# Answer:      8
# Calc:  Copy(8)
#
# Prediction:  16
# Answer:      16
# Calc:  Copy(16)
#
# Prediction:  1
# Answer:      1
# Calc:  Copy(1)
#
# Prediction:  86
# Answer:      861
# Calc:  Paraphrase(861,000,K)
#
# Prediction:  90
# Answer:      90
# Calc:  Copy(90)
#
# Prediction:  300
# Answer:      300
# Calc:  Copy(300)
#
# Prediction:  66
# Answer:      66
# Calc:  Copy(66)
#
# Prediction:  2
# Answer:      2
# Calc:  Copy(2)
#
# Prediction:  4
# Answer:      4
# Calc:  Copy(4)
#
# Prediction:  54
# Answer:      54
# Calc:  Copy(54)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(Two)
#
# Prediction:  9
# Answer:      9/11
# Calc:  Copy(9/11)
#
# Prediction:  5
# Answer:      5
# Calc:  Paraphrase(5,000,K)
#
# Prediction:  Is
# Answer:      5
# Calc:  Trans(five)
#
# Prediction:  19
# Answer:      19,000
# Calc:  Copy(19,000)
#
# Prediction:  600
# Answer:      1,600
# Calc:  Copy(1,600)
#
# Prediction:  650
# Answer:      650
# Calc:  Paraphrase(650,000,K)
#
# Prediction:  31
# Answer:      31
# Calc:  Copy(31)
#
# Prediction:  40
# Answer:      40
# Calc:  Copy(40)
#
# Prediction:  2
# Answer:      2
# Calc:  Paraphrase(2,000,K)
#
# Prediction:  380
# Answer:      380
# Calc:  Copy(380)
#
# Prediction:  200
# Answer:      221
# Calc:  Copy(221)
#
# Prediction:  47
# Answer:      150
# Calc:  Copy(150)
#
# Prediction:  7
# Answer:      8
# Calc:  Round(7.7,0)
#
# Prediction:  50
# Answer:      50
# Calc:  Copy(50)
#
# Prediction:  8
# Answer:      8
# Calc:  Copy(8)
#
# Prediction:  94
# Answer:      94
# Calc:  Copy(94)
# Prediction:  200
# Answer:      200
# Calc:  Copy(200)
#
# Prediction:  10
# Answer:      10
# Calc:  Copy(10)
#
# Prediction:  107
# Answer:      107
# Calc:  Copy(107)
#
# Prediction:  5
# Answer:      5
# Calc:  Trans(Five)
#
# Prediction:  53
# Answer:      53
# Calc:  Copy(53)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(Two)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  25
# Answer:      25
# Calc:  Copy(25)
#
# Prediction:  7
# Answer:      7
# Calc:  Copy(7)
#
# Prediction:  248
# Answer:      248
# Calc:  Copy(248)
#
# Prediction:  35
# Answer:      35
# Calc:  Copy(35)
#
# Prediction:  900
# Answer:      900
# Calc:  Copy(900)
#
# Prediction:  100
# Answer:      100
# Calc:  Copy(100)
#
# Prediction:  10
# Answer:      11
# Calc:  Round(10.9,0)
#
# Prediction:  4
# Answer:      4
# Calc:  Copy(4)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  10
# Answer:      10
# Calc:  Copy(10)
#
# Prediction:  60
# Answer:      60
# Calc:  Copy(60)
#
# Prediction:  20
# Answer:      20
# Calc:  Copy(20)
#
# Prediction:  13
# Answer:      13
# Calc:  Copy(13)
#
# Prediction:  11
# Answer:      11
# Calc:  Copy(11)
#
# Prediction:  20
# Answer:      1990
# Calc:  Copy(1990)
#
# Prediction:  35
# Answer:      35
# Calc:  Copy(35)
#
# Prediction:  187
# Answer:      2
# Calc:  Copy(2)
#
# Prediction:  183
# Answer:      183
# Calc:  Copy(183)
#
# Prediction:  25
# Answer:      25
# Calc:  Copy(25)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  500
# Answer:      2,500
# Calc:  Copy(2,500)
#
# Prediction:  6
# Answer:      6
# Calc:  Round(6.2,0)
#
# Prediction:  18
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  144
# Answer:      144
# Calc:  Copy(144)
#
# Prediction:  29
# Answer:      29
# Calc:  Copy(29)
#
# Prediction:  3
# Answer:      3
# Calc:  Copy(3)
#
# Prediction:  10
# Answer:      10
# Calc:  Copy(10)
#
# Prediction:  283
# Answer:      283
# Calc:  Copy(283)
#
# Prediction:  20
# Answer:      20
# Calc:  Copy(20)
#
# Prediction:  21
# Answer:      8.5
# Calc:  Copy(8.5)
#
# Prediction:  52
# Answer:      52
# Calc:  Copy(52)
#
# Prediction:  3
# Answer:      3
# Calc:  Trans(three)
#
# Prediction:  51
# Answer:      51
# Calc:  Copy(51)
#
# Prediction:  1
# Answer:      1
# Calc:  Copy(1)
#
# Prediction:  1
# Answer:      1.1
# Calc:  Round(1.11,1)
#
# Prediction:  4
# Answer:      4
# Calc:  Trans(four)
#
# Prediction:  1
# Answer:      1
# Calc:  Trans(first)
#
# Prediction:  12
# Answer:      12
# Calc:  Copy(12)
#
# Prediction:  53
# Answer:      53
# Calc:  Copy(53)
#
# Prediction:  5
# Answer:      5
# Calc:  Copy(5)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  13
# Answer:      13
# Calc:  Copy(13)
#
# Prediction:  15
# Answer:      15
# Calc:  Copy(15)
#
# Prediction:  74
# Answer:      74
# Calc:  Copy(74)
#
# Prediction:  4
# Answer:      4
# Calc:  Copy(4)
#
# Prediction:  10
# Answer:      10
# Calc:  Copy(10)
#
# Prediction:  59
# Answer:      59
# Calc:  Copy(59)
#
# Prediction:  10
# Answer:      10
# Calc:  Copy(10)
#
# Prediction:  3
# Answer:      3
# Calc:  Copy(3)
#
# Prediction:  35
# Answer:      35
# Calc:  Copy(35)
#
# Prediction:  4
# Answer:      4
# Calc:  Trans(four)
#
# Prediction:  10
# Answer:      10
# Calc:  Copy(10)
#
# Prediction:  2008
# Answer:      2008
# Calc:  Copy(2008)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(second)
#
# Prediction:  87
# Answer:      87
# Calc:  Copy(87)
#
# Prediction:  88
# Answer:      88
# Calc:  Copy(88)
#
# Prediction:  56
# Answer:      56.2
# Calc:  Copy(56.2)
#
# Prediction:  10
# Answer:      10
# Calc:  Copy(10)
#
# Prediction:  3
# Answer:      3.4
# Calc:  Copy(3.4)
#
# Prediction:  50
# Answer:      50
# Calc:  Copy(50)
#
# Prediction:  44
# Answer:      45
# Calc:  Round(44.7,0)
#
# Prediction:  53
# Answer:      136
# Calc:  Copy(136)
#
# Prediction:  23
# Answer:      23
# Calc:  Copy(23)
#
# Prediction:  10
# Answer:      10
# Calc:  Copy(10)
#
# Prediction:  1
# Answer:      1
# Calc:  Copy(1)
#
# Prediction:  10
# Answer:      10
# Calc:  Copy(10)
#
# Prediction:  911
# Answer:      911
# Calc:  Copy(911)
#
# Prediction:  24
# Answer:      24
# Calc:  Copy(24)
#
# Prediction:  1
# Answer:      1.5
# Calc:  Copy(1.5)
#
# Prediction:  2
# Answer:      2
# Calc:  Copy(2)
#
# Prediction:  9
# Answer:      9
# Calc:  Copy(9)
#
# Prediction:  16
# Answer:      16
# Calc:  Copy(16)
#
# Prediction:  9
# Answer:      9
# Calc:  Trans(nine)
#
# Prediction:  1
# Answer:      1
# Calc:  Copy(1)
#
# Prediction:  83
# Answer:      83
# Calc:  Copy(83)
#
# Prediction:  22
# Answer:      22.3
# Calc:  Copy(22.3)
#
# Prediction:  500
# Answer:      500
# Calc:  Paraphrase(500,000,K)
#
# Prediction:  15
# Answer:      15
# Calc:  Copy(15)
#
# Prediction:  81
# Answer:      81
# Calc:  Copy(81)
#
# Prediction:  7
# Answer:      7
# Calc:  Trans(seven)
#
# Prediction:  2
# Answer:      2
# Calc:  Copy(2)
#
# Prediction:  2
# Answer:      2
# Calc:  Add(Span(A tourist),Span(trainer))
#
# Prediction:  45
# Answer:      45
# Calc:  Copy(45)
#
# Prediction:  2006
# Answer:      2006
# Calc:  Copy(2006)
#
# Prediction:  2
# Answer:      51
# Calc:  Copy(51)
#
# Prediction:  14
# Answer:      14
# Calc:  Copy(14)
#
# Prediction:  300
# Answer:      300
# Calc:  Copy(300)
#
# Prediction:  40
# Answer:      43
# Calc:  Copy(43)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(second)
#
# Prediction:  3
# Answer:      2
# Calc:  Add(Span(Heinz Schymalla),Span(Walter Mai))
#
# Prediction:  1940
# Answer:      1940
# Calc:  Copy(1940)
#
# Prediction:  737
# Answer:      617
# Calc:  Paraphrase(617,000,K)
#
# Prediction:  1
# Answer:      1
# Calc:  Trans(one)
#
# Prediction:  8
# Answer:      8
# Calc:  Copy(8)
#
# Prediction:  61
# Answer:      61
# Calc:  Copy(61)
#
# Prediction:  50
# Answer:      30
# Calc:  Subtract(2015,1985)
#
# Prediction:  1
# Answer:      1
# Calc:  Copy(1)
#
# Prediction:  24
# Answer:      24
# Calc:  Copy(24)
#
# Prediction:  1
# Answer:      1
# Calc:  Copy(1)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  10
# Answer:      8
# Calc:  Trans(eight)
#
# Prediction:  10
# Answer:      10
# Calc:  Copy(10)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(Two)
#
# Prediction:  8
# Answer:      8
# Calc:  Copy(8)
#
# Prediction:  28
# Answer:      28
# Calc:  Copy(28)
#
# Prediction:  4
# Answer:      4
# Calc:  Copy(4)
#
# Prediction:  4
# Answer:      4
# Calc:  Copy(4)
#
# Prediction:  400
# Answer:      400
# Calc:  Copy(400)
#
# Prediction:  82
# Answer:      82
# Calc:  Copy(82)
#
# Prediction:  4
# Answer:      4
# Calc:  Copy(4)
#
# Prediction:  730
# Answer:      730
# Calc:  Paraphrase(730,000,K)
#
# Prediction:  64
# Answer:      64
# Calc:  Subtract(1964,1900)
#
# Prediction:  12
# Answer:      12
# Calc:  Copy(12)
#
# Prediction:  17
# Answer:      17
# Calc:  Copy(17)
#
# Prediction:  1
# Answer:      1
# Calc:  Copy(1)
#
# Prediction:  5
# Answer:      5
# Calc:  Trans(five)
#
# Prediction:  113
# Answer:      113
# Calc:  Round(113.66,0)
#
# Prediction:  2
# Answer:      2,000
# Calc:  Copy(2,000)
#
# Prediction:  71
# Answer:      71
# Calc:  Copy(71)
#
# Prediction:  12
# Answer:      8
# Calc:  Trans(eight)
#
# Prediction:  998
# Answer:      998
# Calc:  Copy(998)
#
# Prediction:  2020
# Answer:      2020
# ...
#
# Prediction:  11
# Answer:      11
# Calc:  Paraphrase(110,000,K)
#
# Prediction:  1
# Answer:      1
# Calc:  Copy(1)
#
# Prediction:  53
# Answer:      53
# Calc:  Copy(53)
#
# Prediction:  83
# Answer:      83
# Calc:  Copy(83)
#
# Prediction:  5
# Answer:      5
# Calc:  Trans(five)
#
# Prediction:  9
# Answer:      9
# Calc:  Copy(9)
#
# Prediction:  9
# Answer:      9
# Calc:  Copy(9)
#
# Prediction:  80
# Answer:      80
# Calc:  Copy(80)
#
# Prediction:  150
# Answer:      150
# Calc:  Copy(150)
#
# Prediction:  500
# Answer:      500
# Calc:  Copy(500)
#
# Prediction:  2
# Answer:      3
# Calc:  Copy(3)
#
# Prediction:  57
# Answer:      2
# Calc:  Copy(2)
#
# Prediction:  19
# Answer:      19
# Calc:  Copy(19)
#
# Prediction:  20
# Answer:      20
# Calc:  Paraphrase(20,000,K)
#
# Prediction:  20
# Answer:      20
# Calc:  Round(20.4,0)
#
# Prediction:  500
# Answer:      500
# Calc:  Copy(500)
#
# Prediction:  2021
# Answer:      2021
# Calc:  Copy(2021)
#
# Prediction:  5
# Answer:      5
# Calc:  Trans(five)
#
# Prediction:  37
# Answer:      37
# Calc:  Copy(37)
#
# Prediction:  5
# Answer:      5
# Calc:  Trans(five)
#
# Prediction:  28
# Answer:      28
# Calc:  Copy(28)
#
# Prediction:  5
# Answer:      5
# Calc:  Trans(five)
#
# Prediction:  13
# Answer:      13
# Calc:  Copy(13)
#
# Prediction:  20
# Answer:      5
# Calc:  Trans(five)
#
# Prediction:  124
# Answer:      124
# Calc:  Copy(124)
#
# Prediction:  1
# Answer:      1
# Calc:  Copy(1)
#
# Prediction:  19
# Answer:      19
# Calc:  Copy(19)
#
# Prediction:  5
# Answer:      5
# Calc:  Trans(five)
#
# Prediction:  1
# Answer:      9/11
# Calc:  Copy(9/11)
#
# Prediction:  126
# Answer:      8
# Calc:  Copy(8)
#
# Prediction:  200
# Answer:      200
# Calc:  Paraphrase(200,000,K)
#
# Prediction:  94
# Answer:      94
# Calc:  Copy(94)
#
# Prediction:  20
# Answer:      20
# Calc:  Copy(20)
#
# Prediction:  300
# Answer:      300
# Calc:  Copy(300)
#
# Prediction:  34
# Answer:      60
# Calc:  Copy(60)
#
# Prediction:  19
# Answer:      19
# Calc:  Copy(19)
#
# Prediction:  8
# Answer:      8
# Calc:  Copy(8)
#
# Prediction:  86
# Answer:      86
# Calc:  Copy(86)
#
# Prediction:  29
# Answer:      29
# Calc:  Copy(29)
#
# Prediction:  12
# Answer:      12
# Calc:  Copy(12)
#
# Prediction:  90
# Answer:      1991
# Calc:  Copy(1991)
#
# Prediction:  1
# Answer:      1.3
# Calc:  Copy(1.3)
#
# Prediction:  2
# Answer:      5
# Calc:  Subtract(2018,2013)
#
# Prediction:  2
# Answer:      2
# Calc:  Copy(2)
#
# Prediction:  15
# Answer:      15
# Calc:  Copy(15)
#
# Prediction:  5
# Answer:      5
# Calc:  Copy(5)
#
# Prediction:  3
# Answer:      3
# Calc:  Round(Paraphrase(3,100 ,K),0)
#
# Prediction:  94
# Answer:      94
# Calc:  Copy(94)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(Two)
#
# Prediction:  8
# Answer:      8
# Calc:  Copy(8)
#
# Prediction:  96
# Answer:      96
# Calc:  Copy(96)
#
# Prediction:  2
# Answer:      2
# Calc:  Copy(2)
#
# Prediction:  2020
# Answer:      2020
# Calc:  Copy(2020)
#
# Prediction:  5
# Answer:      5
# Calc:  Trans(five)
#
# Prediction:  140
# Answer:      2,979
# Calc:  Copy(2,979)
#
# Prediction:  9
# Answer:      9.4
# Calc:  Copy(9.4)
#
# Prediction:  5
# Answer:      5
# Calc:  Trans(five)
#
# Prediction:  111
# Answer:      102
# Calc:  Round(Paraphrase(102,218,K),0)
#
# Prediction:  15
# Answer:      15
# Calc:  Copy(15)
#
# Prediction:  2
# Answer:      2
# Calc:  Copy(2)
#
# Prediction:  89
# Answer:      89
# Calc:  Copy(89)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(second)
#
# Prediction:  2015
# Answer:      2015
# Calc:  Copy(2015)
#
# Prediction:  Life
# Answer:      15
# Calc:  Copy(15)
#
# Prediction:  11
# Answer:      11
# Calc:  Copy(11)
#
# Prediction:  39
# Answer:      39
# Calc:  Copy(39)
#
# Prediction:  100
# Answer:      100
# Calc:  Copy(100)
#
# Prediction:  548
# Answer:      399
# Calc:  Copy(399)
#
# Prediction:  26
# Answer:      26
# Calc:  Copy(26)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(second)
#
# Prediction:  4
# Answer:      5
# Calc:  Round(4.8,0)
#
# Prediction:  100
# Answer:      100
# Calc:  Copy(100)
#
# Prediction:  163
# Answer:      163
# Calc:  Copy(163)
#
# Prediction:  1
# Answer:      1
# Calc:  Copy(1)
#
# Prediction:  8
# Answer:      8
# Calc:  Copy(8)
#
# Prediction:  50
# Answer:      50
# Calc:  Copy(50)
#
# Prediction:  3
# Answer:      3
# Calc:  Trans(three)
#
# Prediction:  1
# Answer:      1
# Calc:  Trans(first)
#
# Prediction:  82
# Answer:      82
# Calc:  Copy(82)
#
# Prediction:  100
# Answer:      100
# Calc:  Subtract(2017,1917)
#
# Prediction:  7
# Answer:      7
# Calc:  Copy(7)
#
# Prediction:  1
# Answer:      1.5
# Calc:  Paraphrase(1,500,K)
#
# Prediction:  911
# Answer:      911
# Calc:  Copy(911)
#
# Prediction:  20
# Answer:      20
# Calc:  Copy(20)
#
# Prediction:  100
# Answer:      100
# Calc:  Copy(100)
#
# Prediction:  2
# Answer:      75
# Calc:  Paraphrase(75,000,K)
#
# Prediction:  5
# Answer:      5
# Calc:  Trans(five)
#
# Prediction:  6
# Answer:      6
# Calc:  Trans(six)
#
# Prediction:  5
# Answer:      10
# Calc:  Copy(10)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  30
# Answer:      30
# Calc:  Copy(30)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  19
# Answer:      60
# Calc:  Copy(60)
#
# Prediction:  2
# Answer:      2
# Calc:  Add(Span(it was an hour before American troops called for help from nearby French forces),Span(another hour after that before French Mirage jet fighters arrived at the scene near the border with Mali))
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  8
# Answer:      8
# Calc:  Trans(eight)
#
# Prediction:  370
# Answer:      370
# Calc:  Copy(370)
#
# Prediction:  96
# Answer:      96
# Calc:  Copy(96)
#
# Prediction:  10
# Answer:      10
# Calc:  Copy(10)
#
# Prediction:  47
# Answer:      47
# Calc:  Copy(47)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  3
# Answer:      3
# Calc:  Trans(three)
#
# Prediction:  5
# Answer:      9
# Calc:  Round(8.76, 0)
#
# Prediction:  2
# Answer:      2
# Calc:  Copy(2)
#
# Prediction:  66
# Answer:      66
# Calc:  Copy(66)
#
# Prediction:  15
# Answer:      15
# Calc:  Copy(15)
#
# Prediction:  87
# Answer:      87
# Calc:  Copy(87)
#
# Prediction:  4
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  89
# Answer:      89
# Calc:  Copy(89)
#
# Prediction:  5
# Answer:      5
# Calc:  Trans(Five)
#
# Prediction:  35
# Answer:      35
# Calc:  Copy(35)
#
# Prediction:  2020
# Answer:      2020
# Calc:  Copy(2020)
#
# Prediction:  1
# Answer:      1
# Calc:  Copy(1)
#
# Prediction:  4
# Answer:      4
# Calc:  Copy(4)
#
# Prediction:  530
# Answer:      530
# Calc:  Paraphrase(530,000,K)
#
# Prediction:  90
# Answer:      90
# Calc:  Copy(90)
#
# Prediction:  5
# Answer:      5
# Calc:  Trans(five)
#
# Prediction:  81
# Answer:      23
# Calc:  Copy(23)
#
# Prediction:  69
# Answer:      69
# Calc:  Copy(69)
#
# Prediction:  1977
# Answer:      1976
# Calc:  Subtract(1977,1)
#
# Prediction:  1
# Answer:      1
# Calc:  Copy(1)
#
# Prediction:  19
# Answer:      19
# Calc:  Copy(19)
#
# Prediction:  67
# Answer:      33
# Calc:  Subtract(100,67)
#
# Prediction:  2000
# Answer:      2000
# Calc:  Copy(2000)
#
# Prediction:  1
# Answer:      1.4
# Calc:  Paraphrase(1,400,K)
#
# Prediction:  20
# Answer:      1920
# Calc:  Copy(1920)
#
# Prediction:  79
# Answer:      79
# Calc:  Copy(79)
#
# Prediction:  78
# Answer:      78
# Calc:  Copy(78)
#
# Prediction:  5
# Answer:      5
# Calc:  Trans(five)
#
# Prediction:  5
# Answer:      5
# Calc:  Trans(Five)
#
# Prediction:  8
# Answer:      8
# Calc:  Copy(8)
#
# Prediction:  1995
# Answer:      1995
# Calc:  Copy(1995)
#
# Prediction:  2
# Answer:      2
# Calc:  Copy(2)
#
# Prediction:  11
# Answer:      11
# Calc:  Copy(11)
#
# Prediction:  3
# Answer:      100
# Calc:  Copy(100)
#
# Prediction:  1
# Answer:      1
# Calc:  Copy(1)
#
# Prediction:  1
# Answer:      1
# Calc:  Paraphrase(1,000,K)
#
# Prediction:  5
# Answer:      5
# Calc:  Trans(five)
#
# Prediction:  90
# Answer:      14
# Calc:  Copy(14)
#
# Prediction:  17
# Answer:      17
# Calc:  Copy(17)
#
# Prediction:  5
# Answer:      5
# Calc:  Trans(five)
#
# Prediction:  1
# Answer:      1
# Calc:  Trans(first)
#
# Prediction:  2
# Answer:      2
# Calc:  Copy(2)
#
# Prediction:  130
# Answer:      130
# Calc:  Copy(130)
#
# Prediction:  2
# Answer:      2.5
# Calc:  Copy(2.5)
#
# Prediction:  600
# Answer:      592
# Calc:  Copy(592)
#
# Prediction:  15
# Answer:      21.6
# Calc:  Copy(21.6)
# Prediction:  69
# Answer:      69
# Calc:  Copy(69)
#
# Prediction:  2018
# Answer:      2018
# Calc:  Copy(2018)
#
# Prediction:  7
# Answer:      7
# Calc:  Trans(seven)
#
# Prediction:  74
# Answer:      74
# Calc:  Copy(74)
#
# Prediction:  500
# Answer:      500
# Calc:  Copy(500)
#
# Prediction:  4
# Answer:      5
# Calc:  Trans(five)
#
# Prediction:  4
# Answer:      4
# Calc:  Copy(4)
#
# Prediction:  3
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  860
# Answer:      860
# Calc:  Paraphrase(860,000,K)
#
# Prediction:  5
# Answer:      5
# Calc:  Trans(Five)
#
# Prediction:  45
# Answer:      45
# Calc:  Copy(45)
#
# Prediction:  21
# Answer:      21
# Calc:  Copy(21)
#
# Prediction:  2
# Answer:      22
# Calc:  Paraphrase(22,000,K)
#
# Prediction:  16
# Answer:      16
# Calc:  Copy(16)
#
# Prediction:  20
# Answer:      300
# Calc:  Paraphrase(300,000,K)
#
# Prediction:  10
# Answer:      10
# Calc:  Copy(10)
#
# Prediction:  330
# Answer:      330
# Calc:  Copy(330)
#
# Prediction:  8
# Answer:      8
# Calc:  Trans(Eight)
#
# Prediction:  2017
# Answer:      2016
# Calc:  Copy(2016)
#
# Prediction:  21
# Answer:      21.6
# Calc:  Copy(21.6)
#
# Prediction:  3
# Answer:      8
# Calc:  Trans(eight)
#
# Prediction:  730
# Answer:      730
# Calc:  Paraphrase(730,000,K)
#
# Prediction:  100
# Answer:      100
# Calc:  Copy(100)
#
# Prediction:  1
# Answer:      1
# Calc:  Copy(1)
#
# Prediction:  32
# Answer:      32
# Calc:  Copy(32)
#
# Prediction:  50
# Answer:      50
# Calc:  Copy(50)
#
# Prediction:  50
# Answer:      50
# Calc:  Paraphrase(50,000,k)
#
# Prediction:  4
# Answer:      1.2
# Calc:  Copy(1.2)
#
# Prediction:  100
# Answer:      100
# Calc:  Copy(100)
#
# Prediction:  1
# Answer:      1
# Calc:  Copy(1)
#
# Prediction:  3
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  8
# Answer:      8
# Calc:  Trans(eight)
#
# Prediction:  65
# Answer:      65
# Calc:  Copy(65)
#
# Prediction:  3
# Answer:      3
# Calc:  Trans(three)
#
# Prediction:  172
# Answer:      172
# Calc:  Copy(172)
#
# Prediction:  500
# Answer:      500
# Calc:  Copy(500)
#
# Prediction:  2018
# Answer:      2013
# Calc:  Copy(2013)
#
# Prediction:  5
# Answer:      5
# Calc:  Trans(five)
#
# Prediction:  5
# Answer:      5
# Calc:  Copy(5)
#
# Prediction:  69
# Answer:      69
# Calc:  Copy(69)
#
# Prediction:  4
# Answer:      4
# Calc:  Copy(4)
#
# Prediction:  1
# Answer:      3
# Calc:  Trans(three)
#
# Prediction:  2011
# Answer:      2011
# Calc:  Copy(2011)
#
# Prediction:  8
# Answer:      8
# Calc:  Trans(eight)
#
# Prediction:  12
# Answer:      12
# Calc:  Copy(12)
#
# Prediction:  50
# Answer:      50.1
# Calc:  Copy(50.1)
#
# Prediction:  401
# Answer:      401
# Calc:  Copy(401)
#
# Prediction:  372
# Answer:      372
# Calc:  Copy(372)
#
# Prediction:  18
# Answer:      18
# Calc:  Copy(18)
#
# Prediction:  1
# Answer:      1
# Calc:  Paraphrase(1,000,K)
#
# Prediction:  70
# Answer:      70
# Calc:  Paraphrase(70,000,K)
#
# Prediction:  190
# Answer:      190
# Calc:  Paraphrase(190,000,K)
#
# Prediction:  20
# Answer:      20
# Calc:  Copy(20)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  3
# Answer:      21
# Calc:  Subtract(23,Add(Span(Mother),Span(Baby)))
#
# Prediction:  30
# Answer:      30
# Calc:  Copy(30)
#
# Prediction:  30
# Answer:      30
# Calc:  Copy(30)
#
# Prediction:  3
# Answer:      3
# Calc:  Copy(3)
#
# Prediction:  2004
# Answer:      2016
# Calc:  Copy(2016)
#
# Prediction:  3
# Answer:      3
# Calc:  Copy(3)
#
# Prediction:  1
# Answer:      1
# Calc:  Trans(first)
#
# Prediction:  33
# Answer:      33
# Calc:  SRound(33.8,0)
#
# Prediction:  46
# Answer:      46
# Calc:  Copy(46)
#
# Prediction:  41
# Answer:      41
# Calc:  Copy(41)
#
# Prediction:  1
# Answer:      1
# Calc:  Copy(1)
#
# Prediction:  8
# Answer:      8
# Calc:  Trans(eight)
#
# Prediction:  5
# Answer:      5
# Calc:  Trans(five)
#
# Prediction:  2030
# Answer:      2030
# Calc:  Copy(2030)
#
# Prediction:  3
# Answer:      50
# Calc:  Copy(50)
#
# Prediction:  1
# Answer:      1
# Calc:  Copy(1)
#
# Prediction:  20
# Answer:      20
# Calc:  Copy(20)
#
# Prediction:  45
# Answer:      45
# Calc:  Copy(45)
#
# Prediction:  5
# Answer:      5
# Calc:  Trans(five)
#
# Prediction:  30
# Answer:      35
# Calc:  Copy(35)
#
# Prediction:  60
# Answer:      6
# Calc:  Divide(60,10)
#
# Prediction:  51
# Answer:      51
# Calc:  Copy(51)
#
# Prediction:  43
# Answer:      43
# Calc:  Copy(43)
#
# Prediction:  5
# Answer:      5
# Calc:  Trans(five)
#
# Prediction:  11
# Answer:      11
# Calc:  Copy(11)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  10
# Answer:      10
# Calc:  Paraphrase(10,000,K)
#
# Prediction:  3
# Answer:      3
# Calc:  Copy(3)
#
# Prediction:  4
# Answer:      8
# Calc:  Trans(eighth)
#
# Prediction:  35
# Answer:      35
# Calc:  Copy(35)
#
# Prediction:  8
# Answer:      8
# Calc:  Copy(8)
#
# Prediction:  1
# Answer:      1.8
# Calc:  Copy(1.8)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  8
# Answer:      8
# Calc:  Trans(Eight)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  25
# Answer:      25
# Calc:  Paraphrase(25,000,k)
#
# Prediction:  3
# Answer:      3
# Calc:  Trans(three)
#
# Prediction:  1
# Answer:      1
# Calc:  Copy(1)
#
# Prediction:  500
# Answer:      500
# Calc:  Copy(500)
#
# Prediction:  3
# Answer:      3
# Calc:  Copy(3)
#
# Prediction:  Worst
# Answer:      5
# Calc:  Trans(five)
#
# Prediction:  10
# Answer:      10
# Calc:  Copy(10)
#
# Prediction:  37
# Answer:      37
# Calc:  Copy(37)
#
# Prediction:  5
# Answer:      5
# Calc:  Trans(five)
#
# Prediction:  8
# Answer:      8.4
# Calc:  Copy(8.4)
#
# Prediction:  200
# Answer:      200
# Calc:  Paraphrase(200,000,K)
#
# Prediction:  3
# Answer:      3
# Calc:  Copy(3)
#
# Prediction:  90
# Answer:      90
# Calc:  Copy(90)
#
# Prediction:  64
# Answer:      64
# Calc:  Copy(64)
#
# Prediction:  63
# Answer:      63
# Calc:  Copy(63)
#
# Prediction:  7
# Answer:      7
# Calc:  Round(7.25,0)
#
# Prediction:  6
# Answer:      6
# Calc:  Trans(six)
#
# Prediction:  4
# Answer:      4.49
# Calc:  Copy(4.49)
#
# Prediction:  39
# Answer:      39
# Calc:  Copy(39)
#
# Prediction:  28
# Answer:      28
# Calc:  Copy(28)
#
# Prediction:  13
# Answer:      13
# Calc:  Copy(13)
#
# Prediction:  4
# Answer:      4
# Calc:  Copy(4)
#
# Prediction:  145
# Answer:      145
# Calc:  Paraphrase(145,000,K)
#
# Prediction:  500
# Answer:      500
# Calc:  Copy(500)
#
# Prediction:  3
# Answer:      3
# Calc:  Trans(three)
#
# Prediction:  20
# Answer:      20
# Calc:  Copy(20)
#
# Prediction:  10
# Answer:      10
# Calc:  Copy(10)
#
# Prediction:  3
# Answer:      32
# Calc:  Subtract(2017,1985)
#
# Prediction:  61
# Answer:      61
# Calc:  Copy(61)
#
# Prediction:  138
# Answer:      138
# Calc:  Copy(138)
#
# Prediction:  1
# Answer:      1
# Calc:  Trans(one)
#
# Prediction:  2020
# Answer:      2020
# Calc:  Copy(2020)
#
# Prediction:  297
# Answer:      297
# Calc:  Copy(297)
#
# Prediction:  112
# Answer:      112
# Calc:  Copy(112)
#
# Prediction:  27
# Answer:      27
# Calc:  Copy(27)
#
# Prediction:  15
# Answer:      15
# Calc:  Copy(15)
#
# Prediction:  47
# Answer:      47
# Calc:  Copy(47)
#
# Prediction:  240
# Answer:      240
# Calc:  Copy(240)
#
# Prediction:  1993
# Answer:      1993
# Calc:  Copy(1993)
#
# Prediction:  40
# Answer:      40
# Calc:  Paraphrase(40,000,K)
#
# Prediction:  15
# Answer:      15
# Calc:  Copy(15)
#
# Prediction:  800
# Answer:      800
# Calc:  Paraphrase(800,000,k)
#
# Prediction:  10
# Answer:      10
# Calc:  Copy(10)
#
# Prediction:  1
# Answer:      1
# Calc:  Copy(1)
#
# Prediction:  9
# Answer:      10
# Calc:  Add(1,Trans(nine))
#
# Prediction:  49
# Answer:      49
# Calc:  Copy(49)
#
# Prediction:  80
# Answer:      80
# Calc:  Copy(80)
#
# Prediction:  8
# Answer:      8
# Calc:  Trans(eight)
#
# Prediction:  27
# Answer:      27
# Calc:  Copy(27)
#
# Prediction:  1997
# Answer:      1994
# Calc:  Copy(1994)
#
# Prediction:  18
# Answer:      18
# Calc:  Copy(18)
#
# Prediction:  60
# Answer:      56
# Calc:  Subtract(2016,1961)
#
# Prediction:  2
# Answer:      2
# Calc:  Trans(two)
#
# Prediction:  32
# Answer:      32
# Calc:  Copy(32)
#
# Prediction:  400
# Answer:      400
# Calc:  Paraphrase(400,000,K)
#
# Prediction:  60
# Answer:      200
# Calc:  Paraphrase(200,000,k)
#
# Prediction:  100
# Answer:      100
# Calc:  Paraphrase(100,000,K)
#
# Prediction:  400
# Answer:      400
# Calc:  Paraphrase(400,000,K)
#
# Prediction:  5
# Answer:      5.6
# Calc:  Copy(5.6)
#
# Prediction:  151
# Answer:      151
# Calc:  Copy(151)
#
# Prediction:  20
# Answer:      20
# Calc:  Copy(20)
#
# Prediction:  21
# Answer:      21
# Calc:  Paraphrase(21,000,K)
#
# Prediction:  2
# Answer:      2
# Calc:  Copy(2)
#
# Prediction:  10
# Answer:      0.07
# Calc:  Copy(0.07)
#
# Prediction:  16
# Answer:      16
# Calc:  Copy(16)
#
# Prediction:  3
# Answer:      3
# Calc:  Trans(third)
#
# Prediction:  2016
# Answer:      2016
# Calc:  Copy(2016)
#
# Prediction:  94
# Answer:      94
# Calc:  Copy(94)
#
# Prediction:  18
# Answer:      18
# Calc:  Copy(18)
#
# Prediction:  15
# Answer:      15
# Calc:  Copy(15)
# Prediction:  3
# Answer:      3
# Calc:  Trans(three)
#
# Prediction:  3
# Answer:      3
# Calc:  Trans(three)

# %%
tr/len(test_data)
# Out:
# 0.7982115085536547

# %%
from sklearn.metrics import accuracy_score
accuracy_score(df['ans'], pre)
# Out:
# 0.7982115085536547
